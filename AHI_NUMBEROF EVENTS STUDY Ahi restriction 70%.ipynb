# %%
import os
#     lookingSection = "Respiratory"
lookingSection = "Arousal"
lookingSection


import os
# import pyedflib
import argparse
import statistics
import numpy as np
import scipy.signal 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import time
import scipy.interpolate

import pandas as pd
col_list = ["a"]

t1 = time.time()


df = pd.read_csv("C:/Users/Bpradsad/Desktop/data/SaO2/norm_sparkremoverAVG_full50_STFT_n/htnderv_s2_n.csv", usecols=["a","b"])
## shhs1-200001
file_n = []
for i in df["a"]:
    file_n.append(f"{i}")

df = pd.read_csv("C:/Users/Bpradsad/Desktop/data/SaO2/norm_sparkremoverAVG_full50_STFT_n/htnderv_s2_n.csv", usecols=["a","b"])
## shhs1-200001
label_n = []
for i in df["b"]:
#     print(df["b"])
    label_n.append(f"{i}")

import os.path
file_nn = []
label_nn = []
for i, patient in enumerate(file_n):
    file_exist = os.path.exists('D:/Directory_D_Desk_jup/Raw_npy/Signal_SaO2_OX_'+lookingSection+"/"+patient)
    if file_exist == True:
        file_nn.append(patient)
        label_nn.append(int(label_n[i]))
    if file_exist == False:
        pass
#         print(patient)




D_len = {}
tempp = []
for counter, patient in enumerate(file_nn, 0):
    p = []
    temp = np.load('D:/Directory_D_Desk_jup/Raw_npy/Signal_SaO2_OX_'+lookingSection+"/"+patient)
    D_len[patient[:-7]] = len(temp)//30
    tempp.append(len(temp)//30)
np.cumsum(tempp)



import math

df = pd.read_csv("C:/Features/time_6_"+lookingSection+"_segmented/htnderv_s2_nnn.csv", usecols=["a","b"])
df = df.dropna(axis=0)
# ## shhs1-200001
file_n = []
label_n = []
for i,j in zip(df["a"],df["b"]):
    file_n.append(f"{i}")
    label_n.append(int(j))




D_len = {}
tempp = []
for counter, patient in enumerate(file_nn, 0):
    p = []
    temp = np.load("D:/Directory_D_Desk_jup/Raw_npy/Signal_SaO2_OX_"+lookingSection+"/"+patient)
    D_len[patient[:-7]] = len(temp)//30
    tempp.append(len(temp)//30)

CUMSUM = np.cumsum(tempp)
CUMSUM_train = CUMSUM[:1400]
CUMSUM_new = CUMSUM - CUMSUM[1400]
CUMSUM_new = CUMSUM_new[1400:]

# folder path
dir_path = "C:/Features/SVM_SUBFEATURE_RES/"
# dir_path = "C:/Features/SVM_SUBFEATURE_RES/NewHalf/"
# dir_path = "C:/Features/SVM_SUBFEATURE_RES/gamma_C/"
# dir_path = "C:/Features/SVM_SUBFEATURE_RES/prob/"

# list to store files
res = []
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        res.append(path)
print(res)


actual_label = []
for i in range(0, len(CUMSUM)-2):
#     print(lbl[CUMSUMM[i]:CUMSUMM[i+1]])
#     print((sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))
    actual_label.append(int(sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))
print("The combination of 1 and 0 in dataset: %.2f" %(sum(actual_label)/len(actual_label)*100)+"%")
# Out:
# ['74_feature_Arousal_normed_0.11.0_33_38_5.npy', '74_feature_Arousal_normed_1.010.0_23_28_32.npy', '74_feature_Arousal_normed_10.010.0_18_23_35.npy', '74_feature_Arousal_normed_10.010.0_28_33_21.npy', '74_feature_Arousal_normed_100.00.1_8_18_43.npy', '74_feature_Arousal_normed_100.010.0_0_1_31.npy', '74_feature_Arousal_normed_100.010.0_18_23_46.npy', '74_feature_Arousal_normed_100.010.0_1_8_129.npy', '74_feature_Arousal_normed_100.010.0_23_28_22.npy', '74_feature_Arousal_normed_100.010.0_28_33_47.npy', '74_feature_Arousal_normed_100.010.0_38_43_31.npy', '74_feature_Arousal_normed_100.010.0_38_43_42.npy', '74_feature_Arousal_normed_100.010.0_43_48_60.npy', '74_feature_Arousal_normed_100.010.0_48_53_140.npy', '74_feature_Arousal_normed_100.010.0_53_58_26.npy', '74_feature_Arousal_normed_100.010.0_58_63_13.npy', '74_feature_Arousal_normed_100.010.0_63_68_90.npy', '74_feature_Arousal_normed_100.010.0_68_73_90.npy', 'actual_label.npy', 'full_ECG_Feature_new_10.01.0_0_10000_16.npy', 'log_S6.npy', 'maxmfcc85.npy', 'mfcc39.npy', 'minmfcc100.npy', 'pitch_arousal_hann_amp51.npy', 'pitch_arousal_hann_amp_100.00.1_0_10000_51.npy', 'pred_label_svm_arousal_interval.npy', 'pred_label_svm_resp_interval.npy', 'R_R_freq_new_10.010.0_0_10000_62.npy', 'R_R_time_new_100.00.1_0_10000_43.npy', 'Simple_NN.ipynb', 'SVM_AROUSAL_pitch48.npy', 'SVM_AROUSAL_pitch_hann24.npy', 'SVM_AROUSAL_SUBFEATURES_0_1_32.npy', 'SVM_AROUSAL_SUBFEATURES_18_23_34.npy', 'SVM_AROUSAL_SUBFEATURES_1_8_128.npy', 'SVM_AROUSAL_SUBFEATURES_23_28_23.npy', 'SVM_AROUSAL_SUBFEATURES_24_25_53.npy', 'SVM_AROUSAL_SUBFEATURES_28_33_35.npy', 'SVM_AROUSAL_SUBFEATURES_29_30_38.npy', 'SVM_AROUSAL_SUBFEATURES_33_38_5.npy', 'SVM_AROUSAL_SUBFEATURES_34_35_2.npy', 'SVM_AROUSAL_SUBFEATURES_38_43_30.npy', 'SVM_AROUSAL_SUBFEATURES_39_40_1.npy', 'SVM_AROUSAL_SUBFEATURES_43_48_41.npy', 'SVM_AROUSAL_SUBFEATURES_44_45_37.npy', 'SVM_AROUSAL_SUBFEATURES_48_53_118.npy', 'SVM_AROUSAL_SUBFEATURES_49_50_92.npy', 'SVM_AROUSAL_SUBFEATURES_53_58_56.npy', 'SVM_AROUSAL_SUBFEATURES_54_55_12.npy', 'SVM_AROUSAL_SUBFEATURES_58_63_6.npy', 'SVM_AROUSAL_SUBFEATURES_59_60_93.npy', 'SVM_AROUSAL_SUBFEATURES_63_68_93.npy', 'SVM_AROUSAL_SUBFEATURES_63_68_94.npy', 'SVM_AROUSAL_SUBFEATURES_64_65_91.npy', 'SVM_AROUSAL_SUBFEATURES_68_73_93.npy', 'SVM_AROUSAL_SUBFEATURES_68_73_94.npy', 'SVM_AROUSAL_SUBFEATURES_69_70_91.npy', 'SVM_AROUSAL_SUBFEATURES_73_74_132.npy', 'SVM_AROUSAL_SUBFEATURES_8_18_40.npy', 'SVM_AROUSAL_SUBFEATURES_full_ECG_Feature_new_14.npy', 'SVM_AROUSAL_SUBFEATURES_R_R_freq_new_118.npy', 'SVM_AROUSAL_SUBFEATURES_R_R_time_new_25.npy', 'SVM_Respiratory_SUBFEATURES_0_5_14.npy', 'SVM_Respiratory_SUBFEATURES_10_15_1.npy', 'SVM_Respiratory_SUBFEATURES_15_20_13.npy', 'SVM_Respiratory_SUBFEATURES_20_25_21.npy', 'SVM_Respiratory_SUBFEATURES_24_25_53.npy', 'SVM_Respiratory_SUBFEATURES_25_30_67.npy', 'SVM_Respiratory_SUBFEATURES_30_35_1.npy', 'SVM_Respiratory_SUBFEATURES_35_40_75.npy', 'SVM_Respiratory_SUBFEATURES_40_45_95.npy', 'SVM_Respiratory_SUBFEATURES_45_50_29.npy', 'SVM_Respiratory_SUBFEATURES_50_55_29.npy', 'SVM_Respiratory_SUBFEATURES_5_10_56.npy', 'SVM_Respiratory_SUBFEATURES_R_R_time125.npy', 'SVM_Respiratory_SUBFEATURES_R_R_time130.npy']
# The combination of 1 and 0 in dataset: 50.14%

# %% [markdown]
# Reading shhs 1-2

# %%
import pandas as pd

best_i = -1
# Read the CSV file into a pandas DataFrame
df = pd.read_csv('C:/Users/Bpradsad/Desktop/prof cetin/prof beharati/shhs1- 2.csv')

# Filter the rows where the "ahi_a0h3a.csv" column is greater than or equal to 5
# and the "htnderv_s1" column is 1
filtered_df = df[(df["ahi_a0h3a"] >= 10) & (df["htnderv_s1"] == 0) & (df["htnderv_s2"].notnull())]
# Out:
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_20852\2602799411.py:5: DtypeWarning: Columns (1263,1347) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/Bpradsad/Desktop/prof cetin/prof beharati/shhs1- 2.csv')

# %%
import matplotlib.pyplot as plt

# Input data
data = tempp

# Plot histogram
plt.hist(data, bins=50)

# Set plot title and axis labels
plt.title("Input Data Distribution")
plt.xlabel("Number of events")
plt.ylabel("Number of data")

# Display plot
plt.show()

# %%
tempp_consider = np.where(np.array(tempp) > 60, 1, 0)

# %%
len(tempp_consider[1400:])
# Out:
# 341

# %%
plt.plot(tempp_consider)

# %%
print("len of data", len(tempp_consider[1400:]), "number of zero in the dataset", list(tempp_consider[1400:]).count(0))
# Out:
# len of data 341 number of zero in the dataset 16

# %%
plt.plot(tempp_consider[1400:])

# %%
len(actual_label[-338:])
# Out:
# 338

# %%
Before = ["SVM_AROUSAL_SUBFEATURES_R_R_freq_new_118.npy",
          "SVM_AROUSAL_SUBFEATURES_R_R_time_new_25.npy",
          "SVM_AROUSAL_SUBFEATURES_R_R_time_new_25.npy",
          'SVM_AROUSAL_SUBFEATURES_23_28_23.npy', 
          'SVM_AROUSAL_SUBFEATURES_28_33_35.npy', 
          'SVM_AROUSAL_SUBFEATURES_33_38_5.npy', 
          'SVM_AROUSAL_SUBFEATURES_38_43_30.npy', 
          'SVM_AROUSAL_SUBFEATURES_43_48_41.npy', 
          'SVM_AROUSAL_SUBFEATURES_48_53_118.npy', 
          'SVM_AROUSAL_SUBFEATURES_63_68_93.npy',              ###
          "SVM_AROUSAL_pitch48.npy",
          'SVM_AROUSAL_SUBFEATURES_0_1_32.npy', 
          'SVM_AROUSAL_SUBFEATURES_1_8_128.npy',
          'SVM_AROUSAL_SUBFEATURES_23_28_23.npy',
          'SVM_AROUSAL_SUBFEATURES_28_33_35.npy',
          'SVM_AROUSAL_SUBFEATURES_33_38_5.npy', 
          'SVM_AROUSAL_SUBFEATURES_38_43_30.npy',  
          'SVM_AROUSAL_SUBFEATURES_48_53_118.npy',
          'SVM_AROUSAL_SUBFEATURES_53_58_56.npy', 
          'SVM_AROUSAL_SUBFEATURES_58_63_6.npy', 
          'SVM_AROUSAL_SUBFEATURES_63_68_93.npy',                ####
          'SVM_AROUSAL_SUBFEATURES_73_74_132.npy',
          'SVM_AROUSAL_SUBFEATURES_8_18_40.npy']

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc,roc_auc_score
import seaborn as sns
dic = {}
for idx, s in enumerate(Before):
    dic[idx] = np.load(dir_path+s)

# %%
dic = {}
for idx, s in enumerate(Before):
    dic[idx] = np.load(dir_path+s)

# %%
y_test = []
for i, patient in enumerate(file_n):
    if i < CUMSUM[1400]:
        pass
    else:
        y_test.append(label_n[i])

# %%
len(actual_label)
# Out:
# 1739

# %%
sum(tempp_consider)
# Out:
# 1637

# %%
# dic = dic2


best = -100
ee = 338

ss = 0
eee = 1

import numpy as np



for event_base in np.arange(10,50):
    for AHI_base in np.arange(5,30):        
#         for num_1 in range(len(dic)):
        for num_1 in [10]:
            
            print(">>>", event_base, AHI_base, num_1)
            prob = [] 
#             print(num_1)
        # on the training set the num_1 value is 6 or 7 in average
        # for num_1 in w:
            pred_label_fused = []
            for i in range(338):

        # max vote approach ################################################################
                fused_label = []
                for j in range(len(dic)):
                    fused_label.append(dic[j][i])

                if sum(fused_label) > num_1:
                    pred_label_fused.append(1)
                else:
                    pred_label_fused.append(0)

                prob.append(sum(fused_label)/len(fused_label))


            from sklearn.metrics import confusion_matrix
            import matplotlib.pyplot as plt
            from sklearn.metrics import roc_curve, auc,roc_auc_score
            import seaborn as sns


            actual_label = []
            # CUMSUM[0] starting from second data in all data(train+test)
            for i in range(0, len(CUMSUM)-2):
                actual_label.append(int(sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))


            actual_label = actual_label[-ee:]
            pred_label_fused = pred_label_fused[-ee:]

        #     print(len(actual_label), len(pred_label_fused))


            ###event base #############################################################################
            tempp_consider = np.where(np.array(tempp) > event_base, 1, 0)    
            #### AHI > THER ###########################################################################
            filtered_df = df[(df["ahi_a0h3a"] >= AHI_base) & (df["htnderv_s1"] == 0) & (df["htnderv_s2"].notnull())]
            selected_basedonAHI = [str(x[0]) for x in filtered_df[["nsrrid"]].values]
            AHI_considered = []
            for patient in file_nn:
                if patient[6:-7] in selected_basedonAHI:
                    AHI_considered.append(1)
                else:
                    AHI_considered.append(0)
            AHI_considered = np.array(AHI_considered)
            ################################################################################
            final_consider = tempp_consider&AHI_considered

            ## update ################################################################################
            Consider = [np.array(final_consider)==1][0]
            Consider = np.array(Consider[1:-1])
            Consider = Consider[-ee:]

            # update
            actual_label = np.array(actual_label)[Consider]
            pred_label_fused = np.array(pred_label_fused)[Consider]

#             print(len(actual_label), len(pred_label_fused))


            cf1 = confusion_matrix(actual_label[ss:int(eee*len(actual_label))], pred_label_fused[ss:int(eee*len(actual_label))])

            lenn = len(pred_label_fused[ss:int(eee*len(actual_label))])

            if best < (cf1[0][0] + cf1[1][1]) / lenn:
                best_pred = pred_label_fused
                best = (cf1[0][0] + cf1[1][1]) / lenn
                print((cf1[0][0] + cf1[1][1]) / lenn, "num_1", num_1)
                # Labels, title and ticks
                label_font = {'size':'18'}  # Adjust to fit
                sns.set(font_scale=2.0) # Adjust to fit
#                 ax = sns.heatmap(cf1, annot=True, cmap='Blues' , fmt=".1f")
                # Calculate row-wise proportions
                row_sums = cf1.sum(axis=1)
                row_percents = cf1 / row_sums[:, np.newaxis]


                ax = sns.heatmap(row_percents, annot=True, fmt='.2%', cmap='Blues')
                # Add axis labels and title
                plt.xlabel('Predicted Values')
                plt.ylabel('Actual Values')
                plt.title('')
                plt.xticks([0.5, 1.5], ['False', 'True'])
                plt.yticks([0.5, 1.5], ['False', 'True'])
                plt.show()

                #############################################
                # calculate True Positive Rate (TPR) or Sensitivity
                TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
                print('True Positive Rate (TPR) or Sensitivity:', TPR)

                # calculate False Positive Rate (FPR)
                FPR = cf1[0][1] / (cf1[0][1] + cf1[1][1])
                print('False Positive Rate (FPR):', FPR)

                #################################################
                print(f"Accuracy: {best*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                plt.show()
# Out:
# >>> 10 5 10
# 0.6745562130177515 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.66875
# False Positive Rate (FPR): 0.3202247191011236
# Accuracy: 67.46 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 6 10
# 0.6837060702875399 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.6783216783216783
# False Positive Rate (FPR): 0.31176470588235294
# Accuracy: 68.37 Threshold for Number of Events: 10 Threshold for AHI: 6 lenght of data 313
# >>> 10 7 10
# 0.6938775510204082 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7076923076923077
# False Positive Rate (FPR): 0.3170731707317073
# Accuracy: 69.39 Threshold for Number of Events: 10 Threshold for AHI: 7 lenght of data 294
# >>> 10 8 10
# >>> 10 9 10
# 0.694980694980695 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7387387387387387
# False Positive Rate (FPR): 0.33783783783783783
# Accuracy: 69.50 Threshold for Number of Events: 10 Threshold for AHI: 9 lenght of data 259
# >>> 10 10 10
# 0.6962025316455697 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7551020408163265
# False Positive Rate (FPR): 0.34532374100719426
# Accuracy: 69.62 Threshold for Number of Events: 10 Threshold for AHI: 10 lenght of data 237
# >>> 10 11 10
# 0.6976744186046512 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7790697674418605
# False Positive Rate (FPR): 0.35658914728682173
# Accuracy: 69.77 Threshold for Number of Events: 10 Threshold for AHI: 11 lenght of data 215
# >>> 10 12 10
# 0.700507614213198 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7848101265822784
# False Positive Rate (FPR): 0.3559322033898305
# Accuracy: 70.05 Threshold for Number of Events: 10 Threshold for AHI: 12 lenght of data 197
# >>> 10 13 10
# >>> 10 14 10
# >>> 10 15 10
# >>> 10 16 10
# >>> 10 17 10
# >>> 10 18 10
# 0.703125 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7727272727272727
# False Positive Rate (FPR): 0.3333333333333333
# Accuracy: 70.31 Threshold for Number of Events: 10 Threshold for AHI: 18 lenght of data 128
# >>> 10 19 10
# 0.7073170731707317 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7857142857142857
# False Positive Rate (FPR): 0.3333333333333333
# Accuracy: 70.73 Threshold for Number of Events: 10 Threshold for AHI: 19 lenght of data 123
# >>> 10 20 10
# >>> 10 21 10
# >>> 10 22 10
# >>> 10 23 10
# >>> 10 24 10
# >>> 10 25 10
# >>> 10 26 10
# >>> 10 27 10
# >>> 10 28 10
# >>> 10 29 10
# >>> 10 30 10
# >>> 10 31 10
# >>> 10 32 10
# >>> 10 33 10
# >>> 10 34 10
# >>> 10 35 10
# >>> 10 36 10
# >>> 10 37 10
# >>> 10 38 10
# >>> 10 39 10
# >>> 10 40 10
# >>> 10 41 10
# >>> 10 42 10
# >>> 10 43 10
# >>> 10 44 10
# >>> 10 45 10
# >>> 10 46 10
# >>> 10 47 10
# >>> 10 48 10
# >>> 10 49 10
# >>> 11 5 10
# >>> 11 6 10
# >>> 11 7 10
# >>> 11 8 10
# >>> 11 9 10
# >>> 11 10 10
# >>> 11 11 10
# >>> 11 12 10
# >>> 11 13 10
# >>> 11 14 10
# >>> 11 15 10
# >>> 11 16 10
# >>> 11 17 10
# >>> 11 18 10
# >>> 11 19 10
# >>> 11 20 10
# >>> 11 21 10
# >>> 11 22 10
# >>> 11 23 10
# >>> 11 24 10
# >>> 11 25 10
# >>> 11 26 10
# >>> 11 27 10
# >>> 11 28 10
# >>> 11 29 10
# >>> 11 30 10
# >>> 11 31 10
# >>> 11 32 10
# >>> 11 33 10
# >>> 11 34 10
# >>> 11 35 10
# >>> 11 36 10
# >>> 11 37 10
# >>> 11 38 10
# >>> 11 39 10
# >>> 11 40 10
# >>> 11 41 10
# >>> 11 42 10
# >>> 11 43 10
# >>> 11 44 10
# >>> 11 45 10
# >>> 11 46 10
# >>> 11 47 10
# >>> 11 48 10
# >>> 11 49 10
# >>> 12 5 10
# >>> 12 6 10
# >>> 12 7 10
# >>> 12 8 10
# >>> 12 9 10
# >>> 12 10 10
# >>> 12 11 10
# >>> 12 12 10
# >>> 12 13 10
# >>> 12 14 10
# >>> 12 15 10
# >>> 12 16 10
# >>> 12 17 10
# >>> 12 18 10
# >>> 12 19 10
# >>> 12 20 10
# >>> 12 21 10
# >>> 12 22 10
# >>> 12 23 10
# >>> 12 24 10
# >>> 12 25 10
# >>> 12 26 10
# >>> 12 27 10
# >>> 12 28 10
# >>> 12 29 10
# >>> 12 30 10
# >>> 12 31 10
# >>> 12 32 10
# >>> 12 33 10
# >>> 12 34 10
# >>> 12 35 10
# >>> 12 36 10
# >>> 12 37 10
# >>> 12 38 10
# >>> 12 39 10
# >>> 12 40 10
# >>> 12 41 10
# >>> 12 42 10
# >>> 12 43 10
# >>> 12 44 10
# >>> 12 45 10
# >>> 12 46 10
# >>> 12 47 10
# >>> 12 48 10
# >>> 12 49 10
# >>> 13 5 10
# >>> 13 6 10
# >>> 13 7 10
# >>> 13 8 10
# >>> 13 9 10
# >>> 13 10 10
# >>> 13 11 10
# >>> 13 12 10
# >>> 13 13 10
# >>> 13 14 10
# >>> 13 15 10
# >>> 13 16 10
# >>> 13 17 10
# >>> 13 18 10
# >>> 13 19 10
# >>> 13 20 10
# >>> 13 21 10
# >>> 13 22 10
# >>> 13 23 10
# >>> 13 24 10
# >>> 13 25 10
# >>> 13 26 10
# >>> 13 27 10
# >>> 13 28 10
# >>> 13 29 10
# >>> 13 30 10
# >>> 13 31 10
# >>> 13 32 10
# >>> 13 33 10
# >>> 13 34 10
# >>> 13 35 10
# >>> 13 36 10
# >>> 13 37 10
# >>> 13 38 10
# >>> 13 39 10
# >>> 13 40 10
# >>> 13 41 10
# >>> 13 42 10
# >>> 13 43 10
# >>> 13 44 10
# >>> 13 45 10
# >>> 13 46 10
# >>> 13 47 10
# >>> 13 48 10
# >>> 13 49 10
# >>> 14 5 10
# >>> 14 6 10
# >>> 14 7 10
# >>> 14 8 10
# >>> 14 9 10
# >>> 14 10 10
# >>> 14 11 10
# >>> 14 12 10
# >>> 14 13 10
# >>> 14 14 10
# >>> 14 15 10
# >>> 14 16 10
# >>> 14 17 10
# >>> 14 18 10
# >>> 14 19 10
# >>> 14 20 10
# >>> 14 21 10
# >>> 14 22 10
# >>> 14 23 10
# >>> 14 24 10
# >>> 14 25 10
# >>> 14 26 10
# >>> 14 27 10
# >>> 14 28 10
# >>> 14 29 10
# >>> 14 30 10
# >>> 14 31 10
# >>> 14 32 10
# >>> 14 33 10
# >>> 14 34 10
# >>> 14 35 10
# >>> 14 36 10
# >>> 14 37 10
# >>> 14 38 10
# >>> 14 39 10
# >>> 14 40 10
# >>> 14 41 10
# >>> 14 42 10
# >>> 14 43 10
# >>> 14 44 10
# >>> 14 45 10
# >>> 14 46 10
# >>> 14 47 10
# >>> 14 48 10
# >>> 14 49 10
# >>> 15 5 10
# >>> 15 6 10
# >>> 15 7 10
# >>> 15 8 10
# >>> 15 9 10
# >>> 15 10 10
# >>> 15 11 10
# >>> 15 12 10
# >>> 15 13 10
# >>> 15 14 10
# >>> 15 15 10
# >>> 15 16 10
# >>> 15 17 10
# >>> 15 18 10
# >>> 15 19 10
# >>> 15 20 10
# >>> 15 21 10
# >>> 15 22 10
# >>> 15 23 10
# >>> 15 24 10
# >>> 15 25 10
# >>> 15 26 10
# >>> 15 27 10
# >>> 15 28 10
# >>> 15 29 10
# >>> 15 30 10
# >>> 15 31 10
# >>> 15 32 10
# >>> 15 33 10
# >>> 15 34 10
# >>> 15 35 10
# >>> 15 36 10
# >>> 15 37 10
# >>> 15 38 10
# >>> 15 39 10
# >>> 15 40 10
# >>> 15 41 10
# >>> 15 42 10
# >>> 15 43 10
# >>> 15 44 10
# >>> 15 45 10
# >>> 15 46 10
# >>> 15 47 10
# >>> 15 48 10
# >>> 15 49 10
# >>> 16 5 10
# >>> 16 6 10
# >>> 16 7 10
# >>> 16 8 10
# >>> 16 9 10
# >>> 16 10 10
# >>> 16 11 10
# >>> 16 12 10
# >>> 16 13 10
# >>> 16 14 10
# >>> 16 15 10
# >>> 16 16 10
# >>> 16 17 10
# >>> 16 18 10
# >>> 16 19 10
# >>> 16 20 10
# >>> 16 21 10
# >>> 16 22 10
# >>> 16 23 10
# >>> 16 24 10
# >>> 16 25 10
# >>> 16 26 10
# >>> 16 27 10
# >>> 16 28 10
# >>> 16 29 10
# >>> 16 30 10
# >>> 16 31 10
# >>> 16 32 10
# >>> 16 33 10
# >>> 16 34 10
# >>> 16 35 10
# >>> 16 36 10
# >>> 16 37 10
# >>> 16 38 10
# >>> 16 39 10
# >>> 16 40 10
# >>> 16 41 10
# >>> 16 42 10
# >>> 16 43 10
# >>> 16 44 10
# >>> 16 45 10
# >>> 16 46 10
# >>> 16 47 10
# >>> 16 48 10
# >>> 16 49 10
# >>> 17 5 10
# >>> 17 6 10
# >>> 17 7 10
# >>> 17 8 10
# >>> 17 9 10
# >>> 17 10 10
# >>> 17 11 10
# >>> 17 12 10
# >>> 17 13 10
# >>> 17 14 10
# >>> 17 15 10
# >>> 17 16 10
# >>> 17 17 10
# >>> 17 18 10
# >>> 17 19 10
# >>> 17 20 10
# >>> 17 21 10
# >>> 17 22 10
# >>> 17 23 10
# >>> 17 24 10
# >>> 17 25 10
# >>> 17 26 10
# >>> 17 27 10
# >>> 17 28 10
# >>> 17 29 10
# >>> 17 30 10
# >>> 17 31 10
# >>> 17 32 10
# >>> 17 33 10
# >>> 17 34 10
# >>> 17 35 10
# >>> 17 36 10
# >>> 17 37 10
# >>> 17 38 10
# >>> 17 39 10
# >>> 17 40 10
# >>> 17 41 10
# >>> 17 42 10
# >>> 17 43 10
# >>> 17 44 10
# >>> 17 45 10
# >>> 17 46 10
# >>> 17 47 10
# >>> 17 48 10
# >>> 17 49 10
# >>> 18 5 10
# >>> 18 6 10
# >>> 18 7 10
# >>> 18 8 10
# >>> 18 9 10
# >>> 18 10 10
# >>> 18 11 10
# >>> 18 12 10
# >>> 18 13 10
# >>> 18 14 10
# >>> 18 15 10
# >>> 18 16 10
# >>> 18 17 10
# >>> 18 18 10
# >>> 18 19 10
# >>> 18 20 10
# >>> 18 21 10
# >>> 18 22 10
# >>> 18 23 10
# >>> 18 24 10
# >>> 18 25 10
# >>> 18 26 10
# >>> 18 27 10
# >>> 18 28 10
# >>> 18 29 10
# >>> 18 30 10
# >>> 18 31 10
# >>> 18 32 10
# >>> 18 33 10
# >>> 18 34 10
# >>> 18 35 10
# >>> 18 36 10
# >>> 18 37 10
# >>> 18 38 10
# >>> 18 39 10
# >>> 18 40 10
# >>> 18 41 10
# >>> 18 42 10
# >>> 18 43 10
# >>> 18 44 10
# >>> 18 45 10
# >>> 18 46 10
# >>> 18 47 10
# >>> 18 48 10
# >>> 18 49 10
# >>> 19 5 10
# >>> 19 6 10
# >>> 19 7 10
# >>> 19 8 10
# >>> 19 9 10
# >>> 19 10 10
# >>> 19 11 10
# >>> 19 12 10
# >>> 19 13 10
# >>> 19 14 10
# >>> 19 15 10
# >>> 19 16 10
# >>> 19 17 10
# >>> 19 18 10
# >>> 19 19 10
# >>> 19 20 10
# >>> 19 21 10
# >>> 19 22 10
# >>> 19 23 10
# >>> 19 24 10
# >>> 19 25 10
# >>> 19 26 10
# >>> 19 27 10
# >>> 19 28 10
# >>> 19 29 10
# >>> 19 30 10
# >>> 19 31 10
# >>> 19 32 10
# >>> 19 33 10
# >>> 19 34 10
# >>> 19 35 10
# >>> 19 36 10
# >>> 19 37 10
# >>> 19 38 10
# >>> 19 39 10
# >>> 19 40 10
# >>> 19 41 10
# >>> 19 42 10
# >>> 19 43 10
# >>> 19 44 10
# >>> 19 45 10
# >>> 19 46 10
# >>> 19 47 10
# >>> 19 48 10
# >>> 19 49 10
# >>> 20 5 10
# >>> 20 6 10
# >>> 20 7 10
# >>> 20 8 10
# >>> 20 9 10
# >>> 20 10 10
# >>> 20 11 10
# >>> 20 12 10
# >>> 20 13 10
# >>> 20 14 10
# >>> 20 15 10
# >>> 20 16 10
# >>> 20 17 10
# >>> 20 18 10
# >>> 20 19 10
# >>> 20 20 10
# >>> 20 21 10
# >>> 20 22 10
# >>> 20 23 10
# >>> 20 24 10
# >>> 20 25 10
# >>> 20 26 10
# >>> 20 27 10
# >>> 20 28 10
# >>> 20 29 10
# >>> 20 30 10
# >>> 20 31 10
# >>> 20 32 10
# >>> 20 33 10
# >>> 20 34 10
# >>> 20 35 10
# >>> 20 36 10
# >>> 20 37 10
# >>> 20 38 10
# >>> 20 39 10
# >>> 20 40 10
# >>> 20 41 10
# >>> 20 42 10
# >>> 20 43 10
# >>> 20 44 10
# >>> 20 45 10
# >>> 20 46 10
# >>> 20 47 10
# >>> 20 48 10
# >>> 20 49 10
# >>> 21 5 10
# >>> 21 6 10
# >>> 21 7 10
# >>> 21 8 10
# >>> 21 9 10
# >>> 21 10 10
# >>> 21 11 10
# >>> 21 12 10
# >>> 21 13 10
# >>> 21 14 10
# >>> 21 15 10
# >>> 21 16 10
# >>> 21 17 10
# >>> 21 18 10
# >>> 21 19 10
# >>> 21 20 10
# >>> 21 21 10
# >>> 21 22 10
# >>> 21 23 10
# >>> 21 24 10
# >>> 21 25 10
# >>> 21 26 10
# >>> 21 27 10
# >>> 21 28 10
# >>> 21 29 10
# >>> 21 30 10
# >>> 21 31 10
# >>> 21 32 10
# >>> 21 33 10
# >>> 21 34 10
# >>> 21 35 10
# >>> 21 36 10
# >>> 21 37 10
# >>> 21 38 10
# >>> 21 39 10
# >>> 21 40 10
# >>> 21 41 10
# >>> 21 42 10
# >>> 21 43 10
# >>> 21 44 10
# >>> 21 45 10
# >>> 21 46 10
# >>> 21 47 10
# >>> 21 48 10
# >>> 21 49 10
# >>> 22 5 10
# >>> 22 6 10
# >>> 22 7 10
# >>> 22 8 10
# >>> 22 9 10
# >>> 22 10 10
# >>> 22 11 10
# >>> 22 12 10
# >>> 22 13 10
# >>> 22 14 10
# >>> 22 15 10
# >>> 22 16 10
# >>> 22 17 10
# >>> 22 18 10
# >>> 22 19 10
# >>> 22 20 10
# >>> 22 21 10
# >>> 22 22 10
# >>> 22 23 10
# >>> 22 24 10
# >>> 22 25 10
# >>> 22 26 10
# >>> 22 27 10
# >>> 22 28 10
# >>> 22 29 10
# >>> 22 30 10
# >>> 22 31 10
# >>> 22 32 10
# >>> 22 33 10
# >>> 22 34 10
# >>> 22 35 10
# >>> 22 36 10
# >>> 22 37 10
# >>> 22 38 10
# >>> 22 39 10
# >>> 22 40 10
# >>> 22 41 10
# >>> 22 42 10
# >>> 22 43 10
# >>> 22 44 10
# >>> 22 45 10
# >>> 22 46 10
# >>> 22 47 10
# >>> 22 48 10
# >>> 22 49 10
# >>> 23 5 10
# >>> 23 6 10
# >>> 23 7 10
# >>> 23 8 10
# >>> 23 9 10
# >>> 23 10 10
# >>> 23 11 10
# >>> 23 12 10
# >>> 23 13 10
# >>> 23 14 10
# >>> 23 15 10
# >>> 23 16 10
# >>> 23 17 10
# >>> 23 18 10
# >>> 23 19 10
# >>> 23 20 10
# >>> 23 21 10
# >>> 23 22 10
# >>> 23 23 10
# >>> 23 24 10
# >>> 23 25 10
# >>> 23 26 10
# >>> 23 27 10
# >>> 23 28 10
# >>> 23 29 10
# >>> 23 30 10
# >>> 23 31 10
# >>> 23 32 10
# >>> 23 33 10
# >>> 23 34 10
# >>> 23 35 10
# >>> 23 36 10
# >>> 23 37 10
# >>> 23 38 10
# >>> 23 39 10
# >>> 23 40 10
# >>> 23 41 10
# >>> 23 42 10
# >>> 23 43 10
# >>> 23 44 10
# >>> 23 45 10
# >>> 23 46 10
# >>> 23 47 10
# >>> 23 48 10
# >>> 23 49 10
# >>> 24 5 10
# >>> 24 6 10
# >>> 24 7 10
# >>> 24 8 10
# >>> 24 9 10
# >>> 24 10 10
# >>> 24 11 10
# >>> 24 12 10
# >>> 24 13 10
# >>> 24 14 10
# >>> 24 15 10
# >>> 24 16 10
# >>> 24 17 10
# >>> 24 18 10
# >>> 24 19 10
# >>> 24 20 10
# >>> 24 21 10
# >>> 24 22 10
# >>> 24 23 10
# >>> 24 24 10
# >>> 24 25 10
# >>> 24 26 10
# >>> 24 27 10
# >>> 24 28 10
# >>> 24 29 10
# >>> 24 30 10
# >>> 24 31 10
# >>> 24 32 10
# >>> 24 33 10
# >>> 24 34 10
# >>> 24 35 10
# >>> 24 36 10
# >>> 24 37 10
# >>> 24 38 10
# >>> 24 39 10
# >>> 24 40 10
# >>> 24 41 10
# >>> 24 42 10
# >>> 24 43 10
# >>> 24 44 10
# >>> 24 45 10
# >>> 24 46 10
# >>> 24 47 10
# >>> 24 48 10
# >>> 24 49 10
# >>> 25 5 10
# >>> 25 6 10
# >>> 25 7 10
# >>> 25 8 10
# >>> 25 9 10
# >>> 25 10 10
# >>> 25 11 10
# >>> 25 12 10
# >>> 25 13 10
# KeyboardInterrupt

# %%
np.sum(cf_matrix)
# Out:
# 339

# %%
## Define the confusion matrix values
false_false = 107
false_true = 57
true_false = 53
true_true = 121

# Create the confusion matrix
cf_matrix = np.array([[false_false, false_true], [true_false, true_true]])

# Calculate row-wise proportions
row_sums = cf_matrix.sum(axis=1)
row_percents = cf_matrix / row_sums[:, np.newaxis]

# Plot the confusion matrix using seaborn heatmap
sns.heatmap(row_percents, annot=True, cmap='Blues', fmt='.2%', cbar=False)

# calculate True Positive Rate (TPR) or Sensitivity
print(TPR, cf_matrix[0][0], cf_matrix[1][0])
TPR = cf_matrix[0][0] / (cf_matrix[0][0] + cf_matrix[1][0])
print('True Positive Rate (TPR) or Sensitivity:', TPR)

# calculate False Positive Rate (FPR)
FPR = cf_matrix[0][1] / (cf_matrix[0][1] + cf_matrix[1][1])
print('False Positive Rate (FPR):', FPR)
# Add axis labels and title
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('')
plt.xticks([0.5, 1.5], ['Healthy', 'Non-Healthy'])
plt.yticks([0.5, 1.5], ['Healthy', 'Non-Healthy'])
plt.show()
# Out:
# 0.66875 107 53
# True Positive Rate (TPR) or Sensitivity: 0.66875
# False Positive Rate (FPR): 0.3202247191011236

# %%
ther = 10, Number of Events: 10 Threshold for AHI: 14

# %%
# dic = dic2


best = -100
ee = 338

ss = 999999
eee = .33

import numpy as np


for num_1 in [10]:
    for event_base in [10]:
        for AHI_base in [14]:
    #     for AHI_base in [15]:
            print(">>>", event_base, AHI_base)
            for num_1 in [10]:
                prob = [] 
    #             print(num_1)
            # on the training set the num_1 value is 6 or 7 in average
            # for num_1 in w:
                pred_label_fused = []
                for i in range(338):

            # max vote approach ################################################################
                    fused_label = []
                    for j in range(len(dic)):
                        fused_label.append(dic[j][i])

                    if sum(fused_label) > num_1:
                        pred_label_fused.append(1)
                    else:
                        pred_label_fused.append(0)

                    prob.append(sum(fused_label)/len(fused_label))


                from sklearn.metrics import confusion_matrix
                import matplotlib.pyplot as plt
                from sklearn.metrics import roc_curve, auc,roc_auc_score
                import seaborn as sns


                actual_label = []
                # CUMSUM[0] starting from second data in all data(train+test)
                for i in range(0, len(CUMSUM)-2):
                    actual_label.append(int(sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))


                actual_label = actual_label[-ee:]
                pred_label_fused = pred_label_fused[-ee:]

            #     print(len(actual_label), len(pred_label_fused))


                ###event base #############################################################################
                tempp_consider = np.where(np.array(tempp) > event_base, 1, 0)    
                #### AHI > THER ###########################################################################
                filtered_df = df[(df["ahi_a0h3a"] >= AHI_base) & (df["htnderv_s1"] == 0) & (df["htnderv_s2"].notnull())]
                selected_basedonAHI = [str(x[0]) for x in filtered_df[["nsrrid"]].values]
                AHI_considered = []
                for patient in file_nn:
                    if patient[6:-7] in selected_basedonAHI:
                        AHI_considered.append(1)
                    else:
                        AHI_considered.append(0)
                AHI_considered = np.array(AHI_considered)
                ################################################################################
                final_consider = tempp_consider&AHI_considered

                ## update ################################################################################
                Consider = [np.array(final_consider)==1][0]
                Consider = np.array(Consider[1:-1])
                Consider = Consider[-ee:]

                # update
                actual_label = np.array(actual_label)[Consider]
                pred_label_fused = np.array(pred_label_fused)[Consider]

    #             print(len(actual_label), len(pred_label_fused))


                cf1 = confusion_matrix(actual_label[int(eee*len(actual_label)):338], pred_label_fused[int(eee*len(actual_label)):338])

                lenn = len(pred_label_fused[int(eee*len(actual_label)):338])

                if best < (cf1[0][0] + cf1[1][1]) / lenn:
                    best_pred = pred_label_fused
                    best = (cf1[0][0] + cf1[1][1]) / lenn
                    print((cf1[0][0] + cf1[1][1]) / lenn, "num_1", num_1)
                    ax = sns.heatmap(cf1, annot=True, cmap='Blues' , fmt=".1f")
                    ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                    ax.set_xlabel('\nPredicted Values')
                    ax.set_ylabel('Actual Values ')
                    ## Ticket labels - List must be in alphabetical order
                    ax.xaxis.set_ticklabels(['False','True'])
                    ax.yaxis.set_ticklabels(['False','True'])

                    #############################################
                    # calculate True Positive Rate (TPR) or Sensitivity
                    TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
                    print('True Positive Rate (TPR) or Sensitivity:', TPR)

                    # calculate False Positive Rate (FPR)
                    FPR = cf1[0][1] / (cf1[0][1] + cf1[1][1])
                    print('False Positive Rate (FPR):', FPR)

                    #################################################
                    print(f"Accuracy: {best*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                    plt.show()
# Out:
# >>> 10 14
# 0.6434782608695652 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.75
# False Positive Rate (FPR): 0.41333333333333333
# Accuracy: 64.35 Threshold for Number of Events: 10 Threshold for AHI: 14 lenght of data 171

# %%
# dic = dic2
from sklearn.model_selection import train_test_split

best = -100
ee = 338

ss = 0
eee = 338

import numpy as np

for event_base in np.arange(10,50):
    for AHI_base in np.arange(5,15):        
        for num_1 in range(len(dic)):
            
            print(">>>", event_base, AHI_base, num_1)
            prob = [] 
#             print(num_1)
        # on the training set the num_1 value is 6 or 7 in average
        # for num_1 in w:
            pred_label_fused = []
            for i in range(338):

        # max vote approach ################################################################
                fused_label = []
                for j in range(len(dic)):
                    fused_label.append(dic[j][i])

                if sum(fused_label) > num_1:
                    pred_label_fused.append(1)
                else:
                    pred_label_fused.append(0)

                prob.append(sum(fused_label)/len(fused_label))


            from sklearn.metrics import confusion_matrix
            import matplotlib.pyplot as plt
            from sklearn.metrics import roc_curve, auc,roc_auc_score
            import seaborn as sns


            actual_label = []
            # CUMSUM[0] starting from second data in all data(train+test)
            for i in range(0, len(CUMSUM)-2):
                actual_label.append(int(sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))


            actual_label = actual_label[-ee:]
            pred_label_fused = pred_label_fused[-ee:]

        #     print(len(actual_label), len(pred_label_fused))


            ###event base #############################################################################
            tempp_consider = np.where(np.array(tempp) > event_base, 1, 0)    
            #### AHI > THER ###########################################################################
            filtered_df = df[(df["ahi_a0h3a"] >= AHI_base) & (df["htnderv_s1"] == 0) & (df["htnderv_s2"].notnull())]
            selected_basedonAHI = [str(x[0]) for x in filtered_df[["nsrrid"]].values]
            AHI_considered = []
            for patient in file_nn:
                if patient[6:-7] in selected_basedonAHI:
                    AHI_considered.append(1)
                else:
                    AHI_considered.append(0)
            AHI_considered = np.array(AHI_considered)
            ################################################################################
            final_consider = tempp_consider&AHI_considered

            ## update ################################################################################
            Consider = [np.array(final_consider)==1][0]
            Consider = np.array(Consider[1:-1])
            Consider = Consider[-ee:]

            # update
            actual_label = np.array(actual_label)[Consider]
            pred_label_fused = np.array(pred_label_fused)[Consider]

#             print(len(actual_label), len(pred_label_fused))


            

            X_train, X_test, y_train, y_test = train_test_split(actual_label, pred_label_fused, test_size=0.7, random_state=42)
    
    
            cf1 = confusion_matrix(X_train, y_train)
            cf1_test = confusion_matrix(X_test, y_test)
    
            lenn = len(y_train)
            lenn_test = len(y_test)

            if best < (cf1[0][0] + cf1[1][1]) / lenn:
                
                # train
                best_pred = pred_label_fused
                best = (cf1[0][0] + cf1[1][1]) / lenn
                print((cf1[0][0] + cf1[1][1]) / lenn, "num_1", num_1)
                ax = sns.heatmap(cf1, annot=True, cmap='Blues' , fmt=".1f")
                ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                ax.set_xlabel('\nPredicted Values')
                ax.set_ylabel('Actual Values ')
                ## Ticket labels - List must be in alphabetical order
                ax.xaxis.set_ticklabels(['False','True'])
                ax.yaxis.set_ticklabels(['False','True'])

                #############################################
                # calculate True Positive Rate (TPR) or Sensitivity
                TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
                print('True Positive Rate (TPR) or Sensitivity:', TPR)

                # calculate False Positive Rate (FPR)
                FPR = cf1[0][1] / (cf1[0][1] + cf1[1][1])
                print('False Positive Rate (FPR):', FPR)

                #################################################
#                 print(f"Accuracy: {best*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                plt.show()
                # Test #########################################3
                
                best_test = (cf1_test[0][0] + cf1_test[1][1]) / lenn_test
                
                ax = sns.heatmap(cf1_test, annot=True, cmap='Oranges' , fmt=".1f")
                ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                ax.set_xlabel('\nPredicted Values')
                ax.set_ylabel('Actual Values ')
                ## Ticket labels - List must be in alphabetical order
                ax.xaxis.set_ticklabels(['False','True'])
                ax.yaxis.set_ticklabels(['False','True'])

                #############################################
                # calculate True Positive Rate (TPR) or Sensitivity
                TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
                print('True Positive Rate (TPR) or Sensitivity:', TPR)

                # calculate False Positive Rate (FPR)
                FPR = cf1_test[0][1] / (cf1_test[0][1] + cf1_test[1][1])
                print('False Positive Rate (FPR):', FPR)

                #################################################
                print(f"Accuracy train: {best*100:.2f}", f"Accuracy test: {best_test*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                plt.show()
# Out:
# >>> 10 5 0
# 0.4752475247524752 num_1 0
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.5247524752475248
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_22108\1220466010.py:111: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.46835443037974683
# Accuracy train: 47.52 Accuracy test: 53.16 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_22108\1220466010.py:135: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
# >>> 10 5 1
# >>> 10 5 2
# 0.504950495049505 num_1 2
# True Positive Rate (TPR) or Sensitivity: 1.0
# False Positive Rate (FPR): 0.5102040816326531
# True Positive Rate (TPR) or Sensitivity: 0.6666666666666666
# False Positive Rate (FPR): 0.4658119658119658
# Accuracy train: 50.50 Accuracy test: 53.59 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 3
# >>> 10 5 4
# >>> 10 5 5
# 0.5544554455445545 num_1 5
# True Positive Rate (TPR) or Sensitivity: 0.8333333333333334
# False Positive Rate (FPR): 0.48314606741573035
# True Positive Rate (TPR) or Sensitivity: 0.6176470588235294
# False Positive Rate (FPR): 0.4433497536945813
# Accuracy train: 55.45 Accuracy test: 56.54 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 6
# 0.5643564356435643 num_1 6
# True Positive Rate (TPR) or Sensitivity: 0.7647058823529411
# False Positive Rate (FPR): 0.47619047619047616
# True Positive Rate (TPR) or Sensitivity: 0.5660377358490566
# False Positive Rate (FPR): 0.44021739130434784
# Accuracy train: 56.44 Accuracy test: 56.12 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 7
# 0.594059405940594 num_1 7
# True Positive Rate (TPR) or Sensitivity: 0.8
# False Positive Rate (FPR): 0.4567901234567901
# True Positive Rate (TPR) or Sensitivity: 0.5441176470588235
# False Positive Rate (FPR): 0.4378698224852071
# Accuracy train: 59.41 Accuracy test: 55.70 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 8
# 0.6336633663366337 num_1 8
# True Positive Rate (TPR) or Sensitivity: 0.8076923076923077
# False Positive Rate (FPR): 0.4266666666666667
# True Positive Rate (TPR) or Sensitivity: 0.5662650602409639
# False Positive Rate (FPR): 0.4155844155844156
# Accuracy train: 63.37 Accuracy test: 57.81 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 9
# 0.6831683168316832 num_1 9
# True Positive Rate (TPR) or Sensitivity: 0.8
# False Positive Rate (FPR): 0.3787878787878788
# True Positive Rate (TPR) or Sensitivity: 0.5876288659793815
# False Positive Rate (FPR): 0.38571428571428573
# Accuracy train: 68.32 Accuracy test: 60.34 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 10
# 0.7227722772277227 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7906976744186046
# False Positive Rate (FPR): 0.3275862068965517
# True Positive Rate (TPR) or Sensitivity: 0.6239316239316239
# False Positive Rate (FPR): 0.31666666666666665
# Accuracy train: 72.28 Accuracy test: 65.40 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 11
# >>> 10 5 12
# >>> 10 5 13
# >>> 10 5 14
# >>> 10 5 15
# >>> 10 5 16
# >>> 10 5 17
# >>> 10 5 18
# >>> 10 5 19
# >>> 10 5 20
# >>> 10 5 21
# >>> 10 5 22
# >>> 10 6 0
# >>> 10 6 1
# >>> 10 6 2
# >>> 10 6 3
# >>> 10 6 4
# >>> 10 6 5
# >>> 10 6 6
# >>> 10 6 7
# >>> 10 6 8
# >>> 10 6 9
# >>> 10 6 10
# 0.7311827956989247 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.723404255319149
# False Positive Rate (FPR): 0.2608695652173913
# True Positive Rate (TPR) or Sensitivity: 0.65625
# False Positive Rate (FPR): 0.33064516129032256
# Accuracy train: 73.12 Accuracy test: 66.36 Threshold for Number of Events: 10 Threshold for AHI: 6 lenght of data 313
# >>> 10 6 11
# >>> 10 6 12
# >>> 10 6 13
# >>> 10 6 14
# >>> 10 6 15
# >>> 10 6 16
# >>> 10 6 17
# >>> 10 6 18
# >>> 10 6 19
# >>> 10 6 20
# >>> 10 6 21
# >>> 10 6 22
# >>> 10 7 0
# >>> 10 7 1
# >>> 10 7 2
# >>> 10 7 3
# >>> 10 7 4
# >>> 10 7 5
# >>> 10 7 6
# >>> 10 7 7
# >>> 10 7 8
# >>> 10 7 9
# >>> 10 7 10
# >>> 10 7 11
# >>> 10 7 12
# >>> 10 7 13
# >>> 10 7 14
# >>> 10 7 15
# >>> 10 7 16
# >>> 10 7 17
# >>> 10 7 18
# >>> 10 7 19
# >>> 10 7 20
# >>> 10 7 21
# >>> 10 7 22
# >>> 10 8 0
# >>> 10 8 1
# >>> 10 8 2
# >>> 10 8 3
# >>> 10 8 4
# >>> 10 8 5
# >>> 10 8 6
# >>> 10 8 7
# >>> 10 8 8
# >>> 10 8 9
# 0.7682926829268293 num_1 9
# True Positive Rate (TPR) or Sensitivity: 0.8205128205128205
# False Positive Rate (FPR): 0.27906976744186046
# True Positive Rate (TPR) or Sensitivity: 0.603448275862069
# False Positive Rate (FPR): 0.43703703703703706
# Accuracy train: 76.83 Accuracy test: 57.51 Threshold for Number of Events: 10 Threshold for AHI: 8 lenght of data 275
# >>> 10 8 10
# >>> 10 8 11
# >>> 10 8 12
# >>> 10 8 13
# >>> 10 8 14
# >>> 10 8 15
# >>> 10 8 16
# >>> 10 8 17
# >>> 10 8 18
# >>> 10 8 19
# >>> 10 8 20
# >>> 10 8 21
# >>> 10 8 22
# >>> 10 9 0
# >>> 10 9 1
# >>> 10 9 2
# >>> 10 9 3
# >>> 10 9 4
# >>> 10 9 5
# >>> 10 9 6
# >>> 10 9 7
# >>> 10 9 8
# >>> 10 9 9
# >>> 10 9 10
# >>> 10 9 11
# >>> 10 9 12
# >>> 10 9 13
# >>> 10 9 14
# >>> 10 9 15
# >>> 10 9 16
# >>> 10 9 17
# >>> 10 9 18
# >>> 10 9 19
# >>> 10 9 20
# >>> 10 9 21
# >>> 10 9 22
# >>> 10 10 0
# >>> 10 10 1
# >>> 10 10 2
# >>> 10 10 3
# >>> 10 10 4
# >>> 10 10 5
# >>> 10 10 6
# >>> 10 10 7
# >>> 10 10 8
# >>> 10 10 9
# >>> 10 10 10
# >>> 10 10 11
# >>> 10 10 12
# >>> 10 10 13
# >>> 10 10 14
# >>> 10 10 15
# >>> 10 10 16
# >>> 10 10 17
# >>> 10 10 18
# >>> 10 10 19
# >>> 10 10 20
# >>> 10 10 21
# >>> 10 10 22
# >>> 10 11 0
# >>> 10 11 1
# >>> 10 11 2
# >>> 10 11 3
# >>> 10 11 4
# >>> 10 11 5
# >>> 10 11 6
# >>> 10 11 7
# >>> 10 11 8
# >>> 10 11 9
# >>> 10 11 10
# >>> 10 11 11
# >>> 10 11 12
# >>> 10 11 13
# >>> 10 11 14
# >>> 10 11 15
# >>> 10 11 16
# >>> 10 11 17
# >>> 10 11 18
# >>> 10 11 19
# >>> 10 11 20
# >>> 10 11 21
# >>> 10 11 22
# >>> 10 12 0
# >>> 10 12 1
# >>> 10 12 2
# >>> 10 12 3
# >>> 10 12 4
# >>> 10 12 5
# >>> 10 12 6
# >>> 10 12 7
# >>> 10 12 8
# >>> 10 12 9
# >>> 10 12 10
# >>> 10 12 11
# >>> 10 12 12
# >>> 10 12 13
# >>> 10 12 14
# >>> 10 12 15
# >>> 10 12 16
# >>> 10 12 17
# >>> 10 12 18
# >>> 10 12 19
# >>> 10 12 20
# >>> 10 12 21
# >>> 10 12 22
# >>> 10 13 0
# >>> 10 13 1
# >>> 10 13 2
# >>> 10 13 3
# >>> 10 13 4
# >>> 10 13 5
# >>> 10 13 6
# >>> 10 13 7
# >>> 10 13 8
# >>> 10 13 9
# >>> 10 13 10
# >>> 10 13 11
# >>> 10 13 12
# >>> 10 13 13
# >>> 10 13 14
# >>> 10 13 15
# >>> 10 13 16
# >>> 10 13 17
# >>> 10 13 18
# >>> 10 13 19
# >>> 10 13 20
# >>> 10 13 21
# >>> 10 13 22
# >>> 10 14 0
# >>> 10 14 1
# >>> 10 14 2
# >>> 10 14 3
# >>> 10 14 4
# >>> 10 14 5
# >>> 10 14 6
# >>> 10 14 7
# >>> 10 14 8
# >>> 10 14 9
# >>> 10 14 10
# >>> 10 14 11
# >>> 10 14 12
# >>> 10 14 13
# >>> 10 14 14
# >>> 10 14 15
# >>> 10 14 16
# >>> 10 14 17
# >>> 10 14 18
# >>> 10 14 19
# >>> 10 14 20
# >>> 10 14 21
# >>> 10 14 22
# >>> 11 5 0
# >>> 11 5 1
# >>> 11 5 2
# >>> 11 5 3
# >>> 11 5 4
# >>> 11 5 5
# >>> 11 5 6
# >>> 11 5 7
# >>> 11 5 8
# >>> 11 5 9
# >>> 11 5 10
# >>> 11 5 11
# >>> 11 5 12
# >>> 11 5 13
# >>> 11 5 14
# >>> 11 5 15
# >>> 11 5 16
# >>> 11 5 17
# >>> 11 5 18
# >>> 11 5 19
# >>> 11 5 20
# >>> 11 5 21
# >>> 11 5 22
# >>> 11 6 0
# >>> 11 6 1
# >>> 11 6 2
# >>> 11 6 3
# >>> 11 6 4
# >>> 11 6 5
# >>> 11 6 6
# >>> 11 6 7
# >>> 11 6 8
# >>> 11 6 9
# >>> 11 6 10
# >>> 11 6 11
# >>> 11 6 12
# >>> 11 6 13
# >>> 11 6 14
# >>> 11 6 15
# >>> 11 6 16
# >>> 11 6 17
# >>> 11 6 18
# >>> 11 6 19
# >>> 11 6 20
# >>> 11 6 21
# >>> 11 6 22
# >>> 11 7 0
# >>> 11 7 1
# >>> 11 7 2
# >>> 11 7 3
# >>> 11 7 4
# >>> 11 7 5
# >>> 11 7 6
# >>> 11 7 7
# >>> 11 7 8
# >>> 11 7 9
# >>> 11 7 10
# >>> 11 7 11
# >>> 11 7 12
# >>> 11 7 13
# >>> 11 7 14
# >>> 11 7 15
# >>> 11 7 16
# >>> 11 7 17
# >>> 11 7 18
# >>> 11 7 19
# >>> 11 7 20
# >>> 11 7 21
# >>> 11 7 22
# >>> 11 8 0
# >>> 11 8 1
# >>> 11 8 2
# >>> 11 8 3
# >>> 11 8 4
# >>> 11 8 5
# >>> 11 8 6
# >>> 11 8 7
# >>> 11 8 8
# >>> 11 8 9
# >>> 11 8 10
# >>> 11 8 11
# >>> 11 8 12
# >>> 11 8 13
# >>> 11 8 14
# >>> 11 8 15
# >>> 11 8 16
# >>> 11 8 17
# >>> 11 8 18
# >>> 11 8 19
# >>> 11 8 20
# >>> 11 8 21
# >>> 11 8 22
# >>> 11 9 0
# >>> 11 9 1
# >>> 11 9 2
# >>> 11 9 3
# >>> 11 9 4
# >>> 11 9 5
# >>> 11 9 6
# >>> 11 9 7
# >>> 11 9 8
# >>> 11 9 9
# >>> 11 9 10
# >>> 11 9 11
# >>> 11 9 12
# >>> 11 9 13
# >>> 11 9 14
# >>> 11 9 15
# >>> 11 9 16
# >>> 11 9 17
# >>> 11 9 18
# >>> 11 9 19
# >>> 11 9 20
# >>> 11 9 21
# >>> 11 9 22
# >>> 11 10 0
# >>> 11 10 1
# >>> 11 10 2
# >>> 11 10 3
# >>> 11 10 4
# >>> 11 10 5
# >>> 11 10 6
# >>> 11 10 7
# >>> 11 10 8
# >>> 11 10 9
# >>> 11 10 10
# >>> 11 10 11
# >>> 11 10 12
# >>> 11 10 13
# >>> 11 10 14
# >>> 11 10 15
# >>> 11 10 16
# >>> 11 10 17
# >>> 11 10 18
# >>> 11 10 19
# >>> 11 10 20
# >>> 11 10 21
# >>> 11 10 22
# >>> 11 11 0
# >>> 11 11 1
# >>> 11 11 2
# >>> 11 11 3
# >>> 11 11 4
# >>> 11 11 5
# >>> 11 11 6
# >>> 11 11 7
# >>> 11 11 8
# >>> 11 11 9
# >>> 11 11 10
# >>> 11 11 11
# >>> 11 11 12
# >>> 11 11 13
# >>> 11 11 14
# >>> 11 11 15
# >>> 11 11 16
# >>> 11 11 17
# >>> 11 11 18
# >>> 11 11 19
# >>> 11 11 20
# >>> 11 11 21
# >>> 11 11 22
# >>> 11 12 0
# >>> 11 12 1
# >>> 11 12 2
# >>> 11 12 3
# >>> 11 12 4
# >>> 11 12 5
# >>> 11 12 6
# >>> 11 12 7
# >>> 11 12 8
# >>> 11 12 9
# >>> 11 12 10
# >>> 11 12 11
# >>> 11 12 12
# >>> 11 12 13
# >>> 11 12 14
# >>> 11 12 15
# >>> 11 12 16
# >>> 11 12 17
# >>> 11 12 18
# >>> 11 12 19
# >>> 11 12 20
# >>> 11 12 21
# >>> 11 12 22
# >>> 11 13 0
# >>> 11 13 1
# >>> 11 13 2
# >>> 11 13 3
# >>> 11 13 4
# >>> 11 13 5
# >>> 11 13 6
# >>> 11 13 7
# >>> 11 13 8
# >>> 11 13 9
# >>> 11 13 10
# >>> 11 13 11
# >>> 11 13 12
# >>> 11 13 13
# >>> 11 13 14
# >>> 11 13 15
# >>> 11 13 16
# >>> 11 13 17
# >>> 11 13 18
# >>> 11 13 19
# >>> 11 13 20
# >>> 11 13 21
# >>> 11 13 22
# >>> 11 14 0
# >>> 11 14 1
# >>> 11 14 2
# >>> 11 14 3
# >>> 11 14 4
# >>> 11 14 5
# >>> 11 14 6
# >>> 11 14 7
# >>> 11 14 8
# >>> 11 14 9
# >>> 11 14 10
# >>> 11 14 11
# >>> 11 14 12
# >>> 11 14 13
# >>> 11 14 14
# >>> 11 14 15
# >>> 11 14 16
# >>> 11 14 17
# >>> 11 14 18
# >>> 11 14 19
# >>> 11 14 20
# >>> 11 14 21
# >>> 11 14 22
# >>> 12 5 0
# >>> 12 5 1
# >>> 12 5 2
# >>> 12 5 3
# >>> 12 5 4
# >>> 12 5 5
# >>> 12 5 6
# >>> 12 5 7
# >>> 12 5 8
# >>> 12 5 9
# >>> 12 5 10
# >>> 12 5 11
# >>> 12 5 12
# >>> 12 5 13
# >>> 12 5 14
# >>> 12 5 15
# >>> 12 5 16
# >>> 12 5 17
# >>> 12 5 18
# >>> 12 5 19
# >>> 12 5 20
# >>> 12 5 21
# >>> 12 5 22
# >>> 12 6 0
# >>> 12 6 1
# >>> 12 6 2
# >>> 12 6 3
# >>> 12 6 4
# >>> 12 6 5
# >>> 12 6 6
# >>> 12 6 7
# >>> 12 6 8
# >>> 12 6 9
# >>> 12 6 10
# >>> 12 6 11
# >>> 12 6 12
# >>> 12 6 13
# >>> 12 6 14
# >>> 12 6 15
# >>> 12 6 16
# >>> 12 6 17
# >>> 12 6 18
# >>> 12 6 19
# >>> 12 6 20
# >>> 12 6 21
# >>> 12 6 22
# >>> 12 7 0
# >>> 12 7 1
# >>> 12 7 2
# >>> 12 7 3
# >>> 12 7 4
# >>> 12 7 5
# >>> 12 7 6
# >>> 12 7 7
# >>> 12 7 8
# >>> 12 7 9
# >>> 12 7 10
# >>> 12 7 11
# >>> 12 7 12
# >>> 12 7 13
# >>> 12 7 14
# >>> 12 7 15
# >>> 12 7 16
# >>> 12 7 17
# >>> 12 7 18
# >>> 12 7 19
# >>> 12 7 20
# >>> 12 7 21
# >>> 12 7 22
# >>> 12 8 0
# >>> 12 8 1
# >>> 12 8 2
# >>> 12 8 3
# >>> 12 8 4
# >>> 12 8 5
# >>> 12 8 6
# >>> 12 8 7
# >>> 12 8 8
# >>> 12 8 9
# >>> 12 8 10
# >>> 12 8 11
# >>> 12 8 12
# >>> 12 8 13
# >>> 12 8 14
# >>> 12 8 15
# >>> 12 8 16
# >>> 12 8 17
# >>> 12 8 18
# >>> 12 8 19
# >>> 12 8 20
# >>> 12 8 21
# >>> 12 8 22
# >>> 12 9 0
# >>> 12 9 1
# >>> 12 9 2
# >>> 12 9 3
# >>> 12 9 4
# >>> 12 9 5
# >>> 12 9 6
# >>> 12 9 7
# >>> 12 9 8
# >>> 12 9 9
# >>> 12 9 10
# >>> 12 9 11
# >>> 12 9 12
# >>> 12 9 13
# >>> 12 9 14
# >>> 12 9 15
# >>> 12 9 16
# >>> 12 9 17
# >>> 12 9 18
# >>> 12 9 19
# >>> 12 9 20
# >>> 12 9 21
# >>> 12 9 22
# >>> 12 10 0
# >>> 12 10 1
# >>> 12 10 2
# >>> 12 10 3
# >>> 12 10 4
# >>> 12 10 5
# >>> 12 10 6
# >>> 12 10 7
# >>> 12 10 8
# >>> 12 10 9
# >>> 12 10 10
# >>> 12 10 11
# >>> 12 10 12
# >>> 12 10 13
# >>> 12 10 14
# >>> 12 10 15
# >>> 12 10 16
# >>> 12 10 17
# >>> 12 10 18
# >>> 12 10 19
# >>> 12 10 20
# >>> 12 10 21
# >>> 12 10 22
# >>> 12 11 0
# >>> 12 11 1
# >>> 12 11 2
# >>> 12 11 3
# >>> 12 11 4
# >>> 12 11 5
# >>> 12 11 6
# >>> 12 11 7
# >>> 12 11 8
# >>> 12 11 9
# >>> 12 11 10
# >>> 12 11 11
# >>> 12 11 12
# >>> 12 11 13
# >>> 12 11 14
# >>> 12 11 15
# >>> 12 11 16
# >>> 12 11 17
# >>> 12 11 18
# >>> 12 11 19
# >>> 12 11 20
# >>> 12 11 21
# >>> 12 11 22
# >>> 12 12 0
# >>> 12 12 1
# >>> 12 12 2
# >>> 12 12 3
# >>> 12 12 4
# >>> 12 12 5
# >>> 12 12 6
# >>> 12 12 7
# >>> 12 12 8
# >>> 12 12 9
# >>> 12 12 10
# >>> 12 12 11
# >>> 12 12 12
# >>> 12 12 13
# >>> 12 12 14
# >>> 12 12 15
# >>> 12 12 16
# >>> 12 12 17
# >>> 12 12 18
# >>> 12 12 19
# >>> 12 12 20
# >>> 12 12 21
# >>> 12 12 22
# >>> 12 13 0
# >>> 12 13 1
# >>> 12 13 2
# >>> 12 13 3
# >>> 12 13 4
# >>> 12 13 5
# >>> 12 13 6
# >>> 12 13 7
# >>> 12 13 8
# >>> 12 13 9
# >>> 12 13 10
# >>> 12 13 11
# >>> 12 13 12
# >>> 12 13 13
# >>> 12 13 14
# >>> 12 13 15
# >>> 12 13 16
# >>> 12 13 17
# >>> 12 13 18
# >>> 12 13 19
# >>> 12 13 20
# >>> 12 13 21
# >>> 12 13 22
# >>> 12 14 0
# >>> 12 14 1
# >>> 12 14 2
# >>> 12 14 3
# >>> 12 14 4
# >>> 12 14 5
# >>> 12 14 6
# >>> 12 14 7
# >>> 12 14 8
# >>> 12 14 9
# >>> 12 14 10
# >>> 12 14 11
# >>> 12 14 12
# >>> 12 14 13
# >>> 12 14 14
# >>> 12 14 15
# >>> 12 14 16
# >>> 12 14 17
# >>> 12 14 18
# >>> 12 14 19
# >>> 12 14 20
# >>> 12 14 21
# >>> 12 14 22
# >>> 13 5 0
# >>> 13 5 1
# >>> 13 5 2
# >>> 13 5 3
# >>> 13 5 4
# >>> 13 5 5
# >>> 13 5 6
# >>> 13 5 7
# >>> 13 5 8
# >>> 13 5 9
# >>> 13 5 10
# >>> 13 5 11
# >>> 13 5 12
# >>> 13 5 13
# >>> 13 5 14
# >>> 13 5 15
# >>> 13 5 16
# >>> 13 5 17
# >>> 13 5 18
# >>> 13 5 19
# >>> 13 5 20
# >>> 13 5 21
# >>> 13 5 22
# >>> 13 6 0
# >>> 13 6 1
# >>> 13 6 2
# >>> 13 6 3
# >>> 13 6 4
# >>> 13 6 5
# >>> 13 6 6
# >>> 13 6 7
# >>> 13 6 8
# >>> 13 6 9
# >>> 13 6 10
# >>> 13 6 11
# >>> 13 6 12
# >>> 13 6 13
# >>> 13 6 14
# >>> 13 6 15
# >>> 13 6 16
# >>> 13 6 17
# >>> 13 6 18
# >>> 13 6 19
# >>> 13 6 20
# >>> 13 6 21
# >>> 13 6 22
# >>> 13 7 0
# >>> 13 7 1
# >>> 13 7 2
# >>> 13 7 3
# >>> 13 7 4
# >>> 13 7 5
# >>> 13 7 6
# >>> 13 7 7
# >>> 13 7 8
# >>> 13 7 9
# >>> 13 7 10
# >>> 13 7 11
# >>> 13 7 12
# >>> 13 7 13
# >>> 13 7 14
# >>> 13 7 15
# >>> 13 7 16
# >>> 13 7 17
# >>> 13 7 18
# >>> 13 7 19
# >>> 13 7 20
# >>> 13 7 21
# >>> 13 7 22
# >>> 13 8 0
# >>> 13 8 1
# >>> 13 8 2
# >>> 13 8 3
# >>> 13 8 4
# >>> 13 8 5
# >>> 13 8 6
# >>> 13 8 7
# >>> 13 8 8
# >>> 13 8 9
# >>> 13 8 10
# >>> 13 8 11
# >>> 13 8 12
# >>> 13 8 13
# >>> 13 8 14
# >>> 13 8 15
# >>> 13 8 16
# >>> 13 8 17
# >>> 13 8 18
# >>> 13 8 19
# >>> 13 8 20
# >>> 13 8 21
# >>> 13 8 22
# >>> 13 9 0
# >>> 13 9 1
# >>> 13 9 2
# >>> 13 9 3
# >>> 13 9 4
# >>> 13 9 5
# >>> 13 9 6
# >>> 13 9 7
# >>> 13 9 8
# >>> 13 9 9
# >>> 13 9 10
# >>> 13 9 11
# >>> 13 9 12
# >>> 13 9 13
# >>> 13 9 14
# >>> 13 9 15
# >>> 13 9 16
# >>> 13 9 17
# >>> 13 9 18
# >>> 13 9 19
# >>> 13 9 20
# >>> 13 9 21
# >>> 13 9 22
# >>> 13 10 0
# >>> 13 10 1
# >>> 13 10 2
# >>> 13 10 3
# >>> 13 10 4
# >>> 13 10 5
# >>> 13 10 6
# >>> 13 10 7
# >>> 13 10 8
# >>> 13 10 9
# >>> 13 10 10
# >>> 13 10 11
# >>> 13 10 12
# >>> 13 10 13
# >>> 13 10 14
# >>> 13 10 15
# >>> 13 10 16
# >>> 13 10 17
# >>> 13 10 18
# >>> 13 10 19
# >>> 13 10 20
# >>> 13 10 21
# >>> 13 10 22
# >>> 13 11 0
# >>> 13 11 1
# >>> 13 11 2
# >>> 13 11 3
# >>> 13 11 4
# >>> 13 11 5
# >>> 13 11 6
# >>> 13 11 7
# >>> 13 11 8
# >>> 13 11 9
# >>> 13 11 10
# >>> 13 11 11
# >>> 13 11 12
# >>> 13 11 13
# >>> 13 11 14
# >>> 13 11 15
# >>> 13 11 16
# >>> 13 11 17
# >>> 13 11 18
# >>> 13 11 19
# >>> 13 11 20
# >>> 13 11 21
# >>> 13 11 22
# >>> 13 12 0
# >>> 13 12 1
# >>> 13 12 2
# >>> 13 12 3
# >>> 13 12 4
# >>> 13 12 5
# >>> 13 12 6
# >>> 13 12 7
# >>> 13 12 8
# >>> 13 12 9
# >>> 13 12 10
# >>> 13 12 11
# >>> 13 12 12
# >>> 13 12 13
# >>> 13 12 14
# >>> 13 12 15
# >>> 13 12 16
# >>> 13 12 17
# >>> 13 12 18
# >>> 13 12 19
# >>> 13 12 20
# >>> 13 12 21
# >>> 13 12 22
# >>> 13 13 0
# >>> 13 13 1
# >>> 13 13 2
# >>> 13 13 3
# >>> 13 13 4
# >>> 13 13 5
# >>> 13 13 6
# >>> 13 13 7
# >>> 13 13 8
# >>> 13 13 9
# >>> 13 13 10
# >>> 13 13 11
# >>> 13 13 12
# >>> 13 13 13
# >>> 13 13 14
# >>> 13 13 15
# >>> 13 13 16
# >>> 13 13 17
# >>> 13 13 18
# >>> 13 13 19
# >>> 13 13 20
# >>> 13 13 21
# >>> 13 13 22
# >>> 13 14 0
# >>> 13 14 1
# >>> 13 14 2
# >>> 13 14 3
# >>> 13 14 4
# >>> 13 14 5
# >>> 13 14 6
# >>> 13 14 7
# >>> 13 14 8
# >>> 13 14 9
# >>> 13 14 10
# >>> 13 14 11
# >>> 13 14 12
# >>> 13 14 13
# >>> 13 14 14
# >>> 13 14 15
# >>> 13 14 16
# >>> 13 14 17
# >>> 13 14 18
# >>> 13 14 19
# >>> 13 14 20
# >>> 13 14 21
# >>> 13 14 22
# >>> 14 5 0
# >>> 14 5 1
# >>> 14 5 2
# >>> 14 5 3
# >>> 14 5 4
# >>> 14 5 5
# >>> 14 5 6
# >>> 14 5 7
# >>> 14 5 8
# >>> 14 5 9
# >>> 14 5 10
# >>> 14 5 11
# >>> 14 5 12
# >>> 14 5 13
# >>> 14 5 14
# >>> 14 5 15
# >>> 14 5 16
# >>> 14 5 17
# >>> 14 5 18
# >>> 14 5 19
# >>> 14 5 20
# >>> 14 5 21
# >>> 14 5 22
# >>> 14 6 0
# >>> 14 6 1
# >>> 14 6 2
# >>> 14 6 3
# >>> 14 6 4
# >>> 14 6 5
# >>> 14 6 6
# >>> 14 6 7
# >>> 14 6 8
# >>> 14 6 9
# >>> 14 6 10
# >>> 14 6 11
# >>> 14 6 12
# >>> 14 6 13
# >>> 14 6 14
# >>> 14 6 15
# >>> 14 6 16
# >>> 14 6 17
# >>> 14 6 18
# >>> 14 6 19
# >>> 14 6 20
# >>> 14 6 21
# >>> 14 6 22
# >>> 14 7 0
# >>> 14 7 1
# >>> 14 7 2
# >>> 14 7 3
# >>> 14 7 4
# >>> 14 7 5
# >>> 14 7 6
# >>> 14 7 7
# >>> 14 7 8
# >>> 14 7 9
# >>> 14 7 10
# >>> 14 7 11
# >>> 14 7 12
# >>> 14 7 13
# >>> 14 7 14
# >>> 14 7 15
# >>> 14 7 16
# >>> 14 7 17
# >>> 14 7 18
# >>> 14 7 19
# >>> 14 7 20
# >>> 14 7 21
# >>> 14 7 22
# >>> 14 8 0
# >>> 14 8 1
# >>> 14 8 2
# >>> 14 8 3
# >>> 14 8 4
# >>> 14 8 5
# >>> 14 8 6
# >>> 14 8 7
# >>> 14 8 8
# >>> 14 8 9
# >>> 14 8 10
# >>> 14 8 11
# >>> 14 8 12
# >>> 14 8 13
# >>> 14 8 14
# >>> 14 8 15
# >>> 14 8 16
# >>> 14 8 17
# >>> 14 8 18
# >>> 14 8 19
# >>> 14 8 20
# >>> 14 8 21
# >>> 14 8 22
# >>> 14 9 0
# >>> 14 9 1
# >>> 14 9 2
# >>> 14 9 3
# >>> 14 9 4
# >>> 14 9 5
# >>> 14 9 6
# >>> 14 9 7
# >>> 14 9 8
# >>> 14 9 9
# >>> 14 9 10
# >>> 14 9 11
# >>> 14 9 12
# >>> 14 9 13
# >>> 14 9 14
# >>> 14 9 15
# >>> 14 9 16
# >>> 14 9 17
# >>> 14 9 18
# >>> 14 9 19
# >>> 14 9 20
# >>> 14 9 21
# >>> 14 9 22
# >>> 14 10 0
# >>> 14 10 1
# >>> 14 10 2
# >>> 14 10 3
# >>> 14 10 4
# >>> 14 10 5
# >>> 14 10 6
# >>> 14 10 7
# >>> 14 10 8
# >>> 14 10 9
# >>> 14 10 10
# >>> 14 10 11
# >>> 14 10 12
# >>> 14 10 13
# >>> 14 10 14
# >>> 14 10 15
# >>> 14 10 16
# >>> 14 10 17
# >>> 14 10 18
# >>> 14 10 19
# >>> 14 10 20
# >>> 14 10 21
# >>> 14 10 22
# >>> 14 11 0
# >>> 14 11 1
# >>> 14 11 2
# >>> 14 11 3
# >>> 14 11 4
# >>> 14 11 5
# >>> 14 11 6
# >>> 14 11 7
# >>> 14 11 8
# >>> 14 11 9
# >>> 14 11 10
# >>> 14 11 11
# >>> 14 11 12
# >>> 14 11 13
# >>> 14 11 14
# >>> 14 11 15
# >>> 14 11 16
# >>> 14 11 17
# >>> 14 11 18
# >>> 14 11 19
# >>> 14 11 20
# >>> 14 11 21
# >>> 14 11 22
# >>> 14 12 0
# >>> 14 12 1
# >>> 14 12 2
# >>> 14 12 3
# >>> 14 12 4
# >>> 14 12 5
# >>> 14 12 6
# >>> 14 12 7
# >>> 14 12 8
# >>> 14 12 9
# >>> 14 12 10
# >>> 14 12 11
# >>> 14 12 12
# >>> 14 12 13
# >>> 14 12 14
# >>> 14 12 15
# >>> 14 12 16
# >>> 14 12 17
# >>> 14 12 18
# >>> 14 12 19
# >>> 14 12 20
# >>> 14 12 21
# >>> 14 12 22
# >>> 14 13 0
# >>> 14 13 1
# >>> 14 13 2
# >>> 14 13 3
# >>> 14 13 4
# >>> 14 13 5
# >>> 14 13 6
# >>> 14 13 7
# >>> 14 13 8
# >>> 14 13 9
# >>> 14 13 10
# >>> 14 13 11
# >>> 14 13 12
# >>> 14 13 13
# >>> 14 13 14
# >>> 14 13 15
# >>> 14 13 16
# >>> 14 13 17
# >>> 14 13 18
# >>> 14 13 19
# >>> 14 13 20
# >>> 14 13 21
# >>> 14 13 22
# >>> 14 14 0
# >>> 14 14 1
# >>> 14 14 2
# >>> 14 14 3
# >>> 14 14 4
# >>> 14 14 5
# >>> 14 14 6
# >>> 14 14 7
# >>> 14 14 8
# >>> 14 14 9
# >>> 14 14 10
# >>> 14 14 11
# >>> 14 14 12
# >>> 14 14 13
# >>> 14 14 14
# >>> 14 14 15
# >>> 14 14 16
# >>> 14 14 17
# >>> 14 14 18
# >>> 14 14 19
# >>> 14 14 20
# >>> 14 14 21
# >>> 14 14 22
# >>> 15 5 0
# >>> 15 5 1
# >>> 15 5 2
# >>> 15 5 3
# >>> 15 5 4
# >>> 15 5 5
# >>> 15 5 6
# >>> 15 5 7
# >>> 15 5 8
# >>> 15 5 9
# >>> 15 5 10
# >>> 15 5 11
# >>> 15 5 12
# >>> 15 5 13
# >>> 15 5 14
# >>> 15 5 15
# >>> 15 5 16
# >>> 15 5 17
# >>> 15 5 18
# >>> 15 5 19
# >>> 15 5 20
# >>> 15 5 21
# >>> 15 5 22
# >>> 15 6 0
# >>> 15 6 1
# >>> 15 6 2
# >>> 15 6 3
# >>> 15 6 4
# >>> 15 6 5
# >>> 15 6 6
# >>> 15 6 7
# >>> 15 6 8
# >>> 15 6 9
# >>> 15 6 10
# >>> 15 6 11
# >>> 15 6 12
# >>> 15 6 13
# >>> 15 6 14
# >>> 15 6 15
# >>> 15 6 16
# >>> 15 6 17
# >>> 15 6 18
# >>> 15 6 19
# >>> 15 6 20
# >>> 15 6 21
# >>> 15 6 22
# >>> 15 7 0
# >>> 15 7 1
# >>> 15 7 2
# >>> 15 7 3
# >>> 15 7 4
# >>> 15 7 5
# >>> 15 7 6
# >>> 15 7 7
# >>> 15 7 8
# >>> 15 7 9
# >>> 15 7 10
# >>> 15 7 11
# >>> 15 7 12
# >>> 15 7 13
# >>> 15 7 14
# >>> 15 7 15
# >>> 15 7 16
# >>> 15 7 17
# >>> 15 7 18
# >>> 15 7 19
# >>> 15 7 20
# >>> 15 7 21
# >>> 15 7 22
# >>> 15 8 0
# >>> 15 8 1
# >>> 15 8 2
# >>> 15 8 3
# >>> 15 8 4
# >>> 15 8 5
# >>> 15 8 6
# >>> 15 8 7
# >>> 15 8 8
# >>> 15 8 9
# >>> 15 8 10
# >>> 15 8 11
# >>> 15 8 12
# >>> 15 8 13
# >>> 15 8 14
# >>> 15 8 15
# >>> 15 8 16
# >>> 15 8 17
# >>> 15 8 18
# >>> 15 8 19
# >>> 15 8 20
# >>> 15 8 21
# >>> 15 8 22
# >>> 15 9 0
# >>> 15 9 1
# >>> 15 9 2
# >>> 15 9 3
# >>> 15 9 4
# >>> 15 9 5
# >>> 15 9 6
# >>> 15 9 7
# >>> 15 9 8
# >>> 15 9 9
# >>> 15 9 10
# >>> 15 9 11
# >>> 15 9 12
# >>> 15 9 13
# >>> 15 9 14
# >>> 15 9 15
# >>> 15 9 16
# >>> 15 9 17
# >>> 15 9 18
# >>> 15 9 19
# >>> 15 9 20
# >>> 15 9 21
# >>> 15 9 22
# >>> 15 10 0
# >>> 15 10 1
# >>> 15 10 2
# >>> 15 10 3
# >>> 15 10 4
# >>> 15 10 5
# >>> 15 10 6
# >>> 15 10 7
# >>> 15 10 8
# >>> 15 10 9
# >>> 15 10 10
# >>> 15 10 11
# >>> 15 10 12
# >>> 15 10 13
# >>> 15 10 14
# >>> 15 10 15
# >>> 15 10 16
# >>> 15 10 17
# >>> 15 10 18
# >>> 15 10 19
# >>> 15 10 20
# >>> 15 10 21
# >>> 15 10 22
# >>> 15 11 0
# >>> 15 11 1
# >>> 15 11 2
# >>> 15 11 3
# >>> 15 11 4
# >>> 15 11 5
# >>> 15 11 6
# >>> 15 11 7
# >>> 15 11 8
# >>> 15 11 9
# >>> 15 11 10
# >>> 15 11 11
# >>> 15 11 12
# >>> 15 11 13
# >>> 15 11 14
# >>> 15 11 15
# >>> 15 11 16
# >>> 15 11 17
# >>> 15 11 18
# >>> 15 11 19
# >>> 15 11 20
# >>> 15 11 21
# >>> 15 11 22
# >>> 15 12 0
# >>> 15 12 1
# >>> 15 12 2
# >>> 15 12 3
# >>> 15 12 4
# >>> 15 12 5
# >>> 15 12 6
# >>> 15 12 7
# >>> 15 12 8
# >>> 15 12 9
# >>> 15 12 10
# >>> 15 12 11
# >>> 15 12 12
# >>> 15 12 13
# >>> 15 12 14
# >>> 15 12 15
# >>> 15 12 16
# >>> 15 12 17
# >>> 15 12 18
# >>> 15 12 19
# >>> 15 12 20
# >>> 15 12 21
# >>> 15 12 22
# >>> 15 13 0
# >>> 15 13 1
# >>> 15 13 2
# >>> 15 13 3
# >>> 15 13 4
# >>> 15 13 5
# >>> 15 13 6
# >>> 15 13 7
# >>> 15 13 8
# >>> 15 13 9
# >>> 15 13 10
# >>> 15 13 11
# >>> 15 13 12
# >>> 15 13 13
# >>> 15 13 14
# >>> 15 13 15
# >>> 15 13 16
# >>> 15 13 17
# >>> 15 13 18
# >>> 15 13 19
# >>> 15 13 20
# >>> 15 13 21
# >>> 15 13 22
# >>> 15 14 0
# >>> 15 14 1
# >>> 15 14 2
# >>> 15 14 3
# >>> 15 14 4
# >>> 15 14 5
# >>> 15 14 6
# >>> 15 14 7
# >>> 15 14 8
# >>> 15 14 9
# >>> 15 14 10
# >>> 15 14 11
# >>> 15 14 12
# >>> 15 14 13
# >>> 15 14 14
# >>> 15 14 15
# >>> 15 14 16
# >>> 15 14 17
# >>> 15 14 18
# >>> 15 14 19
# >>> 15 14 20
# >>> 15 14 21
# >>> 15 14 22
# >>> 16 5 0
# >>> 16 5 1
# >>> 16 5 2
# >>> 16 5 3
# >>> 16 5 4
# >>> 16 5 5
# >>> 16 5 6
# >>> 16 5 7
# >>> 16 5 8
# >>> 16 5 9
# >>> 16 5 10
# >>> 16 5 11
# >>> 16 5 12
# >>> 16 5 13
# >>> 16 5 14
# >>> 16 5 15
# >>> 16 5 16
# >>> 16 5 17
# >>> 16 5 18
# >>> 16 5 19
# >>> 16 5 20
# >>> 16 5 21
# >>> 16 5 22
# >>> 16 6 0
# >>> 16 6 1
# >>> 16 6 2
# >>> 16 6 3
# >>> 16 6 4
# >>> 16 6 5
# >>> 16 6 6
# >>> 16 6 7
# >>> 16 6 8
# >>> 16 6 9
# >>> 16 6 10
# >>> 16 6 11
# >>> 16 6 12
# >>> 16 6 13
# >>> 16 6 14
# >>> 16 6 15
# >>> 16 6 16
# >>> 16 6 17
# >>> 16 6 18
# >>> 16 6 19
# >>> 16 6 20
# >>> 16 6 21
# >>> 16 6 22
# >>> 16 7 0
# >>> 16 7 1
# >>> 16 7 2
# >>> 16 7 3
# >>> 16 7 4
# >>> 16 7 5
# >>> 16 7 6
# >>> 16 7 7
# >>> 16 7 8
# >>> 16 7 9
# >>> 16 7 10
# >>> 16 7 11
# >>> 16 7 12
# >>> 16 7 13
# >>> 16 7 14
# >>> 16 7 15
# >>> 16 7 16
# >>> 16 7 17
# >>> 16 7 18
# >>> 16 7 19
# >>> 16 7 20
# >>> 16 7 21
# >>> 16 7 22
# >>> 16 8 0
# >>> 16 8 1
# >>> 16 8 2
# >>> 16 8 3
# >>> 16 8 4
# >>> 16 8 5
# >>> 16 8 6
# >>> 16 8 7
# >>> 16 8 8
# >>> 16 8 9
# >>> 16 8 10
# >>> 16 8 11
# >>> 16 8 12
# >>> 16 8 13
# >>> 16 8 14
# >>> 16 8 15
# >>> 16 8 16
# >>> 16 8 17
# >>> 16 8 18
# >>> 16 8 19
# >>> 16 8 20
# >>> 16 8 21
# >>> 16 8 22
# >>> 16 9 0
# >>> 16 9 1
# >>> 16 9 2
# >>> 16 9 3
# >>> 16 9 4
# >>> 16 9 5
# >>> 16 9 6
# >>> 16 9 7
# >>> 16 9 8
# >>> 16 9 9
# >>> 16 9 10
# >>> 16 9 11
# >>> 16 9 12
# >>> 16 9 13
# >>> 16 9 14
# >>> 16 9 15
# >>> 16 9 16
# >>> 16 9 17
# >>> 16 9 18
# >>> 16 9 19
# >>> 16 9 20
# >>> 16 9 21
# >>> 16 9 22
# >>> 16 10 0
# >>> 16 10 1
# >>> 16 10 2
# >>> 16 10 3
# >>> 16 10 4
# >>> 16 10 5
# >>> 16 10 6
# >>> 16 10 7
# >>> 16 10 8
# >>> 16 10 9
# >>> 16 10 10
# >>> 16 10 11
# >>> 16 10 12
# >>> 16 10 13
# >>> 16 10 14
# >>> 16 10 15
# >>> 16 10 16
# >>> 16 10 17
# >>> 16 10 18
# >>> 16 10 19
# >>> 16 10 20
# >>> 16 10 21
# >>> 16 10 22
# >>> 16 11 0
# >>> 16 11 1
# >>> 16 11 2
# >>> 16 11 3
# >>> 16 11 4
# >>> 16 11 5
# >>> 16 11 6
# >>> 16 11 7
# >>> 16 11 8
# >>> 16 11 9
# >>> 16 11 10
# >>> 16 11 11
# >>> 16 11 12
# >>> 16 11 13
# >>> 16 11 14
# >>> 16 11 15
# >>> 16 11 16
# >>> 16 11 17
# >>> 16 11 18
# >>> 16 11 19
# >>> 16 11 20
# >>> 16 11 21
# >>> 16 11 22
# >>> 16 12 0
# >>> 16 12 1
# >>> 16 12 2
# >>> 16 12 3
# >>> 16 12 4
# >>> 16 12 5
# >>> 16 12 6
# >>> 16 12 7
# >>> 16 12 8
# >>> 16 12 9
# >>> 16 12 10
# >>> 16 12 11
# >>> 16 12 12
# >>> 16 12 13
# >>> 16 12 14
# >>> 16 12 15
# >>> 16 12 16
# >>> 16 12 17
# >>> 16 12 18
# >>> 16 12 19
# >>> 16 12 20
# >>> 16 12 21
# >>> 16 12 22
# >>> 16 13 0
# >>> 16 13 1
# >>> 16 13 2
# >>> 16 13 3
# >>> 16 13 4
# >>> 16 13 5
# >>> 16 13 6
# >>> 16 13 7
# >>> 16 13 8
# >>> 16 13 9
# >>> 16 13 10
# >>> 16 13 11
# >>> 16 13 12
# >>> 16 13 13
# >>> 16 13 14
# >>> 16 13 15
# >>> 16 13 16
# >>> 16 13 17
# >>> 16 13 18
# >>> 16 13 19
# >>> 16 13 20
# >>> 16 13 21
# >>> 16 13 22
# >>> 16 14 0
# >>> 16 14 1
# >>> 16 14 2
# >>> 16 14 3
# >>> 16 14 4
# >>> 16 14 5
# >>> 16 14 6
# >>> 16 14 7
# >>> 16 14 8
# >>> 16 14 9
# >>> 16 14 10
# >>> 16 14 11
# >>> 16 14 12
# >>> 16 14 13
# >>> 16 14 14
# >>> 16 14 15
# >>> 16 14 16
# >>> 16 14 17
# >>> 16 14 18
# >>> 16 14 19
# >>> 16 14 20
# >>> 16 14 21
# >>> 16 14 22
# >>> 17 5 0
# >>> 17 5 1
# >>> 17 5 2
# >>> 17 5 3
# >>> 17 5 4
# >>> 17 5 5
# >>> 17 5 6
# >>> 17 5 7
# >>> 17 5 8
# >>> 17 5 9
# >>> 17 5 10
# >>> 17 5 11
# >>> 17 5 12
# >>> 17 5 13
# >>> 17 5 14
# >>> 17 5 15
# >>> 17 5 16
# >>> 17 5 17
# >>> 17 5 18
# >>> 17 5 19
# >>> 17 5 20
# >>> 17 5 21
# >>> 17 5 22
# >>> 17 6 0
# >>> 17 6 1
# >>> 17 6 2
# >>> 17 6 3
# >>> 17 6 4
# >>> 17 6 5
# >>> 17 6 6
# >>> 17 6 7
# >>> 17 6 8
# >>> 17 6 9
# >>> 17 6 10
# >>> 17 6 11
# >>> 17 6 12
# >>> 17 6 13
# >>> 17 6 14
# >>> 17 6 15
# >>> 17 6 16
# >>> 17 6 17
# >>> 17 6 18
# >>> 17 6 19
# >>> 17 6 20
# >>> 17 6 21
# >>> 17 6 22
# >>> 17 7 0
# >>> 17 7 1
# >>> 17 7 2
# >>> 17 7 3
# >>> 17 7 4
# >>> 17 7 5
# >>> 17 7 6
# >>> 17 7 7
# >>> 17 7 8
# >>> 17 7 9
# >>> 17 7 10
# >>> 17 7 11
# >>> 17 7 12
# >>> 17 7 13
# >>> 17 7 14
# >>> 17 7 15
# >>> 17 7 16
# >>> 17 7 17
# >>> 17 7 18
# >>> 17 7 19
# >>> 17 7 20
# >>> 17 7 21
# >>> 17 7 22
# >>> 17 8 0
# >>> 17 8 1
# >>> 17 8 2
# >>> 17 8 3
# >>> 17 8 4
# >>> 17 8 5
# >>> 17 8 6
# >>> 17 8 7
# >>> 17 8 8
# >>> 17 8 9
# >>> 17 8 10
# >>> 17 8 11
# >>> 17 8 12
# >>> 17 8 13
# >>> 17 8 14
# >>> 17 8 15
# >>> 17 8 16
# >>> 17 8 17
# >>> 17 8 18
# >>> 17 8 19
# >>> 17 8 20
# >>> 17 8 21
# >>> 17 8 22
# >>> 17 9 0
# >>> 17 9 1
# >>> 17 9 2
# >>> 17 9 3
# >>> 17 9 4
# >>> 17 9 5
# >>> 17 9 6
# >>> 17 9 7
# >>> 17 9 8
# >>> 17 9 9
# >>> 17 9 10
# >>> 17 9 11
# >>> 17 9 12
# >>> 17 9 13
# >>> 17 9 14
# >>> 17 9 15
# >>> 17 9 16
# >>> 17 9 17
# >>> 17 9 18
# >>> 17 9 19
# >>> 17 9 20
# >>> 17 9 21
# >>> 17 9 22
# >>> 17 10 0
# >>> 17 10 1
# >>> 17 10 2
# >>> 17 10 3
# >>> 17 10 4
# >>> 17 10 5
# >>> 17 10 6
# >>> 17 10 7
# >>> 17 10 8
# >>> 17 10 9
# >>> 17 10 10
# >>> 17 10 11
# >>> 17 10 12
# >>> 17 10 13
# >>> 17 10 14
# >>> 17 10 15
# >>> 17 10 16
# >>> 17 10 17
# >>> 17 10 18
# >>> 17 10 19
# >>> 17 10 20
# >>> 17 10 21
# >>> 17 10 22
# >>> 17 11 0
# >>> 17 11 1
# >>> 17 11 2
# >>> 17 11 3
# >>> 17 11 4
# >>> 17 11 5
# >>> 17 11 6
# >>> 17 11 7
# >>> 17 11 8
# >>> 17 11 9
# >>> 17 11 10
# >>> 17 11 11
# >>> 17 11 12
# >>> 17 11 13
# >>> 17 11 14
# >>> 17 11 15
# >>> 17 11 16
# >>> 17 11 17
# >>> 17 11 18
# >>> 17 11 19
# >>> 17 11 20
# >>> 17 11 21
# >>> 17 11 22
# >>> 17 12 0
# >>> 17 12 1
# >>> 17 12 2
# >>> 17 12 3
# >>> 17 12 4
# >>> 17 12 5
# >>> 17 12 6
# >>> 17 12 7
# >>> 17 12 8
# >>> 17 12 9
# >>> 17 12 10
# >>> 17 12 11
# >>> 17 12 12
# >>> 17 12 13
# >>> 17 12 14
# >>> 17 12 15
# >>> 17 12 16
# >>> 17 12 17
# >>> 17 12 18
# >>> 17 12 19
# >>> 17 12 20
# >>> 17 12 21
# >>> 17 12 22
# >>> 17 13 0
# >>> 17 13 1
# >>> 17 13 2
# >>> 17 13 3
# >>> 17 13 4
# >>> 17 13 5
# >>> 17 13 6
# >>> 17 13 7
# >>> 17 13 8
# >>> 17 13 9
# >>> 17 13 10
# >>> 17 13 11
# >>> 17 13 12
# >>> 17 13 13
# >>> 17 13 14
# >>> 17 13 15
# >>> 17 13 16
# >>> 17 13 17
# >>> 17 13 18
# >>> 17 13 19
# >>> 17 13 20
# >>> 17 13 21
# >>> 17 13 22
# >>> 17 14 0
# >>> 17 14 1
# >>> 17 14 2
# >>> 17 14 3
# >>> 17 14 4
# >>> 17 14 5
# >>> 17 14 6
# >>> 17 14 7
# >>> 17 14 8
# >>> 17 14 9
# >>> 17 14 10
# >>> 17 14 11
# >>> 17 14 12
# >>> 17 14 13
# >>> 17 14 14
# >>> 17 14 15
# >>> 17 14 16
# >>> 17 14 17
# >>> 17 14 18
# >>> 17 14 19
# >>> 17 14 20
# >>> 17 14 21
# >>> 17 14 22
# >>> 18 5 0
# >>> 18 5 1
# >>> 18 5 2
# >>> 18 5 3
# >>> 18 5 4
# >>> 18 5 5
# >>> 18 5 6
# >>> 18 5 7
# >>> 18 5 8
# >>> 18 5 9
# >>> 18 5 10
# >>> 18 5 11
# >>> 18 5 12
# >>> 18 5 13
# >>> 18 5 14
# >>> 18 5 15
# >>> 18 5 16
# >>> 18 5 17
# >>> 18 5 18
# >>> 18 5 19
# >>> 18 5 20
# >>> 18 5 21
# >>> 18 5 22
# >>> 18 6 0
# >>> 18 6 1
# >>> 18 6 2
# >>> 18 6 3
# >>> 18 6 4
# >>> 18 6 5
# >>> 18 6 6
# >>> 18 6 7
# >>> 18 6 8
# >>> 18 6 9
# >>> 18 6 10
# >>> 18 6 11
# >>> 18 6 12
# >>> 18 6 13
# >>> 18 6 14
# >>> 18 6 15
# >>> 18 6 16
# >>> 18 6 17
# >>> 18 6 18
# >>> 18 6 19
# >>> 18 6 20
# >>> 18 6 21
# >>> 18 6 22
# >>> 18 7 0
# >>> 18 7 1
# >>> 18 7 2
# >>> 18 7 3
# >>> 18 7 4
# >>> 18 7 5
# >>> 18 7 6
# >>> 18 7 7
# >>> 18 7 8
# >>> 18 7 9
# >>> 18 7 10
# >>> 18 7 11
# >>> 18 7 12
# >>> 18 7 13
# >>> 18 7 14
# >>> 18 7 15
# >>> 18 7 16
# >>> 18 7 17
# >>> 18 7 18
# >>> 18 7 19
# >>> 18 7 20
# >>> 18 7 21
# >>> 18 7 22
# >>> 18 8 0
# >>> 18 8 1
# >>> 18 8 2
# >>> 18 8 3
# >>> 18 8 4
# >>> 18 8 5
# >>> 18 8 6
# >>> 18 8 7
# >>> 18 8 8
# >>> 18 8 9
# >>> 18 8 10
# >>> 18 8 11
# >>> 18 8 12
# >>> 18 8 13
# >>> 18 8 14
# >>> 18 8 15
# >>> 18 8 16
# >>> 18 8 17
# >>> 18 8 18
# >>> 18 8 19
# >>> 18 8 20
# >>> 18 8 21
# >>> 18 8 22
# >>> 18 9 0
# >>> 18 9 1
# >>> 18 9 2
# >>> 18 9 3
# >>> 18 9 4
# >>> 18 9 5
# >>> 18 9 6
# >>> 18 9 7
# >>> 18 9 8
# >>> 18 9 9
# >>> 18 9 10
# >>> 18 9 11
# >>> 18 9 12
# >>> 18 9 13
# >>> 18 9 14
# >>> 18 9 15
# >>> 18 9 16
# >>> 18 9 17
# >>> 18 9 18
# >>> 18 9 19
# >>> 18 9 20
# >>> 18 9 21
# >>> 18 9 22
# >>> 18 10 0
# >>> 18 10 1
# >>> 18 10 2
# >>> 18 10 3
# >>> 18 10 4
# >>> 18 10 5
# >>> 18 10 6
# >>> 18 10 7
# >>> 18 10 8
# >>> 18 10 9
# >>> 18 10 10
# >>> 18 10 11
# >>> 18 10 12
# >>> 18 10 13
# >>> 18 10 14
# >>> 18 10 15
# >>> 18 10 16
# >>> 18 10 17
# >>> 18 10 18
# >>> 18 10 19
# >>> 18 10 20
# >>> 18 10 21
# >>> 18 10 22
# >>> 18 11 0
# >>> 18 11 1
# >>> 18 11 2
# >>> 18 11 3
# >>> 18 11 4
# >>> 18 11 5
# >>> 18 11 6
# >>> 18 11 7
# >>> 18 11 8
# >>> 18 11 9
# >>> 18 11 10
# >>> 18 11 11
# >>> 18 11 12
# >>> 18 11 13
# >>> 18 11 14
# >>> 18 11 15
# >>> 18 11 16
# >>> 18 11 17
# >>> 18 11 18
# >>> 18 11 19
# >>> 18 11 20
# >>> 18 11 21
# >>> 18 11 22
# >>> 18 12 0
# >>> 18 12 1
# >>> 18 12 2
# >>> 18 12 3
# >>> 18 12 4
# >>> 18 12 5
# >>> 18 12 6
# >>> 18 12 7
# >>> 18 12 8
# >>> 18 12 9
# >>> 18 12 10
# >>> 18 12 11
# >>> 18 12 12
# >>> 18 12 13
# >>> 18 12 14
# >>> 18 12 15
# >>> 18 12 16
# >>> 18 12 17
# >>> 18 12 18
# >>> 18 12 19
# >>> 18 12 20
# >>> 18 12 21
# >>> 18 12 22
# >>> 18 13 0
# >>> 18 13 1
# >>> 18 13 2
# >>> 18 13 3
# >>> 18 13 4
# >>> 18 13 5
# >>> 18 13 6
# >>> 18 13 7
# >>> 18 13 8
# >>> 18 13 9
# >>> 18 13 10
# >>> 18 13 11
# >>> 18 13 12
# >>> 18 13 13
# >>> 18 13 14
# >>> 18 13 15
# >>> 18 13 16
# >>> 18 13 17
# >>> 18 13 18
# >>> 18 13 19
# >>> 18 13 20
# >>> 18 13 21
# >>> 18 13 22
# >>> 18 14 0
# >>> 18 14 1
# >>> 18 14 2
# >>> 18 14 3
# >>> 18 14 4
# >>> 18 14 5
# >>> 18 14 6
# >>> 18 14 7
# >>> 18 14 8
# >>> 18 14 9
# >>> 18 14 10
# >>> 18 14 11
# >>> 18 14 12
# >>> 18 14 13
# >>> 18 14 14
# >>> 18 14 15
# >>> 18 14 16
# >>> 18 14 17
# >>> 18 14 18
# >>> 18 14 19
# >>> 18 14 20
# >>> 18 14 21
# >>> 18 14 22
# >>> 19 5 0
# >>> 19 5 1
# >>> 19 5 2
# >>> 19 5 3
# >>> 19 5 4
# >>> 19 5 5
# >>> 19 5 6
# >>> 19 5 7
# >>> 19 5 8
# >>> 19 5 9
# >>> 19 5 10
# >>> 19 5 11
# >>> 19 5 12
# >>> 19 5 13
# >>> 19 5 14
# >>> 19 5 15
# >>> 19 5 16
# >>> 19 5 17
# >>> 19 5 18
# >>> 19 5 19
# >>> 19 5 20
# >>> 19 5 21
# >>> 19 5 22
# >>> 19 6 0
# >>> 19 6 1
# >>> 19 6 2
# >>> 19 6 3
# >>> 19 6 4
# >>> 19 6 5
# >>> 19 6 6
# >>> 19 6 7
# >>> 19 6 8
# >>> 19 6 9
# >>> 19 6 10
# >>> 19 6 11
# >>> 19 6 12
# >>> 19 6 13
# >>> 19 6 14
# >>> 19 6 15
# >>> 19 6 16
# >>> 19 6 17
# >>> 19 6 18
# >>> 19 6 19
# >>> 19 6 20
# >>> 19 6 21
# >>> 19 6 22
# >>> 19 7 0
# >>> 19 7 1
# >>> 19 7 2
# >>> 19 7 3
# >>> 19 7 4
# >>> 19 7 5
# >>> 19 7 6
# >>> 19 7 7
# >>> 19 7 8
# >>> 19 7 9
# >>> 19 7 10
# >>> 19 7 11
# >>> 19 7 12
# >>> 19 7 13
# >>> 19 7 14
# >>> 19 7 15
# >>> 19 7 16
# >>> 19 7 17
# >>> 19 7 18
# >>> 19 7 19
# >>> 19 7 20
# >>> 19 7 21
# >>> 19 7 22
# >>> 19 8 0
# >>> 19 8 1
# >>> 19 8 2
# >>> 19 8 3
# >>> 19 8 4
# >>> 19 8 5
# >>> 19 8 6
# >>> 19 8 7
# >>> 19 8 8
# >>> 19 8 9
# >>> 19 8 10
# >>> 19 8 11
# >>> 19 8 12
# >>> 19 8 13
# >>> 19 8 14
# >>> 19 8 15
# >>> 19 8 16
# >>> 19 8 17
# >>> 19 8 18
# >>> 19 8 19
# >>> 19 8 20
# >>> 19 8 21
# >>> 19 8 22
# >>> 19 9 0
# >>> 19 9 1
# >>> 19 9 2
# >>> 19 9 3
# >>> 19 9 4
# >>> 19 9 5
# >>> 19 9 6
# >>> 19 9 7
# >>> 19 9 8
# >>> 19 9 9
# >>> 19 9 10
# >>> 19 9 11
# >>> 19 9 12
# >>> 19 9 13
# >>> 19 9 14
# >>> 19 9 15
# >>> 19 9 16
# >>> 19 9 17
# >>> 19 9 18
# >>> 19 9 19
# >>> 19 9 20
# >>> 19 9 21
# >>> 19 9 22
# >>> 19 10 0
# >>> 19 10 1
# >>> 19 10 2
# >>> 19 10 3
# >>> 19 10 4
# >>> 19 10 5
# >>> 19 10 6
# >>> 19 10 7
# >>> 19 10 8
# >>> 19 10 9
# >>> 19 10 10
# >>> 19 10 11
# >>> 19 10 12
# >>> 19 10 13
# >>> 19 10 14
# >>> 19 10 15
# >>> 19 10 16
# >>> 19 10 17
# >>> 19 10 18
# >>> 19 10 19
# >>> 19 10 20
# >>> 19 10 21
# >>> 19 10 22
# >>> 19 11 0
# >>> 19 11 1
# >>> 19 11 2
# >>> 19 11 3
# >>> 19 11 4
# >>> 19 11 5
# >>> 19 11 6
# >>> 19 11 7
# >>> 19 11 8
# >>> 19 11 9
# >>> 19 11 10
# >>> 19 11 11
# >>> 19 11 12
# >>> 19 11 13
# >>> 19 11 14
# >>> 19 11 15
# >>> 19 11 16
# >>> 19 11 17
# >>> 19 11 18
# >>> 19 11 19
# >>> 19 11 20
# >>> 19 11 21
# >>> 19 11 22
# >>> 19 12 0
# >>> 19 12 1
# >>> 19 12 2
# >>> 19 12 3
# >>> 19 12 4
# >>> 19 12 5
# >>> 19 12 6
# >>> 19 12 7
# >>> 19 12 8
# >>> 19 12 9
# >>> 19 12 10
# >>> 19 12 11
# >>> 19 12 12
# >>> 19 12 13
# >>> 19 12 14
# >>> 19 12 15
# >>> 19 12 16
# >>> 19 12 17
# >>> 19 12 18
# >>> 19 12 19
# >>> 19 12 20
# >>> 19 12 21
# >>> 19 12 22
# >>> 19 13 0
# >>> 19 13 1
# >>> 19 13 2
# >>> 19 13 3
# >>> 19 13 4
# >>> 19 13 5
# >>> 19 13 6
# >>> 19 13 7
# >>> 19 13 8
# >>> 19 13 9
# >>> 19 13 10
# >>> 19 13 11
# >>> 19 13 12
# >>> 19 13 13
# >>> 19 13 14
# >>> 19 13 15
# >>> 19 13 16
# >>> 19 13 17
# >>> 19 13 18
# >>> 19 13 19
# >>> 19 13 20
# >>> 19 13 21
# >>> 19 13 22
# >>> 19 14 0
# >>> 19 14 1
# >>> 19 14 2
# >>> 19 14 3
# >>> 19 14 4
# >>> 19 14 5
# >>> 19 14 6
# >>> 19 14 7
# >>> 19 14 8
# >>> 19 14 9
# >>> 19 14 10
# >>> 19 14 11
# >>> 19 14 12
# >>> 19 14 13
# >>> 19 14 14
# >>> 19 14 15
# >>> 19 14 16
# >>> 19 14 17
# >>> 19 14 18
# >>> 19 14 19
# >>> 19 14 20
# >>> 19 14 21
# >>> 19 14 22
# >>> 20 5 0
# >>> 20 5 1
# >>> 20 5 2
# >>> 20 5 3
# >>> 20 5 4
# >>> 20 5 5
# >>> 20 5 6
# >>> 20 5 7
# >>> 20 5 8
# >>> 20 5 9
# >>> 20 5 10
# >>> 20 5 11
# >>> 20 5 12
# >>> 20 5 13
# >>> 20 5 14
# >>> 20 5 15
# >>> 20 5 16
# >>> 20 5 17
# >>> 20 5 18
# >>> 20 5 19
# >>> 20 5 20
# >>> 20 5 21
# >>> 20 5 22
# >>> 20 6 0
# >>> 20 6 1
# >>> 20 6 2
# >>> 20 6 3
# >>> 20 6 4
# >>> 20 6 5
# >>> 20 6 6
# >>> 20 6 7
# >>> 20 6 8
# >>> 20 6 9
# >>> 20 6 10
# >>> 20 6 11
# >>> 20 6 12
# >>> 20 6 13
# >>> 20 6 14
# >>> 20 6 15
# >>> 20 6 16
# >>> 20 6 17
# >>> 20 6 18
# >>> 20 6 19
# >>> 20 6 20
# >>> 20 6 21
# >>> 20 6 22
# >>> 20 7 0
# >>> 20 7 1
# >>> 20 7 2
# >>> 20 7 3
# >>> 20 7 4
# >>> 20 7 5
# >>> 20 7 6
# >>> 20 7 7
# >>> 20 7 8
# >>> 20 7 9
# >>> 20 7 10
# >>> 20 7 11
# >>> 20 7 12
# >>> 20 7 13
# >>> 20 7 14
# >>> 20 7 15
# >>> 20 7 16
# >>> 20 7 17
# >>> 20 7 18
# >>> 20 7 19
# >>> 20 7 20
# >>> 20 7 21
# >>> 20 7 22
# >>> 20 8 0
# >>> 20 8 1
# >>> 20 8 2
# >>> 20 8 3
# >>> 20 8 4
# >>> 20 8 5
# >>> 20 8 6
# >>> 20 8 7
# >>> 20 8 8
# >>> 20 8 9
# >>> 20 8 10
# >>> 20 8 11
# >>> 20 8 12
# >>> 20 8 13
# >>> 20 8 14
# >>> 20 8 15
# >>> 20 8 16
# >>> 20 8 17
# >>> 20 8 18
# >>> 20 8 19
# >>> 20 8 20
# >>> 20 8 21
# >>> 20 8 22
# >>> 20 9 0
# >>> 20 9 1
# >>> 20 9 2
# >>> 20 9 3
# >>> 20 9 4
# >>> 20 9 5
# >>> 20 9 6
# >>> 20 9 7
# >>> 20 9 8
# >>> 20 9 9
# >>> 20 9 10
# >>> 20 9 11
# >>> 20 9 12
# >>> 20 9 13
# >>> 20 9 14
# >>> 20 9 15
# >>> 20 9 16
# >>> 20 9 17
# >>> 20 9 18
# >>> 20 9 19
# >>> 20 9 20
# >>> 20 9 21
# >>> 20 9 22
# >>> 20 10 0
# >>> 20 10 1
# >>> 20 10 2
# >>> 20 10 3
# >>> 20 10 4
# >>> 20 10 5
# >>> 20 10 6
# >>> 20 10 7
# >>> 20 10 8
# >>> 20 10 9
# >>> 20 10 10
# >>> 20 10 11
# >>> 20 10 12
# >>> 20 10 13
# >>> 20 10 14
# >>> 20 10 15
# >>> 20 10 16
# >>> 20 10 17
# >>> 20 10 18
# >>> 20 10 19
# >>> 20 10 20
# >>> 20 10 21
# >>> 20 10 22
# >>> 20 11 0
# >>> 20 11 1
# >>> 20 11 2
# >>> 20 11 3
# >>> 20 11 4
# >>> 20 11 5
# >>> 20 11 6
# >>> 20 11 7
# >>> 20 11 8
# >>> 20 11 9
# >>> 20 11 10
# >>> 20 11 11
# >>> 20 11 12
# >>> 20 11 13
# >>> 20 11 14
# >>> 20 11 15
# >>> 20 11 16
# >>> 20 11 17
# >>> 20 11 18
# >>> 20 11 19
# >>> 20 11 20
# >>> 20 11 21
# >>> 20 11 22
# >>> 20 12 0
# >>> 20 12 1
# >>> 20 12 2
# >>> 20 12 3
# >>> 20 12 4
# >>> 20 12 5
# >>> 20 12 6
# >>> 20 12 7
# >>> 20 12 8
# >>> 20 12 9
# >>> 20 12 10
# >>> 20 12 11
# >>> 20 12 12
# >>> 20 12 13
# >>> 20 12 14
# >>> 20 12 15
# >>> 20 12 16
# >>> 20 12 17
# >>> 20 12 18
# >>> 20 12 19
# >>> 20 12 20
# >>> 20 12 21
# >>> 20 12 22
# >>> 20 13 0
# >>> 20 13 1
# >>> 20 13 2
# >>> 20 13 3
# >>> 20 13 4
# >>> 20 13 5
# >>> 20 13 6
# >>> 20 13 7
# >>> 20 13 8
# >>> 20 13 9
# >>> 20 13 10
# >>> 20 13 11
# >>> 20 13 12
# >>> 20 13 13
# >>> 20 13 14
# >>> 20 13 15
# >>> 20 13 16
# >>> 20 13 17
# >>> 20 13 18
# >>> 20 13 19
# >>> 20 13 20
# >>> 20 13 21
# >>> 20 13 22
# >>> 20 14 0
# >>> 20 14 1
# >>> 20 14 2
# >>> 20 14 3
# >>> 20 14 4
# >>> 20 14 5
# >>> 20 14 6
# >>> 20 14 7
# >>> 20 14 8
# >>> 20 14 9
# >>> 20 14 10
# >>> 20 14 11
# >>> 20 14 12
# >>> 20 14 13
# >>> 20 14 14
# >>> 20 14 15
# >>> 20 14 16
# >>> 20 14 17
# >>> 20 14 18
# >>> 20 14 19
# >>> 20 14 20
# >>> 20 14 21
# >>> 20 14 22
# >>> 21 5 0
# >>> 21 5 1
# >>> 21 5 2
# >>> 21 5 3
# >>> 21 5 4
# >>> 21 5 5
# >>> 21 5 6
# >>> 21 5 7
# >>> 21 5 8
# >>> 21 5 9
# >>> 21 5 10
# >>> 21 5 11
# >>> 21 5 12
# >>> 21 5 13
# >>> 21 5 14
# >>> 21 5 15
# >>> 21 5 16
# >>> 21 5 17
# >>> 21 5 18
# >>> 21 5 19
# >>> 21 5 20
# >>> 21 5 21
# >>> 21 5 22
# >>> 21 6 0
# >>> 21 6 1
# >>> 21 6 2
# >>> 21 6 3
# >>> 21 6 4
# >>> 21 6 5
# >>> 21 6 6
# >>> 21 6 7
# >>> 21 6 8
# >>> 21 6 9
# >>> 21 6 10
# >>> 21 6 11
# >>> 21 6 12
# >>> 21 6 13
# >>> 21 6 14
# >>> 21 6 15
# >>> 21 6 16
# >>> 21 6 17
# >>> 21 6 18
# >>> 21 6 19
# >>> 21 6 20
# >>> 21 6 21
# >>> 21 6 22
# >>> 21 7 0
# >>> 21 7 1
# >>> 21 7 2
# >>> 21 7 3
# >>> 21 7 4
# >>> 21 7 5
# >>> 21 7 6
# >>> 21 7 7
# >>> 21 7 8
# >>> 21 7 9
# >>> 21 7 10
# >>> 21 7 11
# >>> 21 7 12
# >>> 21 7 13
# >>> 21 7 14
# >>> 21 7 15
# >>> 21 7 16
# >>> 21 7 17
# >>> 21 7 18
# >>> 21 7 19
# >>> 21 7 20
# >>> 21 7 21
# >>> 21 7 22
# >>> 21 8 0
# >>> 21 8 1
# >>> 21 8 2
# >>> 21 8 3
# >>> 21 8 4
# >>> 21 8 5
# >>> 21 8 6
# >>> 21 8 7
# >>> 21 8 8
# >>> 21 8 9
# >>> 21 8 10
# >>> 21 8 11
# >>> 21 8 12
# >>> 21 8 13
# >>> 21 8 14
# >>> 21 8 15
# >>> 21 8 16
# >>> 21 8 17
# >>> 21 8 18
# >>> 21 8 19
# >>> 21 8 20
# >>> 21 8 21
# >>> 21 8 22
# >>> 21 9 0
# >>> 21 9 1
# >>> 21 9 2
# >>> 21 9 3
# >>> 21 9 4
# >>> 21 9 5
# >>> 21 9 6
# >>> 21 9 7
# >>> 21 9 8
# >>> 21 9 9
# >>> 21 9 10
# >>> 21 9 11
# >>> 21 9 12
# >>> 21 9 13
# >>> 21 9 14
# >>> 21 9 15
# >>> 21 9 16
# >>> 21 9 17
# >>> 21 9 18
# >>> 21 9 19
# >>> 21 9 20
# >>> 21 9 21
# >>> 21 9 22
# >>> 21 10 0
# >>> 21 10 1
# >>> 21 10 2
# >>> 21 10 3
# >>> 21 10 4
# >>> 21 10 5
# >>> 21 10 6
# >>> 21 10 7
# >>> 21 10 8
# >>> 21 10 9
# >>> 21 10 10
# >>> 21 10 11
# >>> 21 10 12
# >>> 21 10 13
# >>> 21 10 14
# >>> 21 10 15
# >>> 21 10 16
# >>> 21 10 17
# >>> 21 10 18
# >>> 21 10 19
# >>> 21 10 20
# >>> 21 10 21
# >>> 21 10 22
# >>> 21 11 0
# >>> 21 11 1
# >>> 21 11 2
# >>> 21 11 3
# >>> 21 11 4
# >>> 21 11 5
# >>> 21 11 6
# >>> 21 11 7
# >>> 21 11 8
# >>> 21 11 9
# >>> 21 11 10
# >>> 21 11 11
# >>> 21 11 12
# >>> 21 11 13
# >>> 21 11 14
# >>> 21 11 15
# >>> 21 11 16
# >>> 21 11 17
# >>> 21 11 18
# >>> 21 11 19
# >>> 21 11 20
# >>> 21 11 21
# >>> 21 11 22
# >>> 21 12 0
# >>> 21 12 1
# >>> 21 12 2
# >>> 21 12 3
# >>> 21 12 4
# >>> 21 12 5
# >>> 21 12 6
# >>> 21 12 7
# >>> 21 12 8
# >>> 21 12 9
# >>> 21 12 10
# >>> 21 12 11
# >>> 21 12 12
# >>> 21 12 13
# >>> 21 12 14
# >>> 21 12 15
# >>> 21 12 16
# >>> 21 12 17
# >>> 21 12 18
# >>> 21 12 19
# >>> 21 12 20
# >>> 21 12 21
# >>> 21 12 22
# >>> 21 13 0
# >>> 21 13 1
# >>> 21 13 2
# >>> 21 13 3
# >>> 21 13 4
# >>> 21 13 5
# >>> 21 13 6
# >>> 21 13 7
# >>> 21 13 8
# >>> 21 13 9
# >>> 21 13 10
# >>> 21 13 11
# >>> 21 13 12
# >>> 21 13 13
# >>> 21 13 14
# >>> 21 13 15
# >>> 21 13 16
# >>> 21 13 17
# >>> 21 13 18
# >>> 21 13 19
# >>> 21 13 20
# >>> 21 13 21
# >>> 21 13 22
# >>> 21 14 0
# >>> 21 14 1
# >>> 21 14 2
# >>> 21 14 3
# >>> 21 14 4
# >>> 21 14 5
# >>> 21 14 6
# >>> 21 14 7
# >>> 21 14 8
# >>> 21 14 9
# >>> 21 14 10
# >>> 21 14 11
# >>> 21 14 12
# >>> 21 14 13
# >>> 21 14 14
# >>> 21 14 15
# >>> 21 14 16
# >>> 21 14 17
# >>> 21 14 18
# >>> 21 14 19
# >>> 21 14 20
# >>> 21 14 21
# >>> 21 14 22
# >>> 22 5 0
# >>> 22 5 1
# >>> 22 5 2
# >>> 22 5 3
# >>> 22 5 4
# >>> 22 5 5
# >>> 22 5 6
# >>> 22 5 7
# >>> 22 5 8
# >>> 22 5 9
# >>> 22 5 10
# >>> 22 5 11
# >>> 22 5 12
# >>> 22 5 13
# >>> 22 5 14
# >>> 22 5 15
# >>> 22 5 16
# >>> 22 5 17
# >>> 22 5 18
# >>> 22 5 19
# >>> 22 5 20
# >>> 22 5 21
# >>> 22 5 22
# >>> 22 6 0
# >>> 22 6 1
# >>> 22 6 2
# >>> 22 6 3
# >>> 22 6 4
# >>> 22 6 5
# >>> 22 6 6
# >>> 22 6 7
# >>> 22 6 8
# >>> 22 6 9
# >>> 22 6 10
# >>> 22 6 11
# >>> 22 6 12
# >>> 22 6 13
# >>> 22 6 14
# >>> 22 6 15
# >>> 22 6 16
# >>> 22 6 17
# >>> 22 6 18
# >>> 22 6 19
# >>> 22 6 20
# >>> 22 6 21
# >>> 22 6 22
# >>> 22 7 0
# >>> 22 7 1
# >>> 22 7 2
# >>> 22 7 3
# >>> 22 7 4
# >>> 22 7 5
# >>> 22 7 6
# >>> 22 7 7
# >>> 22 7 8
# >>> 22 7 9
# >>> 22 7 10
# >>> 22 7 11
# >>> 22 7 12
# >>> 22 7 13
# >>> 22 7 14
# >>> 22 7 15
# >>> 22 7 16
# >>> 22 7 17
# >>> 22 7 18
# >>> 22 7 19
# >>> 22 7 20
# >>> 22 7 21
# >>> 22 7 22
# >>> 22 8 0
# >>> 22 8 1
# >>> 22 8 2
# >>> 22 8 3
# >>> 22 8 4
# >>> 22 8 5
# >>> 22 8 6
# >>> 22 8 7
# >>> 22 8 8
# >>> 22 8 9
# >>> 22 8 10
# >>> 22 8 11
# >>> 22 8 12
# >>> 22 8 13
# >>> 22 8 14
# >>> 22 8 15
# >>> 22 8 16
# >>> 22 8 17
# >>> 22 8 18
# >>> 22 8 19
# >>> 22 8 20
# >>> 22 8 21
# >>> 22 8 22
# >>> 22 9 0
# >>> 22 9 1
# >>> 22 9 2
# >>> 22 9 3
# >>> 22 9 4
# >>> 22 9 5
# >>> 22 9 6
# >>> 22 9 7
# >>> 22 9 8
# >>> 22 9 9
# >>> 22 9 10
# >>> 22 9 11
# >>> 22 9 12
# >>> 22 9 13
# >>> 22 9 14
# >>> 22 9 15
# >>> 22 9 16
# >>> 22 9 17
# >>> 22 9 18
# >>> 22 9 19
# >>> 22 9 20
# >>> 22 9 21
# >>> 22 9 22
# >>> 22 10 0
# >>> 22 10 1
# >>> 22 10 2
# >>> 22 10 3
# >>> 22 10 4
# >>> 22 10 5
# >>> 22 10 6
# >>> 22 10 7
# >>> 22 10 8
# >>> 22 10 9
# >>> 22 10 10
# >>> 22 10 11
# >>> 22 10 12
# >>> 22 10 13
# >>> 22 10 14
# >>> 22 10 15
# >>> 22 10 16
# >>> 22 10 17
# >>> 22 10 18
# >>> 22 10 19
# >>> 22 10 20
# >>> 22 10 21
# >>> 22 10 22
# >>> 22 11 0
# >>> 22 11 1
# >>> 22 11 2
# >>> 22 11 3
# >>> 22 11 4
# >>> 22 11 5
# >>> 22 11 6
# >>> 22 11 7
# >>> 22 11 8
# >>> 22 11 9
# >>> 22 11 10
# >>> 22 11 11
# >>> 22 11 12
# >>> 22 11 13
# >>> 22 11 14
# >>> 22 11 15
# >>> 22 11 16
# >>> 22 11 17
# >>> 22 11 18
# >>> 22 11 19
# >>> 22 11 20
# >>> 22 11 21
# >>> 22 11 22
# >>> 22 12 0
# >>> 22 12 1
# >>> 22 12 2
# >>> 22 12 3
# >>> 22 12 4
# >>> 22 12 5
# >>> 22 12 6
# >>> 22 12 7
# >>> 22 12 8
# >>> 22 12 9
# >>> 22 12 10
# >>> 22 12 11
# >>> 22 12 12
# >>> 22 12 13
# >>> 22 12 14
# >>> 22 12 15
# >>> 22 12 16
# >>> 22 12 17
# >>> 22 12 18
# >>> 22 12 19
# >>> 22 12 20
# >>> 22 12 21
# >>> 22 12 22
# >>> 22 13 0
# >>> 22 13 1
# >>> 22 13 2
# >>> 22 13 3
# >>> 22 13 4
# >>> 22 13 5
# >>> 22 13 6
# >>> 22 13 7
# >>> 22 13 8
# >>> 22 13 9
# >>> 22 13 10
# >>> 22 13 11
# >>> 22 13 12
# >>> 22 13 13
# >>> 22 13 14
# >>> 22 13 15
# >>> 22 13 16
# >>> 22 13 17
# >>> 22 13 18
# >>> 22 13 19
# >>> 22 13 20
# >>> 22 13 21
# >>> 22 13 22
# >>> 22 14 0
# >>> 22 14 1
# >>> 22 14 2
# >>> 22 14 3
# >>> 22 14 4
# >>> 22 14 5
# >>> 22 14 6
# >>> 22 14 7
# >>> 22 14 8
# >>> 22 14 9
# >>> 22 14 10
# >>> 22 14 11
# >>> 22 14 12
# >>> 22 14 13
# >>> 22 14 14
# >>> 22 14 15
# >>> 22 14 16
# >>> 22 14 17
# >>> 22 14 18
# >>> 22 14 19
# >>> 22 14 20
# >>> 22 14 21
# >>> 22 14 22
# >>> 23 5 0
# >>> 23 5 1
# >>> 23 5 2
# >>> 23 5 3
# >>> 23 5 4
# >>> 23 5 5
# >>> 23 5 6
# >>> 23 5 7
# >>> 23 5 8
# >>> 23 5 9
# >>> 23 5 10
# >>> 23 5 11
# >>> 23 5 12
# >>> 23 5 13
# >>> 23 5 14
# >>> 23 5 15
# >>> 23 5 16
# >>> 23 5 17
# >>> 23 5 18
# >>> 23 5 19
# >>> 23 5 20
# >>> 23 5 21
# >>> 23 5 22
# >>> 23 6 0
# >>> 23 6 1
# >>> 23 6 2
# >>> 23 6 3
# >>> 23 6 4
# >>> 23 6 5
# >>> 23 6 6
# >>> 23 6 7
# >>> 23 6 8
# >>> 23 6 9
# >>> 23 6 10
# >>> 23 6 11
# >>> 23 6 12
# >>> 23 6 13
# >>> 23 6 14
# >>> 23 6 15
# >>> 23 6 16
# >>> 23 6 17
# >>> 23 6 18
# >>> 23 6 19
# >>> 23 6 20
# >>> 23 6 21
# >>> 23 6 22
# >>> 23 7 0
# >>> 23 7 1
# >>> 23 7 2
# >>> 23 7 3
# >>> 23 7 4
# >>> 23 7 5
# >>> 23 7 6
# >>> 23 7 7
# >>> 23 7 8
# >>> 23 7 9
# >>> 23 7 10
# >>> 23 7 11
# >>> 23 7 12
# >>> 23 7 13
# >>> 23 7 14
# >>> 23 7 15
# >>> 23 7 16
# >>> 23 7 17
# >>> 23 7 18
# >>> 23 7 19
# >>> 23 7 20
# >>> 23 7 21
# >>> 23 7 22
# >>> 23 8 0
# >>> 23 8 1
# >>> 23 8 2
# >>> 23 8 3
# >>> 23 8 4
# >>> 23 8 5
# >>> 23 8 6
# >>> 23 8 7
# >>> 23 8 8
# >>> 23 8 9
# >>> 23 8 10
# >>> 23 8 11
# >>> 23 8 12
# >>> 23 8 13
# >>> 23 8 14
# >>> 23 8 15
# >>> 23 8 16
# >>> 23 8 17
# >>> 23 8 18
# >>> 23 8 19
# >>> 23 8 20
# >>> 23 8 21
# >>> 23 8 22
# >>> 23 9 0
# >>> 23 9 1
# >>> 23 9 2
# >>> 23 9 3
# >>> 23 9 4
# >>> 23 9 5
# >>> 23 9 6
# >>> 23 9 7
# >>> 23 9 8
# >>> 23 9 9
# >>> 23 9 10
# >>> 23 9 11
# >>> 23 9 12
# >>> 23 9 13
# >>> 23 9 14
# >>> 23 9 15
# >>> 23 9 16
# >>> 23 9 17
# >>> 23 9 18
# >>> 23 9 19
# >>> 23 9 20
# >>> 23 9 21
# >>> 23 9 22
# >>> 23 10 0
# >>> 23 10 1
# >>> 23 10 2
# >>> 23 10 3
# >>> 23 10 4
# >>> 23 10 5
# >>> 23 10 6
# >>> 23 10 7
# >>> 23 10 8
# >>> 23 10 9
# >>> 23 10 10
# >>> 23 10 11
# >>> 23 10 12
# >>> 23 10 13
# >>> 23 10 14
# >>> 23 10 15
# >>> 23 10 16
# >>> 23 10 17
# >>> 23 10 18
# >>> 23 10 19
# >>> 23 10 20
# >>> 23 10 21
# >>> 23 10 22
# >>> 23 11 0
# >>> 23 11 1
# >>> 23 11 2
# >>> 23 11 3
# >>> 23 11 4
# >>> 23 11 5
# >>> 23 11 6
# >>> 23 11 7
# >>> 23 11 8
# >>> 23 11 9
# >>> 23 11 10
# >>> 23 11 11
# >>> 23 11 12
# >>> 23 11 13
# >>> 23 11 14
# >>> 23 11 15
# >>> 23 11 16
# >>> 23 11 17
# >>> 23 11 18
# >>> 23 11 19
# >>> 23 11 20
# >>> 23 11 21
# >>> 23 11 22
# >>> 23 12 0
# >>> 23 12 1
# >>> 23 12 2
# >>> 23 12 3
# >>> 23 12 4
# >>> 23 12 5
# >>> 23 12 6
# >>> 23 12 7
# >>> 23 12 8
# >>> 23 12 9
# >>> 23 12 10
# >>> 23 12 11
# >>> 23 12 12
# >>> 23 12 13
# >>> 23 12 14
# >>> 23 12 15
# >>> 23 12 16
# >>> 23 12 17
# >>> 23 12 18
# >>> 23 12 19
# >>> 23 12 20
# >>> 23 12 21
# >>> 23 12 22
# >>> 23 13 0
# >>> 23 13 1
# >>> 23 13 2
# >>> 23 13 3
# >>> 23 13 4
# >>> 23 13 5
# >>> 23 13 6
# >>> 23 13 7
# >>> 23 13 8
# >>> 23 13 9
# >>> 23 13 10
# >>> 23 13 11
# >>> 23 13 12
# >>> 23 13 13
# >>> 23 13 14
# >>> 23 13 15
# >>> 23 13 16
# >>> 23 13 17
# >>> 23 13 18
# >>> 23 13 19
# >>> 23 13 20
# >>> 23 13 21
# >>> 23 13 22
# >>> 23 14 0
# >>> 23 14 1
# >>> 23 14 2
# >>> 23 14 3
# >>> 23 14 4
# >>> 23 14 5
# >>> 23 14 6
# >>> 23 14 7
# >>> 23 14 8
# >>> 23 14 9
# >>> 23 14 10
# >>> 23 14 11
# >>> 23 14 12
# >>> 23 14 13
# >>> 23 14 14
# >>> 23 14 15
# >>> 23 14 16
# >>> 23 14 17
# >>> 23 14 18
# >>> 23 14 19
# >>> 23 14 20
# >>> 23 14 21
# >>> 23 14 22
# >>> 24 5 0
# >>> 24 5 1
# >>> 24 5 2
# >>> 24 5 3
# >>> 24 5 4
# >>> 24 5 5
# >>> 24 5 6
# >>> 24 5 7
# >>> 24 5 8
# >>> 24 5 9
# >>> 24 5 10
# >>> 24 5 11
# >>> 24 5 12
# >>> 24 5 13
# >>> 24 5 14
# >>> 24 5 15
# >>> 24 5 16
# >>> 24 5 17
# >>> 24 5 18
# >>> 24 5 19
# >>> 24 5 20
# >>> 24 5 21
# >>> 24 5 22
# >>> 24 6 0
# >>> 24 6 1
# >>> 24 6 2
# >>> 24 6 3
# >>> 24 6 4
# >>> 24 6 5
# >>> 24 6 6
# >>> 24 6 7
# >>> 24 6 8
# >>> 24 6 9
# >>> 24 6 10
# >>> 24 6 11
# >>> 24 6 12
# >>> 24 6 13
# >>> 24 6 14
# >>> 24 6 15
# >>> 24 6 16
# >>> 24 6 17
# >>> 24 6 18
# >>> 24 6 19
# >>> 24 6 20
# >>> 24 6 21
# >>> 24 6 22
# >>> 24 7 0
# >>> 24 7 1
# >>> 24 7 2
# >>> 24 7 3
# >>> 24 7 4
# >>> 24 7 5
# >>> 24 7 6
# >>> 24 7 7
# >>> 24 7 8
# >>> 24 7 9
# >>> 24 7 10
# >>> 24 7 11
# >>> 24 7 12
# >>> 24 7 13
# >>> 24 7 14
# >>> 24 7 15
# >>> 24 7 16
# >>> 24 7 17
# >>> 24 7 18
# >>> 24 7 19
# >>> 24 7 20
# >>> 24 7 21
# >>> 24 7 22
# >>> 24 8 0
# >>> 24 8 1
# >>> 24 8 2
# >>> 24 8 3
# >>> 24 8 4
# >>> 24 8 5
# >>> 24 8 6
# >>> 24 8 7
# >>> 24 8 8
# >>> 24 8 9
# >>> 24 8 10
# >>> 24 8 11
# >>> 24 8 12
# >>> 24 8 13
# >>> 24 8 14
# >>> 24 8 15
# >>> 24 8 16
# >>> 24 8 17
# >>> 24 8 18
# >>> 24 8 19
# >>> 24 8 20
# >>> 24 8 21
# >>> 24 8 22
# >>> 24 9 0
# >>> 24 9 1
# >>> 24 9 2
# >>> 24 9 3
# >>> 24 9 4
# >>> 24 9 5
# >>> 24 9 6
# >>> 24 9 7
# >>> 24 9 8
# >>> 24 9 9
# >>> 24 9 10
# >>> 24 9 11
# >>> 24 9 12
# >>> 24 9 13
# >>> 24 9 14
# >>> 24 9 15
# >>> 24 9 16
# >>> 24 9 17
# >>> 24 9 18
# >>> 24 9 19
# >>> 24 9 20
# >>> 24 9 21
# >>> 24 9 22
# >>> 24 10 0
# >>> 24 10 1
# >>> 24 10 2
# >>> 24 10 3
# >>> 24 10 4
# >>> 24 10 5
# >>> 24 10 6
# >>> 24 10 7
# >>> 24 10 8
# >>> 24 10 9
# >>> 24 10 10
# >>> 24 10 11
# >>> 24 10 12
# >>> 24 10 13
# >>> 24 10 14
# >>> 24 10 15
# >>> 24 10 16
# >>> 24 10 17
# >>> 24 10 18
# >>> 24 10 19
# >>> 24 10 20
# >>> 24 10 21
# >>> 24 10 22
# >>> 24 11 0
# >>> 24 11 1
# >>> 24 11 2
# >>> 24 11 3
# >>> 24 11 4
# >>> 24 11 5
# >>> 24 11 6
# >>> 24 11 7
# >>> 24 11 8
# >>> 24 11 9
# >>> 24 11 10
# >>> 24 11 11
# >>> 24 11 12
# >>> 24 11 13
# >>> 24 11 14
# >>> 24 11 15
# >>> 24 11 16
# >>> 24 11 17
# >>> 24 11 18
# >>> 24 11 19
# >>> 24 11 20
# >>> 24 11 21
# >>> 24 11 22
# >>> 24 12 0
# >>> 24 12 1
# >>> 24 12 2
# >>> 24 12 3
# >>> 24 12 4
# >>> 24 12 5
# >>> 24 12 6
# >>> 24 12 7
# >>> 24 12 8
# >>> 24 12 9
# >>> 24 12 10
# >>> 24 12 11
# >>> 24 12 12
# >>> 24 12 13
# >>> 24 12 14
# >>> 24 12 15
# >>> 24 12 16
# >>> 24 12 17
# >>> 24 12 18
# >>> 24 12 19
# >>> 24 12 20
# >>> 24 12 21
# >>> 24 12 22
# >>> 24 13 0
# >>> 24 13 1
# >>> 24 13 2
# >>> 24 13 3
# >>> 24 13 4
# >>> 24 13 5
# >>> 24 13 6
# >>> 24 13 7
# >>> 24 13 8
# >>> 24 13 9
# >>> 24 13 10
# >>> 24 13 11
# >>> 24 13 12
# >>> 24 13 13
# >>> 24 13 14
# >>> 24 13 15
# >>> 24 13 16
# >>> 24 13 17
# >>> 24 13 18
# >>> 24 13 19
# >>> 24 13 20
# >>> 24 13 21
# >>> 24 13 22
# >>> 24 14 0
# >>> 24 14 1
# >>> 24 14 2
# >>> 24 14 3
# >>> 24 14 4
# >>> 24 14 5
# >>> 24 14 6
# >>> 24 14 7
# >>> 24 14 8
# >>> 24 14 9
# >>> 24 14 10
# >>> 24 14 11
# >>> 24 14 12
# >>> 24 14 13
# >>> 24 14 14
# >>> 24 14 15
# >>> 24 14 16
# >>> 24 14 17
# >>> 24 14 18
# >>> 24 14 19
# >>> 24 14 20
# >>> 24 14 21
# >>> 24 14 22
# >>> 25 5 0
# >>> 25 5 1
# >>> 25 5 2
# >>> 25 5 3
# >>> 25 5 4
# >>> 25 5 5
# >>> 25 5 6
# >>> 25 5 7
# >>> 25 5 8
# >>> 25 5 9
# >>> 25 5 10
# >>> 25 5 11
# >>> 25 5 12
# >>> 25 5 13
# >>> 25 5 14
# >>> 25 5 15
# >>> 25 5 16
# >>> 25 5 17
# >>> 25 5 18
# >>> 25 5 19
# >>> 25 5 20
# >>> 25 5 21
# >>> 25 5 22
# >>> 25 6 0
# >>> 25 6 1
# >>> 25 6 2
# >>> 25 6 3
# >>> 25 6 4
# >>> 25 6 5
# >>> 25 6 6
# >>> 25 6 7
# >>> 25 6 8
# >>> 25 6 9
# >>> 25 6 10
# >>> 25 6 11
# >>> 25 6 12
# >>> 25 6 13
# >>> 25 6 14
# >>> 25 6 15
# >>> 25 6 16
# >>> 25 6 17
# >>> 25 6 18
# >>> 25 6 19
# >>> 25 6 20
# >>> 25 6 21
# >>> 25 6 22
# >>> 25 7 0
# >>> 25 7 1
# >>> 25 7 2
# >>> 25 7 3
# >>> 25 7 4
# >>> 25 7 5
# >>> 25 7 6
# >>> 25 7 7
# >>> 25 7 8
# >>> 25 7 9
# >>> 25 7 10
# >>> 25 7 11
# >>> 25 7 12
# >>> 25 7 13
# >>> 25 7 14
# >>> 25 7 15
# >>> 25 7 16
# >>> 25 7 17
# >>> 25 7 18
# >>> 25 7 19
# >>> 25 7 20
# >>> 25 7 21
# >>> 25 7 22
# >>> 25 8 0
# >>> 25 8 1
# >>> 25 8 2
# >>> 25 8 3
# >>> 25 8 4
# >>> 25 8 5
# >>> 25 8 6
# >>> 25 8 7
# >>> 25 8 8
# >>> 25 8 9
# >>> 25 8 10
# >>> 25 8 11
# >>> 25 8 12
# >>> 25 8 13
# >>> 25 8 14
# >>> 25 8 15
# >>> 25 8 16
# >>> 25 8 17
# >>> 25 8 18
# >>> 25 8 19
# >>> 25 8 20
# >>> 25 8 21
# >>> 25 8 22
# >>> 25 9 0
# >>> 25 9 1
# >>> 25 9 2
# >>> 25 9 3
# >>> 25 9 4
# >>> 25 9 5
# >>> 25 9 6
# >>> 25 9 7
# >>> 25 9 8
# >>> 25 9 9
# >>> 25 9 10
# >>> 25 9 11
# >>> 25 9 12
# >>> 25 9 13
# >>> 25 9 14
# >>> 25 9 15
# >>> 25 9 16
# >>> 25 9 17
# >>> 25 9 18
# >>> 25 9 19
# >>> 25 9 20
# >>> 25 9 21
# >>> 25 9 22
# >>> 25 10 0
# >>> 25 10 1
# >>> 25 10 2
# >>> 25 10 3
# >>> 25 10 4
# >>> 25 10 5
# >>> 25 10 6
# >>> 25 10 7
# >>> 25 10 8
# >>> 25 10 9
# >>> 25 10 10
# >>> 25 10 11
# >>> 25 10 12
# >>> 25 10 13
# >>> 25 10 14
# >>> 25 10 15
# >>> 25 10 16
# >>> 25 10 17
# >>> 25 10 18
# >>> 25 10 19
# >>> 25 10 20
# >>> 25 10 21
# >>> 25 10 22
# >>> 25 11 0
# >>> 25 11 1
# >>> 25 11 2
# >>> 25 11 3
# >>> 25 11 4
# >>> 25 11 5
# >>> 25 11 6
# >>> 25 11 7
# >>> 25 11 8
# >>> 25 11 9
# >>> 25 11 10
# >>> 25 11 11
# >>> 25 11 12
# >>> 25 11 13
# >>> 25 11 14
# >>> 25 11 15
# >>> 25 11 16
# >>> 25 11 17
# >>> 25 11 18
# >>> 25 11 19
# >>> 25 11 20
# >>> 25 11 21
# >>> 25 11 22
# >>> 25 12 0
# >>> 25 12 1
# >>> 25 12 2
# >>> 25 12 3
# >>> 25 12 4
# >>> 25 12 5
# >>> 25 12 6
# >>> 25 12 7
# >>> 25 12 8
# >>> 25 12 9
# >>> 25 12 10
# >>> 25 12 11
# >>> 25 12 12
# >>> 25 12 13
# >>> 25 12 14
# >>> 25 12 15
# >>> 25 12 16
# >>> 25 12 17
# >>> 25 12 18
# >>> 25 12 19
# >>> 25 12 20
# >>> 25 12 21
# >>> 25 12 22
# >>> 25 13 0
# >>> 25 13 1
# >>> 25 13 2
# >>> 25 13 3
# >>> 25 13 4
# >>> 25 13 5
# >>> 25 13 6
# >>> 25 13 7
# >>> 25 13 8
# >>> 25 13 9
# >>> 25 13 10
# >>> 25 13 11
# >>> 25 13 12
# >>> 25 13 13
# >>> 25 13 14
# >>> 25 13 15
# >>> 25 13 16
# >>> 25 13 17
# >>> 25 13 18
# >>> 25 13 19
# >>> 25 13 20
# >>> 25 13 21
# >>> 25 13 22
# >>> 25 14 0
# >>> 25 14 1
# ...
# >>> 43 6 9
# >>> 43 6 10
# >>> 43 6 11
# >>> 43 6 12
# >>> 43 6 13
# >>> 43 6 14
# >>> 43 6 15
# >>> 43 6 16
# >>> 43 6 17
# >>> 43 6 18
# >>> 43 6 19
# >>> 43 6 20
# >>> 43 6 21
# >>> 43 6 22
# >>> 43 7 0
# >>> 43 7 1
# >>> 43 7 2
# >>> 43 7 3
# >>> 43 7 4
# >>> 43 7 5
# >>> 43 7 6
# >>> 43 7 7
# >>> 43 7 8
# >>> 43 7 9
# >>> 43 7 10
# >>> 43 7 11
# >>> 43 7 12
# >>> 43 7 13
# >>> 43 7 14
# >>> 43 7 15
# >>> 43 7 16
# >>> 43 7 17
# >>> 43 7 18
# >>> 43 7 19
# >>> 43 7 20
# >>> 43 7 21
# >>> 43 7 22
# >>> 43 8 0
# >>> 43 8 1
# >>> 43 8 2
# >>> 43 8 3
# >>> 43 8 4
# >>> 43 8 5
# >>> 43 8 6
# >>> 43 8 7
# >>> 43 8 8
# >>> 43 8 9
# >>> 43 8 10
# >>> 43 8 11
# >>> 43 8 12
# >>> 43 8 13
# >>> 43 8 14
# >>> 43 8 15
# >>> 43 8 16
# >>> 43 8 17
# >>> 43 8 18
# >>> 43 8 19
# >>> 43 8 20
# >>> 43 8 21
# >>> 43 8 22
# >>> 43 9 0
# >>> 43 9 1
# >>> 43 9 2
# >>> 43 9 3
# >>> 43 9 4
# >>> 43 9 5
# >>> 43 9 6
# >>> 43 9 7
# >>> 43 9 8
# >>> 43 9 9
# >>> 43 9 10
# >>> 43 9 11
# >>> 43 9 12
# >>> 43 9 13
# >>> 43 9 14
# >>> 43 9 15
# >>> 43 9 16
# >>> 43 9 17
# >>> 43 9 18
# >>> 43 9 19
# >>> 43 9 20
# >>> 43 9 21
# >>> 43 9 22
# >>> 43 10 0
# >>> 43 10 1
# >>> 43 10 2
# >>> 43 10 3
# >>> 43 10 4
# >>> 43 10 5
# >>> 43 10 6
# >>> 43 10 7
# >>> 43 10 8
# >>> 43 10 9
# >>> 43 10 10
# >>> 43 10 11
# >>> 43 10 12
# >>> 43 10 13
# >>> 43 10 14
# >>> 43 10 15
# >>> 43 10 16
# >>> 43 10 17
# >>> 43 10 18
# >>> 43 10 19
# >>> 43 10 20
# >>> 43 10 21
# >>> 43 10 22
# >>> 43 11 0
# >>> 43 11 1
# >>> 43 11 2
# >>> 43 11 3
# >>> 43 11 4
# >>> 43 11 5
# >>> 43 11 6
# >>> 43 11 7
# >>> 43 11 8
# >>> 43 11 9
# >>> 43 11 10
# >>> 43 11 11
# >>> 43 11 12
# >>> 43 11 13
# >>> 43 11 14
# >>> 43 11 15
# >>> 43 11 16
# >>> 43 11 17
# >>> 43 11 18
# >>> 43 11 19
# >>> 43 11 20
# >>> 43 11 21
# >>> 43 11 22
# >>> 43 12 0
# >>> 43 12 1
# >>> 43 12 2
# >>> 43 12 3
# >>> 43 12 4
# >>> 43 12 5
# >>> 43 12 6
# >>> 43 12 7
# >>> 43 12 8
# >>> 43 12 9
# >>> 43 12 10
# >>> 43 12 11
# >>> 43 12 12
# >>> 43 12 13
# >>> 43 12 14
# >>> 43 12 15
# >>> 43 12 16
# >>> 43 12 17
# >>> 43 12 18
# >>> 43 12 19
# >>> 43 12 20
# >>> 43 12 21
# >>> 43 12 22
# >>> 43 13 0
# >>> 43 13 1
# >>> 43 13 2
# >>> 43 13 3
# >>> 43 13 4
# >>> 43 13 5
# >>> 43 13 6
# >>> 43 13 7
# >>> 43 13 8
# >>> 43 13 9
# >>> 43 13 10
# >>> 43 13 11
# >>> 43 13 12
# >>> 43 13 13
# >>> 43 13 14
# >>> 43 13 15
# >>> 43 13 16
# >>> 43 13 17
# >>> 43 13 18
# >>> 43 13 19
# >>> 43 13 20
# >>> 43 13 21
# >>> 43 13 22
# >>> 43 14 0
# >>> 43 14 1
# >>> 43 14 2
# >>> 43 14 3
# >>> 43 14 4
# >>> 43 14 5
# >>> 43 14 6
# >>> 43 14 7
# >>> 43 14 8
# >>> 43 14 9
# >>> 43 14 10
# >>> 43 14 11
# >>> 43 14 12
# >>> 43 14 13
# >>> 43 14 14
# >>> 43 14 15
# >>> 43 14 16
# >>> 43 14 17
# >>> 43 14 18
# >>> 43 14 19
# >>> 43 14 20
# >>> 43 14 21
# >>> 43 14 22
# >>> 44 5 0
# >>> 44 5 1
# >>> 44 5 2
# >>> 44 5 3
# >>> 44 5 4
# >>> 44 5 5
# >>> 44 5 6
# >>> 44 5 7
# >>> 44 5 8
# >>> 44 5 9
# >>> 44 5 10
# >>> 44 5 11
# >>> 44 5 12
# >>> 44 5 13
# >>> 44 5 14
# >>> 44 5 15
# >>> 44 5 16
# >>> 44 5 17
# >>> 44 5 18
# >>> 44 5 19
# >>> 44 5 20
# >>> 44 5 21
# >>> 44 5 22
# >>> 44 6 0
# >>> 44 6 1
# >>> 44 6 2
# >>> 44 6 3
# >>> 44 6 4
# >>> 44 6 5
# >>> 44 6 6
# >>> 44 6 7
# >>> 44 6 8
# >>> 44 6 9
# >>> 44 6 10
# >>> 44 6 11
# >>> 44 6 12
# >>> 44 6 13
# >>> 44 6 14
# >>> 44 6 15
# >>> 44 6 16
# >>> 44 6 17
# >>> 44 6 18
# >>> 44 6 19
# >>> 44 6 20
# >>> 44 6 21
# >>> 44 6 22
# >>> 44 7 0
# >>> 44 7 1
# >>> 44 7 2
# >>> 44 7 3
# >>> 44 7 4
# >>> 44 7 5
# >>> 44 7 6
# >>> 44 7 7
# >>> 44 7 8
# >>> 44 7 9
# >>> 44 7 10
# >>> 44 7 11
# >>> 44 7 12
# >>> 44 7 13
# >>> 44 7 14
# >>> 44 7 15
# >>> 44 7 16
# >>> 44 7 17
# >>> 44 7 18
# >>> 44 7 19
# >>> 44 7 20
# >>> 44 7 21
# >>> 44 7 22
# >>> 44 8 0
# >>> 44 8 1
# >>> 44 8 2
# >>> 44 8 3
# >>> 44 8 4
# >>> 44 8 5
# >>> 44 8 6
# >>> 44 8 7
# >>> 44 8 8
# >>> 44 8 9
# >>> 44 8 10
# >>> 44 8 11
# >>> 44 8 12
# >>> 44 8 13
# >>> 44 8 14
# >>> 44 8 15
# >>> 44 8 16
# >>> 44 8 17
# >>> 44 8 18
# >>> 44 8 19
# >>> 44 8 20
# >>> 44 8 21
# >>> 44 8 22
# >>> 44 9 0
# >>> 44 9 1
# >>> 44 9 2
# >>> 44 9 3
# >>> 44 9 4
# >>> 44 9 5
# >>> 44 9 6
# >>> 44 9 7
# >>> 44 9 8
# >>> 44 9 9
# >>> 44 9 10
# >>> 44 9 11
# >>> 44 9 12
# >>> 44 9 13
# >>> 44 9 14
# >>> 44 9 15
# >>> 44 9 16
# >>> 44 9 17
# >>> 44 9 18
# >>> 44 9 19
# >>> 44 9 20
# >>> 44 9 21
# >>> 44 9 22
# >>> 44 10 0
# >>> 44 10 1
# >>> 44 10 2
# >>> 44 10 3
# >>> 44 10 4
# >>> 44 10 5
# >>> 44 10 6
# >>> 44 10 7
# >>> 44 10 8
# >>> 44 10 9
# >>> 44 10 10
# >>> 44 10 11
# >>> 44 10 12
# >>> 44 10 13
# >>> 44 10 14
# >>> 44 10 15
# >>> 44 10 16
# >>> 44 10 17
# >>> 44 10 18
# >>> 44 10 19
# >>> 44 10 20
# >>> 44 10 21
# >>> 44 10 22
# >>> 44 11 0
# >>> 44 11 1
# >>> 44 11 2
# >>> 44 11 3
# >>> 44 11 4
# >>> 44 11 5
# >>> 44 11 6
# >>> 44 11 7
# >>> 44 11 8
# >>> 44 11 9
# >>> 44 11 10
# >>> 44 11 11
# >>> 44 11 12
# >>> 44 11 13
# >>> 44 11 14
# >>> 44 11 15
# >>> 44 11 16
# >>> 44 11 17
# >>> 44 11 18
# >>> 44 11 19
# >>> 44 11 20
# >>> 44 11 21
# >>> 44 11 22
# >>> 44 12 0
# >>> 44 12 1
# >>> 44 12 2
# >>> 44 12 3
# >>> 44 12 4
# >>> 44 12 5
# >>> 44 12 6
# >>> 44 12 7
# >>> 44 12 8
# >>> 44 12 9
# >>> 44 12 10
# >>> 44 12 11
# >>> 44 12 12
# >>> 44 12 13
# >>> 44 12 14
# >>> 44 12 15
# >>> 44 12 16
# >>> 44 12 17
# >>> 44 12 18
# >>> 44 12 19
# >>> 44 12 20
# >>> 44 12 21
# >>> 44 12 22
# >>> 44 13 0
# >>> 44 13 1
# >>> 44 13 2
# >>> 44 13 3
# >>> 44 13 4
# >>> 44 13 5
# >>> 44 13 6
# >>> 44 13 7
# >>> 44 13 8
# >>> 44 13 9
# >>> 44 13 10
# >>> 44 13 11
# >>> 44 13 12
# >>> 44 13 13
# >>> 44 13 14
# >>> 44 13 15
# >>> 44 13 16
# >>> 44 13 17
# >>> 44 13 18
# >>> 44 13 19
# >>> 44 13 20
# >>> 44 13 21
# >>> 44 13 22
# >>> 44 14 0
# >>> 44 14 1
# >>> 44 14 2
# >>> 44 14 3
# >>> 44 14 4
# >>> 44 14 5
# >>> 44 14 6
# >>> 44 14 7
# >>> 44 14 8
# >>> 44 14 9
# >>> 44 14 10
# >>> 44 14 11
# >>> 44 14 12
# >>> 44 14 13
# >>> 44 14 14
# >>> 44 14 15
# >>> 44 14 16
# >>> 44 14 17
# >>> 44 14 18
# >>> 44 14 19
# >>> 44 14 20
# >>> 44 14 21
# >>> 44 14 22
# >>> 45 5 0
# >>> 45 5 1
# >>> 45 5 2
# >>> 45 5 3
# >>> 45 5 4
# >>> 45 5 5
# >>> 45 5 6
# >>> 45 5 7
# >>> 45 5 8
# >>> 45 5 9
# >>> 45 5 10
# >>> 45 5 11
# >>> 45 5 12
# >>> 45 5 13
# >>> 45 5 14
# >>> 45 5 15
# >>> 45 5 16
# >>> 45 5 17
# >>> 45 5 18
# >>> 45 5 19
# >>> 45 5 20
# >>> 45 5 21
# >>> 45 5 22
# >>> 45 6 0
# >>> 45 6 1
# >>> 45 6 2
# >>> 45 6 3
# >>> 45 6 4
# >>> 45 6 5
# >>> 45 6 6
# >>> 45 6 7
# >>> 45 6 8
# >>> 45 6 9
# >>> 45 6 10
# >>> 45 6 11
# >>> 45 6 12
# >>> 45 6 13
# >>> 45 6 14
# >>> 45 6 15
# >>> 45 6 16
# >>> 45 6 17
# >>> 45 6 18
# >>> 45 6 19
# >>> 45 6 20
# >>> 45 6 21
# >>> 45 6 22
# >>> 45 7 0
# >>> 45 7 1
# >>> 45 7 2
# >>> 45 7 3
# >>> 45 7 4
# >>> 45 7 5
# >>> 45 7 6
# >>> 45 7 7
# >>> 45 7 8
# >>> 45 7 9
# >>> 45 7 10
# >>> 45 7 11
# >>> 45 7 12
# >>> 45 7 13
# >>> 45 7 14
# >>> 45 7 15
# >>> 45 7 16
# >>> 45 7 17
# >>> 45 7 18
# >>> 45 7 19
# >>> 45 7 20
# >>> 45 7 21
# >>> 45 7 22
# >>> 45 8 0
# >>> 45 8 1
# >>> 45 8 2
# >>> 45 8 3
# >>> 45 8 4
# >>> 45 8 5
# >>> 45 8 6
# >>> 45 8 7
# >>> 45 8 8
# >>> 45 8 9
# >>> 45 8 10
# >>> 45 8 11
# >>> 45 8 12
# >>> 45 8 13
# >>> 45 8 14
# >>> 45 8 15
# >>> 45 8 16
# >>> 45 8 17
# >>> 45 8 18
# >>> 45 8 19
# >>> 45 8 20
# >>> 45 8 21
# >>> 45 8 22
# >>> 45 9 0
# >>> 45 9 1
# >>> 45 9 2
# >>> 45 9 3
# >>> 45 9 4
# >>> 45 9 5
# >>> 45 9 6
# >>> 45 9 7
# >>> 45 9 8
# >>> 45 9 9
# >>> 45 9 10
# >>> 45 9 11
# >>> 45 9 12
# >>> 45 9 13
# >>> 45 9 14
# >>> 45 9 15
# >>> 45 9 16
# >>> 45 9 17
# >>> 45 9 18
# >>> 45 9 19
# >>> 45 9 20
# >>> 45 9 21
# >>> 45 9 22
# >>> 45 10 0
# >>> 45 10 1
# >>> 45 10 2
# >>> 45 10 3
# >>> 45 10 4
# >>> 45 10 5
# >>> 45 10 6
# >>> 45 10 7
# >>> 45 10 8
# >>> 45 10 9
# >>> 45 10 10
# >>> 45 10 11
# >>> 45 10 12
# >>> 45 10 13
# >>> 45 10 14
# >>> 45 10 15
# >>> 45 10 16
# >>> 45 10 17
# >>> 45 10 18
# >>> 45 10 19
# >>> 45 10 20
# >>> 45 10 21
# >>> 45 10 22
# >>> 45 11 0
# >>> 45 11 1
# >>> 45 11 2
# >>> 45 11 3
# >>> 45 11 4
# >>> 45 11 5
# >>> 45 11 6
# >>> 45 11 7
# >>> 45 11 8
# >>> 45 11 9
# >>> 45 11 10
# >>> 45 11 11
# >>> 45 11 12
# >>> 45 11 13
# >>> 45 11 14
# >>> 45 11 15
# >>> 45 11 16
# >>> 45 11 17
# >>> 45 11 18
# >>> 45 11 19
# >>> 45 11 20
# >>> 45 11 21
# >>> 45 11 22
# >>> 45 12 0
# >>> 45 12 1
# >>> 45 12 2
# >>> 45 12 3
# >>> 45 12 4
# >>> 45 12 5
# >>> 45 12 6
# >>> 45 12 7
# >>> 45 12 8
# >>> 45 12 9
# >>> 45 12 10
# >>> 45 12 11
# >>> 45 12 12
# >>> 45 12 13
# >>> 45 12 14
# >>> 45 12 15
# >>> 45 12 16
# >>> 45 12 17
# >>> 45 12 18
# >>> 45 12 19
# >>> 45 12 20
# >>> 45 12 21
# >>> 45 12 22
# >>> 45 13 0
# >>> 45 13 1
# >>> 45 13 2
# >>> 45 13 3
# >>> 45 13 4
# >>> 45 13 5
# >>> 45 13 6
# >>> 45 13 7
# >>> 45 13 8
# >>> 45 13 9
# >>> 45 13 10
# >>> 45 13 11
# >>> 45 13 12
# >>> 45 13 13
# >>> 45 13 14
# >>> 45 13 15
# >>> 45 13 16
# >>> 45 13 17
# >>> 45 13 18
# >>> 45 13 19
# >>> 45 13 20
# >>> 45 13 21
# >>> 45 13 22
# >>> 45 14 0
# >>> 45 14 1
# >>> 45 14 2
# >>> 45 14 3
# >>> 45 14 4
# >>> 45 14 5
# >>> 45 14 6
# >>> 45 14 7
# >>> 45 14 8
# >>> 45 14 9
# >>> 45 14 10
# >>> 45 14 11
# >>> 45 14 12
# >>> 45 14 13
# >>> 45 14 14
# >>> 45 14 15
# >>> 45 14 16
# >>> 45 14 17
# >>> 45 14 18
# >>> 45 14 19
# >>> 45 14 20
# >>> 45 14 21
# >>> 45 14 22
# >>> 46 5 0
# >>> 46 5 1
# >>> 46 5 2
# >>> 46 5 3
# >>> 46 5 4
# >>> 46 5 5
# >>> 46 5 6
# >>> 46 5 7
# >>> 46 5 8
# >>> 46 5 9
# >>> 46 5 10
# >>> 46 5 11
# >>> 46 5 12
# >>> 46 5 13
# >>> 46 5 14
# >>> 46 5 15
# >>> 46 5 16
# >>> 46 5 17
# >>> 46 5 18
# >>> 46 5 19
# >>> 46 5 20
# >>> 46 5 21
# >>> 46 5 22
# >>> 46 6 0
# >>> 46 6 1
# >>> 46 6 2
# >>> 46 6 3
# >>> 46 6 4
# >>> 46 6 5
# >>> 46 6 6
# >>> 46 6 7
# >>> 46 6 8
# >>> 46 6 9
# >>> 46 6 10
# >>> 46 6 11
# >>> 46 6 12
# >>> 46 6 13
# >>> 46 6 14
# >>> 46 6 15
# >>> 46 6 16
# >>> 46 6 17
# >>> 46 6 18
# >>> 46 6 19
# >>> 46 6 20
# >>> 46 6 21
# >>> 46 6 22
# >>> 46 7 0
# >>> 46 7 1
# >>> 46 7 2
# >>> 46 7 3
# >>> 46 7 4
# >>> 46 7 5
# >>> 46 7 6
# >>> 46 7 7
# >>> 46 7 8
# >>> 46 7 9
# >>> 46 7 10
# >>> 46 7 11
# >>> 46 7 12
# >>> 46 7 13
# >>> 46 7 14
# >>> 46 7 15
# >>> 46 7 16
# >>> 46 7 17
# >>> 46 7 18
# >>> 46 7 19
# >>> 46 7 20
# >>> 46 7 21
# >>> 46 7 22
# >>> 46 8 0
# >>> 46 8 1
# >>> 46 8 2
# >>> 46 8 3
# >>> 46 8 4
# >>> 46 8 5
# >>> 46 8 6
# >>> 46 8 7
# >>> 46 8 8
# >>> 46 8 9
# >>> 46 8 10
# >>> 46 8 11
# >>> 46 8 12
# >>> 46 8 13
# >>> 46 8 14
# >>> 46 8 15
# >>> 46 8 16
# >>> 46 8 17
# >>> 46 8 18
# >>> 46 8 19
# >>> 46 8 20
# >>> 46 8 21
# >>> 46 8 22
# >>> 46 9 0
# >>> 46 9 1
# >>> 46 9 2
# >>> 46 9 3
# >>> 46 9 4
# >>> 46 9 5
# >>> 46 9 6
# >>> 46 9 7
# >>> 46 9 8
# >>> 46 9 9
# >>> 46 9 10
# >>> 46 9 11
# >>> 46 9 12
# >>> 46 9 13
# >>> 46 9 14
# >>> 46 9 15
# >>> 46 9 16
# >>> 46 9 17
# >>> 46 9 18
# >>> 46 9 19
# >>> 46 9 20
# >>> 46 9 21
# >>> 46 9 22
# >>> 46 10 0
# >>> 46 10 1
# >>> 46 10 2
# >>> 46 10 3
# >>> 46 10 4
# >>> 46 10 5
# >>> 46 10 6
# >>> 46 10 7
# >>> 46 10 8
# >>> 46 10 9
# >>> 46 10 10
# >>> 46 10 11
# >>> 46 10 12
# >>> 46 10 13
# >>> 46 10 14
# >>> 46 10 15
# >>> 46 10 16
# >>> 46 10 17
# >>> 46 10 18
# >>> 46 10 19
# >>> 46 10 20
# >>> 46 10 21
# >>> 46 10 22
# >>> 46 11 0
# >>> 46 11 1
# >>> 46 11 2
# >>> 46 11 3
# >>> 46 11 4
# >>> 46 11 5
# >>> 46 11 6
# >>> 46 11 7
# >>> 46 11 8
# >>> 46 11 9
# >>> 46 11 10
# >>> 46 11 11
# >>> 46 11 12
# >>> 46 11 13
# >>> 46 11 14
# >>> 46 11 15
# >>> 46 11 16
# >>> 46 11 17
# >>> 46 11 18
# >>> 46 11 19
# >>> 46 11 20
# >>> 46 11 21
# >>> 46 11 22
# >>> 46 12 0
# >>> 46 12 1
# >>> 46 12 2
# >>> 46 12 3
# >>> 46 12 4
# >>> 46 12 5
# >>> 46 12 6
# >>> 46 12 7
# >>> 46 12 8
# >>> 46 12 9
# >>> 46 12 10
# >>> 46 12 11
# >>> 46 12 12
# >>> 46 12 13
# >>> 46 12 14
# >>> 46 12 15
# >>> 46 12 16
# >>> 46 12 17
# >>> 46 12 18
# >>> 46 12 19
# >>> 46 12 20
# >>> 46 12 21
# >>> 46 12 22
# >>> 46 13 0
# >>> 46 13 1
# >>> 46 13 2
# >>> 46 13 3
# >>> 46 13 4
# >>> 46 13 5
# >>> 46 13 6
# >>> 46 13 7
# >>> 46 13 8
# >>> 46 13 9
# >>> 46 13 10
# >>> 46 13 11
# >>> 46 13 12
# >>> 46 13 13
# >>> 46 13 14
# >>> 46 13 15
# >>> 46 13 16
# >>> 46 13 17
# >>> 46 13 18
# >>> 46 13 19
# >>> 46 13 20
# >>> 46 13 21
# >>> 46 13 22
# >>> 46 14 0
# >>> 46 14 1
# >>> 46 14 2
# >>> 46 14 3
# >>> 46 14 4
# >>> 46 14 5
# >>> 46 14 6
# >>> 46 14 7
# >>> 46 14 8
# >>> 46 14 9
# >>> 46 14 10
# >>> 46 14 11
# >>> 46 14 12
# >>> 46 14 13
# >>> 46 14 14
# >>> 46 14 15
# >>> 46 14 16
# >>> 46 14 17
# >>> 46 14 18
# >>> 46 14 19
# >>> 46 14 20
# >>> 46 14 21
# >>> 46 14 22
# >>> 47 5 0
# >>> 47 5 1
# >>> 47 5 2
# >>> 47 5 3
# >>> 47 5 4
# >>> 47 5 5
# >>> 47 5 6
# >>> 47 5 7
# >>> 47 5 8
# >>> 47 5 9
# >>> 47 5 10
# >>> 47 5 11
# >>> 47 5 12
# >>> 47 5 13
# >>> 47 5 14
# >>> 47 5 15
# >>> 47 5 16
# >>> 47 5 17
# >>> 47 5 18
# >>> 47 5 19
# >>> 47 5 20
# >>> 47 5 21
# >>> 47 5 22
# >>> 47 6 0
# >>> 47 6 1
# >>> 47 6 2
# >>> 47 6 3
# >>> 47 6 4
# >>> 47 6 5
# >>> 47 6 6
# >>> 47 6 7
# >>> 47 6 8
# >>> 47 6 9
# >>> 47 6 10
# >>> 47 6 11
# >>> 47 6 12
# >>> 47 6 13
# >>> 47 6 14
# >>> 47 6 15
# >>> 47 6 16
# >>> 47 6 17
# >>> 47 6 18
# >>> 47 6 19
# >>> 47 6 20
# >>> 47 6 21
# >>> 47 6 22
# >>> 47 7 0
# >>> 47 7 1
# >>> 47 7 2
# >>> 47 7 3
# >>> 47 7 4
# >>> 47 7 5
# >>> 47 7 6
# >>> 47 7 7
# >>> 47 7 8
# >>> 47 7 9
# >>> 47 7 10
# >>> 47 7 11
# >>> 47 7 12
# >>> 47 7 13
# >>> 47 7 14
# >>> 47 7 15
# >>> 47 7 16
# >>> 47 7 17
# >>> 47 7 18
# >>> 47 7 19
# >>> 47 7 20
# >>> 47 7 21
# >>> 47 7 22
# >>> 47 8 0
# >>> 47 8 1
# >>> 47 8 2
# >>> 47 8 3
# >>> 47 8 4
# >>> 47 8 5
# >>> 47 8 6
# >>> 47 8 7
# >>> 47 8 8
# >>> 47 8 9
# >>> 47 8 10
# >>> 47 8 11
# >>> 47 8 12
# >>> 47 8 13
# >>> 47 8 14
# >>> 47 8 15
# >>> 47 8 16
# >>> 47 8 17
# >>> 47 8 18
# >>> 47 8 19
# >>> 47 8 20
# >>> 47 8 21
# >>> 47 8 22
# >>> 47 9 0
# >>> 47 9 1
# >>> 47 9 2
# >>> 47 9 3
# >>> 47 9 4
# >>> 47 9 5
# >>> 47 9 6
# >>> 47 9 7
# >>> 47 9 8
# >>> 47 9 9
# >>> 47 9 10
# >>> 47 9 11
# >>> 47 9 12
# >>> 47 9 13
# >>> 47 9 14
# >>> 47 9 15
# >>> 47 9 16
# >>> 47 9 17
# >>> 47 9 18
# >>> 47 9 19
# >>> 47 9 20
# >>> 47 9 21
# >>> 47 9 22
# >>> 47 10 0
# >>> 47 10 1
# >>> 47 10 2
# >>> 47 10 3
# >>> 47 10 4
# >>> 47 10 5
# >>> 47 10 6
# >>> 47 10 7
# >>> 47 10 8
# >>> 47 10 9
# >>> 47 10 10
# >>> 47 10 11
# >>> 47 10 12
# >>> 47 10 13
# >>> 47 10 14
# >>> 47 10 15
# >>> 47 10 16
# >>> 47 10 17
# >>> 47 10 18
# >>> 47 10 19
# >>> 47 10 20
# >>> 47 10 21
# >>> 47 10 22
# >>> 47 11 0
# >>> 47 11 1
# >>> 47 11 2
# >>> 47 11 3
# >>> 47 11 4
# >>> 47 11 5
# >>> 47 11 6
# >>> 47 11 7
# >>> 47 11 8
# >>> 47 11 9
# >>> 47 11 10
# >>> 47 11 11
# >>> 47 11 12
# >>> 47 11 13
# >>> 47 11 14
# >>> 47 11 15
# >>> 47 11 16
# >>> 47 11 17
# >>> 47 11 18
# >>> 47 11 19
# >>> 47 11 20
# >>> 47 11 21
# >>> 47 11 22
# >>> 47 12 0
# >>> 47 12 1
# >>> 47 12 2
# >>> 47 12 3
# >>> 47 12 4
# >>> 47 12 5
# >>> 47 12 6
# >>> 47 12 7
# >>> 47 12 8
# >>> 47 12 9
# >>> 47 12 10
# >>> 47 12 11
# >>> 47 12 12
# >>> 47 12 13
# >>> 47 12 14
# >>> 47 12 15
# >>> 47 12 16
# >>> 47 12 17
# >>> 47 12 18
# >>> 47 12 19
# >>> 47 12 20
# >>> 47 12 21
# >>> 47 12 22
# >>> 47 13 0
# >>> 47 13 1
# >>> 47 13 2
# >>> 47 13 3
# >>> 47 13 4
# >>> 47 13 5
# >>> 47 13 6
# >>> 47 13 7
# >>> 47 13 8
# >>> 47 13 9
# >>> 47 13 10
# >>> 47 13 11
# >>> 47 13 12
# >>> 47 13 13
# >>> 47 13 14
# >>> 47 13 15
# >>> 47 13 16
# >>> 47 13 17
# >>> 47 13 18
# >>> 47 13 19
# >>> 47 13 20
# >>> 47 13 21
# >>> 47 13 22
# >>> 47 14 0
# >>> 47 14 1
# >>> 47 14 2
# >>> 47 14 3
# >>> 47 14 4
# >>> 47 14 5
# >>> 47 14 6
# >>> 47 14 7
# >>> 47 14 8
# >>> 47 14 9
# >>> 47 14 10
# >>> 47 14 11
# >>> 47 14 12
# >>> 47 14 13
# >>> 47 14 14
# >>> 47 14 15
# >>> 47 14 16
# >>> 47 14 17
# >>> 47 14 18
# >>> 47 14 19
# >>> 47 14 20
# >>> 47 14 21
# >>> 47 14 22
# >>> 48 5 0
# >>> 48 5 1
# >>> 48 5 2
# >>> 48 5 3
# >>> 48 5 4
# >>> 48 5 5
# >>> 48 5 6
# >>> 48 5 7
# >>> 48 5 8
# >>> 48 5 9
# >>> 48 5 10
# >>> 48 5 11
# >>> 48 5 12
# >>> 48 5 13
# >>> 48 5 14
# >>> 48 5 15
# >>> 48 5 16
# >>> 48 5 17
# >>> 48 5 18
# >>> 48 5 19
# >>> 48 5 20
# >>> 48 5 21
# >>> 48 5 22
# >>> 48 6 0
# >>> 48 6 1
# >>> 48 6 2
# >>> 48 6 3
# >>> 48 6 4
# >>> 48 6 5
# >>> 48 6 6
# >>> 48 6 7
# >>> 48 6 8
# >>> 48 6 9
# >>> 48 6 10
# >>> 48 6 11
# >>> 48 6 12
# >>> 48 6 13
# >>> 48 6 14
# >>> 48 6 15
# >>> 48 6 16
# >>> 48 6 17
# >>> 48 6 18
# >>> 48 6 19
# >>> 48 6 20
# >>> 48 6 21
# >>> 48 6 22
# >>> 48 7 0
# >>> 48 7 1
# >>> 48 7 2
# >>> 48 7 3
# >>> 48 7 4
# >>> 48 7 5
# >>> 48 7 6
# >>> 48 7 7
# >>> 48 7 8
# >>> 48 7 9
# >>> 48 7 10
# >>> 48 7 11
# >>> 48 7 12
# >>> 48 7 13
# >>> 48 7 14
# >>> 48 7 15
# >>> 48 7 16
# >>> 48 7 17
# >>> 48 7 18
# >>> 48 7 19
# >>> 48 7 20
# >>> 48 7 21
# >>> 48 7 22
# >>> 48 8 0
# >>> 48 8 1
# >>> 48 8 2
# >>> 48 8 3
# >>> 48 8 4
# >>> 48 8 5
# >>> 48 8 6
# >>> 48 8 7
# >>> 48 8 8
# >>> 48 8 9
# >>> 48 8 10
# >>> 48 8 11
# >>> 48 8 12
# >>> 48 8 13
# >>> 48 8 14
# >>> 48 8 15
# >>> 48 8 16
# >>> 48 8 17
# >>> 48 8 18
# >>> 48 8 19
# >>> 48 8 20
# >>> 48 8 21
# >>> 48 8 22
# >>> 48 9 0
# >>> 48 9 1
# >>> 48 9 2
# >>> 48 9 3
# >>> 48 9 4
# >>> 48 9 5
# >>> 48 9 6
# >>> 48 9 7
# >>> 48 9 8
# >>> 48 9 9
# >>> 48 9 10
# >>> 48 9 11
# >>> 48 9 12
# >>> 48 9 13
# >>> 48 9 14
# >>> 48 9 15
# >>> 48 9 16
# >>> 48 9 17
# >>> 48 9 18
# >>> 48 9 19
# >>> 48 9 20
# >>> 48 9 21
# >>> 48 9 22
# >>> 48 10 0
# >>> 48 10 1
# >>> 48 10 2
# >>> 48 10 3
# >>> 48 10 4
# >>> 48 10 5
# >>> 48 10 6
# >>> 48 10 7
# >>> 48 10 8
# >>> 48 10 9
# >>> 48 10 10
# >>> 48 10 11
# >>> 48 10 12
# >>> 48 10 13
# >>> 48 10 14
# >>> 48 10 15
# >>> 48 10 16
# >>> 48 10 17
# >>> 48 10 18
# >>> 48 10 19
# >>> 48 10 20
# >>> 48 10 21
# >>> 48 10 22
# >>> 48 11 0
# >>> 48 11 1
# >>> 48 11 2
# >>> 48 11 3
# >>> 48 11 4
# >>> 48 11 5
# >>> 48 11 6
# >>> 48 11 7
# >>> 48 11 8
# >>> 48 11 9
# >>> 48 11 10
# 0.7777777777777778 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7931034482758621
# False Positive Rate (FPR): 0.23529411764705882
# True Positive Rate (TPR) or Sensitivity: 0.7592592592592593
# False Positive Rate (FPR): 0.4
# Accuracy train: 77.78 Accuracy test: 65.77 Threshold for Number of Events: 48 Threshold for AHI: 11 lenght of data 212
# >>> 48 11 11
# >>> 48 11 12
# >>> 48 11 13
# >>> 48 11 14
# >>> 48 11 15
# >>> 48 11 16
# >>> 48 11 17
# >>> 48 11 18
# >>> 48 11 19
# >>> 48 11 20
# >>> 48 11 21
# >>> 48 11 22
# >>> 48 12 0
# >>> 48 12 1
# >>> 48 12 2
# >>> 48 12 3
# >>> 48 12 4
# >>> 48 12 5
# >>> 48 12 6
# >>> 48 12 7
# >>> 48 12 8
# >>> 48 12 9
# >>> 48 12 10
# >>> 48 12 11
# >>> 48 12 12
# >>> 48 12 13
# >>> 48 12 14
# >>> 48 12 15
# >>> 48 12 16
# KeyboardInterrupt

# %%
# dic = dic2
from sklearn.model_selection import train_test_split

best = -100
ee = 338

ss = 0
eee = 338

import numpy as np



for event_base in np.arange(10,50):
    for AHI_base in np.arange(5,15):        
        for num_1 in range(len(dic)):
            
#             print(">>>", event_base, AHI_base, num_1)
            prob = [] 
#             print(num_1)
        # on the training set the num_1 value is 6 or 7 in average
        # for num_1 in w:
            pred_label_fused = []
            for i in range(338):

        # max vote approach ################################################################
                fused_label = []
                for j in range(len(dic)):
                    fused_label.append(dic[j][i])

                if sum(fused_label) > num_1:
                    pred_label_fused.append(1)
                else:
                    pred_label_fused.append(0)

                prob.append(sum(fused_label)/len(fused_label))


            from sklearn.metrics import confusion_matrix
            import matplotlib.pyplot as plt
            from sklearn.metrics import roc_curve, auc,roc_auc_score
            import seaborn as sns


            actual_label = []
            # CUMSUM[0] starting from second data in all data(train+test)
            for i in range(0, len(CUMSUM)-2):
                actual_label.append(int(sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))


            actual_label = actual_label[-ee:]
            pred_label_fused = pred_label_fused[-ee:]

        #     print(len(actual_label), len(pred_label_fused))


            ###event base #############################################################################
            tempp_consider = np.where(np.array(tempp) > event_base, 1, 0)    
            #### AHI > THER ###########################################################################
            filtered_df = df[(df["ahi_a0h3a"] >= AHI_base) & (df["htnderv_s1"] == 0) & (df["htnderv_s2"].notnull())]
            selected_basedonAHI = [str(x[0]) for x in filtered_df[["nsrrid"]].values]
            AHI_considered = []
            for patient in file_nn:
                if patient[6:-7] in selected_basedonAHI:
                    AHI_considered.append(1)
                else:
                    AHI_considered.append(0)
            AHI_considered = np.array(AHI_considered)
            ################################################################################
            final_consider = tempp_consider&AHI_considered

            ## update ################################################################################
            Consider = [np.array(final_consider)==1][0]
            Consider = np.array(Consider[1:-1])
            Consider = Consider[-ee:]

            # update
            actual_label = np.array(actual_label)[Consider]
            pred_label_fused = np.array(pred_label_fused)[Consider]

#             print(len(actual_label), len(pred_label_fused))



            for rs in [42,47,53,72]:
                X_train, X_test, y_train, y_test = train_test_split(actual_label, pred_label_fused, test_size=0.7, random_state=rs)


                cf1 = confusion_matrix(X_train, y_train)
                cf1_test = confusion_matrix(X_test, y_test)

                lenn = len(y_train)
                lenn_test = len(y_test)

                if best < (cf1[0][0] + cf1[1][1]) / lenn:
                    print(">>>", event_base, AHI_base, num_1, rs)
                    # train
                    best_pred = pred_label_fused
                    best = (cf1[0][0] + cf1[1][1]) / lenn
                    print((cf1[0][0] + cf1[1][1]) / lenn, "num_1", num_1)
                    ax = sns.heatmap(cf1, annot=True, cmap='Blues' , fmt=".1f")
                    ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                    ax.set_xlabel('\nPredicted Values')
                    ax.set_ylabel('Actual Values ')
                    ## Ticket labels - List must be in alphabetical order
                    ax.xaxis.set_ticklabels(['False','True'])
                    ax.yaxis.set_ticklabels(['False','True'])

                    #############################################
                    # calculate True Positive Rate (TPR) or Sensitivity
                    TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
                    print('True Positive Rate (TPR) or Sensitivity:', TPR)

                    # calculate False Positive Rate (FPR)
                    FPR = cf1[0][1] / (cf1[0][1] + cf1[1][1])
                    print('False Positive Rate (FPR):', FPR)

                    #################################################
    #                 print(f"Accuracy: {best*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                    plt.show()
                    # Test #########################################3

                    best_test = (cf1_test[0][0] + cf1_test[1][1]) / lenn_test

                    ax = sns.heatmap(cf1_test, annot=True, cmap='Oranges' , fmt=".1f")
                    ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                    ax.set_xlabel('\nPredicted Values')
                    ax.set_ylabel('Actual Values ')
                    ## Ticket labels - List must be in alphabetical order
                    ax.xaxis.set_ticklabels(['False','True'])
                    ax.yaxis.set_ticklabels(['False','True'])

                    #############################################
                    # calculate True Positive Rate (TPR) or Sensitivity
                    TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
                    print('True Positive Rate (TPR) or Sensitivity:', TPR)

                    # calculate False Positive Rate (FPR)
                    FPR = cf1_test[0][1] / (cf1_test[0][1] + cf1_test[1][1])
                    print('False Positive Rate (FPR):', FPR)

                    #################################################
                    print(f"Accuracy train: {best*100:.2f}", f"Accuracy test: {best_test*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                    plt.show()
# Out:
# >>> 10 5 0 42
# 0.4752475247524752 num_1 0
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.5247524752475248
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\2051332397.py:111: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.46835443037974683
# Accuracy train: 47.52 Accuracy test: 53.16 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\2051332397.py:135: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
# >>> 10 5 0 47
# 0.5247524752475248 num_1 0
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.4752475247524752
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\2051332397.py:111: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.48945147679324896
# Accuracy train: 52.48 Accuracy test: 51.05 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\2051332397.py:135: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
# >>> 10 5 0 72
# 0.5544554455445545 num_1 0
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.44554455445544555
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\2051332397.py:111: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.5021097046413502
# Accuracy train: 55.45 Accuracy test: 49.79 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\2051332397.py:135: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
# >>> 10 5 1 72
# 0.5643564356435643 num_1 1
# True Positive Rate (TPR) or Sensitivity: 1.0
# False Positive Rate (FPR): 0.44
# True Positive Rate (TPR) or Sensitivity: 0.0
# False Positive Rate (FPR): 0.5042372881355932
# Accuracy train: 56.44 Accuracy test: 49.37 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 5 72
# 0.5841584158415841 num_1 5
# True Positive Rate (TPR) or Sensitivity: 0.6363636363636364
# False Positive Rate (FPR): 0.4222222222222222
# True Positive Rate (TPR) or Sensitivity: 0.6857142857142857
# False Positive Rate (FPR): 0.47029702970297027
# Accuracy train: 58.42 Accuracy test: 55.27 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 7 42
# 0.594059405940594 num_1 7
# True Positive Rate (TPR) or Sensitivity: 0.8
# False Positive Rate (FPR): 0.4567901234567901
# True Positive Rate (TPR) or Sensitivity: 0.5441176470588235
# False Positive Rate (FPR): 0.4378698224852071
# Accuracy train: 59.41 Accuracy test: 55.70 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 8 42
# 0.6336633663366337 num_1 8
# True Positive Rate (TPR) or Sensitivity: 0.8076923076923077
# False Positive Rate (FPR): 0.4266666666666667
# True Positive Rate (TPR) or Sensitivity: 0.5662650602409639
# False Positive Rate (FPR): 0.4155844155844156
# Accuracy train: 63.37 Accuracy test: 57.81 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 9 42
# 0.6831683168316832 num_1 9
# True Positive Rate (TPR) or Sensitivity: 0.8
# False Positive Rate (FPR): 0.3787878787878788
# True Positive Rate (TPR) or Sensitivity: 0.5876288659793815
# False Positive Rate (FPR): 0.38571428571428573
# Accuracy train: 68.32 Accuracy test: 60.34 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 5 10 42
# 0.7227722772277227 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7906976744186046
# False Positive Rate (FPR): 0.3275862068965517
# True Positive Rate (TPR) or Sensitivity: 0.6239316239316239
# False Positive Rate (FPR): 0.31666666666666665
# Accuracy train: 72.28 Accuracy test: 65.40 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> 10 6 10 42
# 0.7311827956989247 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.723404255319149
# False Positive Rate (FPR): 0.2608695652173913
# True Positive Rate (TPR) or Sensitivity: 0.65625
# False Positive Rate (FPR): 0.33064516129032256
# Accuracy train: 73.12 Accuracy test: 66.36 Threshold for Number of Events: 10 Threshold for AHI: 6 lenght of data 313
# >>> 10 6 10 47
# 0.7526881720430108 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7073170731707317
# False Positive Rate (FPR): 0.21153846153846154
# True Positive Rate (TPR) or Sensitivity: 0.6666666666666666
# False Positive Rate (FPR): 0.3559322033898305
# Accuracy train: 75.27 Accuracy test: 65.45 Threshold for Number of Events: 10 Threshold for AHI: 6 lenght of data 313
# >>> 10 7 10 53
# 0.7727272727272727 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8857142857142857
# False Positive Rate (FPR): 0.3018867924528302
# True Positive Rate (TPR) or Sensitivity: 0.6421052631578947
# False Positive Rate (FPR): 0.32432432432432434
# Accuracy train: 77.27 Accuracy test: 66.02 Threshold for Number of Events: 10 Threshold for AHI: 7 lenght of data 294
# >>> 10 8 10 47
# 0.7926829268292683 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.813953488372093
# False Positive Rate (FPR): 0.23076923076923078
# True Positive Rate (TPR) or Sensitivity: 0.6666666666666666
# False Positive Rate (FPR): 0.3652173913043478
# Accuracy train: 79.27 Accuracy test: 64.77 Threshold for Number of Events: 10 Threshold for AHI: 8 lenght of data 275
# >>> 10 12 10 47
# 0.8305084745762712 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.9
# False Positive Rate (FPR): 0.20512820512820512
# True Positive Rate (TPR) or Sensitivity: 0.7457627118644068
# False Positive Rate (FPR): 0.43037974683544306
# Accuracy train: 83.05 Accuracy test: 64.49 Threshold for Number of Events: 10 Threshold for AHI: 12 lenght of data 197
# >>> 10 12 11 47
# 0.847457627118644 num_1 11
# True Positive Rate (TPR) or Sensitivity: 0.8148148148148148
# False Positive Rate (FPR): 0.125
# True Positive Rate (TPR) or Sensitivity: 0.6865671641791045
# False Positive Rate (FPR): 0.4507042253521127
# Accuracy train: 84.75 Accuracy test: 61.59 Threshold for Number of Events: 10 Threshold for AHI: 12 lenght of data 197
# >>> 40 12 11 47
# 0.8620689655172413 num_1 11
# True Positive Rate (TPR) or Sensitivity: 0.8518518518518519
# False Positive Rate (FPR): 0.12903225806451613
# True Positive Rate (TPR) or Sensitivity: 0.6666666666666666
# False Positive Rate (FPR): 0.4444444444444444
# Accuracy train: 86.21 Accuracy test: 60.87 Threshold for Number of Events: 40 Threshold for AHI: 12 lenght of data 196
# >>> 47 12 11 47
# 0.896551724137931 num_1 11
# True Positive Rate (TPR) or Sensitivity: 0.8333333333333334
# False Positive Rate (FPR): 0.03571428571428571
# True Positive Rate (TPR) or Sensitivity: 0.6612903225806451
# False Positive Rate (FPR): 0.4666666666666667
# Accuracy train: 89.66 Accuracy test: 59.12 Threshold for Number of Events: 47 Threshold for AHI: 12 lenght of data 195

# %%
# dic = dic2
from sklearn.model_selection import train_test_split

best = -100
ee = 338

ss = 0
eee = 338
best_test = -100
import numpy as np



for event_base in [9]:
    for AHI_base in [5]:        
        for num_1 in range(len(dic)):
            
#             print(">>>", event_base, AHI_base, num_1)
            prob = [] 
#             print(num_1)
        # on the training set the num_1 value is 6 or 7 in average
        # for num_1 in w:
            pred_label_fused = []
            for i in range(338):

        # max vote approach ################################################################
                fused_label = []
                for j in range(len(dic)):
                    fused_label.append(dic[j][i])

                if sum(fused_label) > num_1:
                    pred_label_fused.append(1)
                else:
                    pred_label_fused.append(0)

                prob.append(sum(fused_label)/len(fused_label))


            from sklearn.metrics import confusion_matrix
            import matplotlib.pyplot as plt
            from sklearn.metrics import roc_curve, auc,roc_auc_score
            import seaborn as sns


            actual_label = []
            # CUMSUM[0] starting from second data in all data(train+test)
            for i in range(0, len(CUMSUM)-2):
                actual_label.append(int(sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))


            actual_label = actual_label[-ee:]
            pred_label_fused = pred_label_fused[-ee:]

        #     print(len(actual_label), len(pred_label_fused))


            ###event base #############################################################################
            tempp_consider = np.where(np.array(tempp) > event_base, 1, 0)    
            #### AHI > THER ###########################################################################
            filtered_df = df[(df["ahi_a0h3a"] >= AHI_base) & (df["htnderv_s1"] == 0) & (df["htnderv_s2"].notnull())]
            selected_basedonAHI = [str(x[0]) for x in filtered_df[["nsrrid"]].values]
            AHI_considered = []
            for patient in file_nn:
                if patient[6:-7] in selected_basedonAHI:
                    AHI_considered.append(1)
                else:
                    AHI_considered.append(0)
            AHI_considered = np.array(AHI_considered)
            ################################################################################
            final_consider = tempp_consider&AHI_considered

            ## update ################################################################################
            Consider = [np.array(final_consider)==1][0]
            Consider = np.array(Consider[1:-1])
            Consider = Consider[-ee:]

            # update
            actual_label = np.array(actual_label)[Consider]
            pred_label_fused = np.array(pred_label_fused)[Consider]

#             print(len(actual_label), len(pred_label_fused))



            for rs in np.arange(1,51):
                X_train, X_test, y_train, y_test = train_test_split(actual_label, pred_label_fused, test_size=0.85, random_state=rs)


                cf1 = confusion_matrix(X_train, y_train)
                cf1_test = confusion_matrix(X_test, y_test)

                lenn = len(y_train)
                lenn_test = len(y_test)

                if best < (cf1[0][0] + cf1[1][1]) / lenn:
#                 if best_test < (cf1_test[0][0] + cf1_test[1][1]) / lenn_test:
                    print(">>>", "event_base", event_base, "AHI_base", AHI_base, "num_1",num_1, "rs",rs)
                    # train
                    best_pred = pred_label_fused
                    best = (cf1[0][0] + cf1[1][1]) / lenn
                    print((cf1[0][0] + cf1[1][1]) / lenn, "num_1", num_1)
                    ax = sns.heatmap(cf1, annot=True, cmap='Blues' , fmt=".1f")
                    ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                    ax.set_xlabel('\nPredicted Values')
                    ax.set_ylabel('Actual Values ')
                    ## Ticket labels - List must be in alphabetical order
                    ax.xaxis.set_ticklabels(['False','True'])
                    ax.yaxis.set_ticklabels(['False','True'])

                    #############################################
                    # calculate True Positive Rate (TPR) or Sensitivity
                    TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
                    print('True Positive Rate (TPR) or Sensitivity:', TPR)

                    # calculate False Positive Rate (FPR)
                    FPR = cf1[0][1] / (cf1[0][1] + cf1[1][1])
                    print('False Positive Rate (FPR):', FPR)

                    #################################################
    #                 print(f"Accuracy: {best*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                    plt.show()
                    # Test #########################################3

                    best_test = (cf1_test[0][0] + cf1_test[1][1]) / lenn_test

                    ax = sns.heatmap(cf1_test, annot=True, cmap='Oranges' , fmt=".1f")
                    ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                    ax.set_xlabel('\nPredicted Values')
                    ax.set_ylabel('Actual Values ')
                    ## Ticket labels - List must be in alphabetical order
                    ax.xaxis.set_ticklabels(['False','True'])
                    ax.yaxis.set_ticklabels(['False','True'])

                    #############################################
                    # calculate True Positive Rate (TPR) or Sensitivity
                    TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
                    print('True Positive Rate (TPR) or Sensitivity:', TPR)

                    # calculate False Positive Rate (FPR)
                    FPR = cf1_test[0][1] / (cf1_test[0][1] + cf1_test[1][1])
                    print('False Positive Rate (FPR):', FPR)

                    #################################################
                    print(f"Accuracy train: {best*100:.2f}", f"Accuracy test: {best_test*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                    plt.show()
# Out:
# >>> event_base 9 AHI_base 5 num_1 0 rs 1
# 0.46 num_1 0
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.54
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\3425075269.py:112: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.4756944444444444
# Accuracy train: 46.00 Accuracy test: 52.43 Threshold for Number of Events: 9 Threshold for AHI: 5 lenght of data 338
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\3425075269.py:136: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
# >>> event_base 9 AHI_base 5 num_1 0 rs 3
# 0.58 num_1 0
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.42
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\3425075269.py:112: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.4965277777777778
# Accuracy train: 58.00 Accuracy test: 50.35 Threshold for Number of Events: 9 Threshold for AHI: 5 lenght of data 338
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\3425075269.py:136: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
# >>> event_base 9 AHI_base 5 num_1 0 rs 8
# 0.6 num_1 0
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.4
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\3425075269.py:112: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.5
# Accuracy train: 60.00 Accuracy test: 50.00 Threshold for Number of Events: 9 Threshold for AHI: 5 lenght of data 338
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\3425075269.py:136: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
# >>> event_base 9 AHI_base 5 num_1 0 rs 40
# 0.66 num_1 0
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.34
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\3425075269.py:112: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
# True Positive Rate (TPR) or Sensitivity: nan
# False Positive Rate (FPR): 0.5104166666666666
# Accuracy train: 66.00 Accuracy test: 48.96 Threshold for Number of Events: 9 Threshold for AHI: 5 lenght of data 338
# C:\Users\Bpradsad\AppData\Local\Temp\ipykernel_18332\3425075269.py:136: RuntimeWarning: invalid value encountered in longlong_scalars
#   TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
# >>> event_base 9 AHI_base 5 num_1 3 rs 40
# 0.68 num_1 3
# True Positive Rate (TPR) or Sensitivity: 1.0
# False Positive Rate (FPR): 0.32653061224489793
# True Positive Rate (TPR) or Sensitivity: 0.5
# False Positive Rate (FPR): 0.5109489051094891
# Accuracy train: 68.00 Accuracy test: 48.96 Threshold for Number of Events: 9 Threshold for AHI: 5 lenght of data 338
# >>> event_base 9 AHI_base 5 num_1 5 rs 40
# 0.72 num_1 5
# True Positive Rate (TPR) or Sensitivity: 0.8
# False Positive Rate (FPR): 0.28888888888888886
# True Positive Rate (TPR) or Sensitivity: 0.6585365853658537
# False Positive Rate (FPR): 0.48582995951417
# Accuracy train: 72.00 Accuracy test: 53.47 Threshold for Number of Events: 9 Threshold for AHI: 5 lenght of data 338
# >>> event_base 9 AHI_base 5 num_1 8 rs 34
# 0.76 num_1 8
# True Positive Rate (TPR) or Sensitivity: 0.7368421052631579
# False Positive Rate (FPR): 0.22580645161290322
# True Positive Rate (TPR) or Sensitivity: 0.6
# False Positive Rate (FPR): 0.4494949494949495
# Accuracy train: 76.00 Accuracy test: 56.60 Threshold for Number of Events: 9 Threshold for AHI: 5 lenght of data 338
# >>> event_base 9 AHI_base 5 num_1 9 rs 34
# 0.78 num_1 9
# True Positive Rate (TPR) or Sensitivity: 0.7272727272727273
# False Positive Rate (FPR): 0.17857142857142858
# True Positive Rate (TPR) or Sensitivity: 0.6272727272727273
# False Positive Rate (FPR): 0.4157303370786517
# Accuracy train: 78.00 Accuracy test: 60.07 Threshold for Number of Events: 9 Threshold for AHI: 5 lenght of data 338
# >>> event_base 9 AHI_base 5 num_1 10 rs 4
# 0.8 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8571428571428571
# False Positive Rate (FPR): 0.2727272727272727
# True Positive Rate (TPR) or Sensitivity: 0.6287878787878788
# False Positive Rate (FPR): 0.3269230769230769
# Accuracy train: 80.00 Accuracy test: 65.28 Threshold for Number of Events: 9 Threshold for AHI: 5 lenght of data 338

# %%
# dic = dic2
from sklearn.model_selection import train_test_split

best = -100
ee = 338

ss = 0
eee = 338
best_test = -100
import numpy as np



for event_base in [9]:
    for AHI_base in [5]:        
        for num_1 in [10]:
            
#             print(">>>", event_base, AHI_base, num_1)
            prob = [] 
#             print(num_1)
        # on the training set the num_1 value is 6 or 7 in average
        # for num_1 in w:
            pred_label_fused = []
            for i in range(338):

        # max vote approach ################################################################
                fused_label = []
                for j in range(len(dic)):
                    fused_label.append(dic[j][i])

                if sum(fused_label) > num_1:
                    pred_label_fused.append(1)
                else:
                    pred_label_fused.append(0)

                prob.append(sum(fused_label)/len(fused_label))


            from sklearn.metrics import confusion_matrix
            import matplotlib.pyplot as plt
            from sklearn.metrics import roc_curve, auc,roc_auc_score
            import seaborn as sns


            actual_label = []
            # CUMSUM[0] starting from second data in all data(train+test)
            for i in range(0, len(CUMSUM)-2):
                actual_label.append(int(sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))


            actual_label = actual_label[-ee:]
            pred_label_fused = pred_label_fused[-ee:]

        #     print(len(actual_label), len(pred_label_fused))


            ###event base #############################################################################
            tempp_consider = np.where(np.array(tempp) > event_base, 1, 0)    
            #### AHI > THER ###########################################################################
            filtered_df = df[(df["ahi_a0h3a"] >= AHI_base) & (df["htnderv_s1"] == 0) & (df["htnderv_s2"].notnull())]
            selected_basedonAHI = [str(x[0]) for x in filtered_df[["nsrrid"]].values]
            AHI_considered = []
            for patient in file_nn:
                if patient[6:-7] in selected_basedonAHI:
                    AHI_considered.append(1)
                else:
                    AHI_considered.append(0)
            AHI_considered = np.array(AHI_considered)
            ################################################################################
            final_consider = tempp_consider&AHI_considered

            ## update ################################################################################
            Consider = [np.array(final_consider)==1][0]
            Consider = np.array(Consider[1:-1])
            Consider = Consider[-ee:]

            # update
            actual_label = np.array(actual_label)[Consider]
            pred_label_fused = np.array(pred_label_fused)[Consider]

#             print(len(actual_label), len(pred_label_fused))



            for rs in np.arange(10,330):
#                 X_train, X_test, y_train, y_test = train_test_split(actual_label, pred_label_fused, test_size=0.85, random_state=rs)
#                 X_train, X_test, y_train, y_test = actual_label[0:100], actual_label[100:300], pred_label_fused[0:100], pred_label_fused[100:300]
#                 X_train, X_test, y_train, y_test = actual_label[200:300], actual_label[0:200], pred_label_fused[200:300], pred_label_fused[0:200]
                X_train, X_test, y_train, y_test = actual_label[100:200], list(actual_label[0:100])+list(actual_label[200:300]), pred_label_fused[100:200],list(pred_label_fused[0:100])+list(pred_label_fused[200:300]) 

    #                 X_train, X_test, y_train, y_test = actual_label[rs:], actual_label[:rs], pred_label_fused[rs:], pred_label_fused[:rs]

                cf1 = confusion_matrix(X_train, y_train)
                cf1_test = confusion_matrix(X_test, y_test)

                lenn = len(y_train)
                lenn_test = len(y_test)

                if best < (cf1[0][0] + cf1[1][1]) / lenn:
#                 if best_test < (cf1_test[0][0] + cf1_test[1][1]) / lenn_test:
                    print(">>>", "event_base", event_base, "AHI_base", AHI_base, "num_1",num_1, "rs",rs)
                    # train
                    best_pred = pred_label_fused
                    best = (cf1[0][0] + cf1[1][1]) / lenn
                    print((cf1[0][0] + cf1[1][1]) / lenn, "num_1", num_1)
                    ax = sns.heatmap(cf1, annot=True, cmap='Blues' , fmt=".1f")
                    ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                    ax.set_xlabel('\nPredicted Values')
                    ax.set_ylabel('Actual Values ')
                    ## Ticket labels - List must be in alphabetical order
                    ax.xaxis.set_ticklabels(['False','True'])
                    ax.yaxis.set_ticklabels(['False','True'])

                    #############################################
                    # calculate True Positive Rate (TPR) or Sensitivity
                    TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
                    print('True Positive Rate (TPR) or Sensitivity:', TPR)

                    # calculate False Positive Rate (FPR)
                    FPR = cf1[0][1] / (cf1[0][1] + cf1[1][1])
                    print('False Positive Rate (FPR):', FPR)

                    #################################################
    #                 print(f"Accuracy: {best*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                    plt.show()
                    # Test #########################################3

                    best_test = (cf1_test[0][0] + cf1_test[1][1]) / lenn_test

                    ax = sns.heatmap(cf1_test, annot=True, cmap='Oranges' , fmt=".1f")
                    ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                    ax.set_xlabel('\nPredicted Values')
                    ax.set_ylabel('Actual Values ')
                    ## Ticket labels - List must be in alphabetical order
                    ax.xaxis.set_ticklabels(['False','True'])
                    ax.yaxis.set_ticklabels(['False','True'])

                    #############################################
                    # calculate True Positive Rate (TPR) or Sensitivity
                    TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
                    print('True Positive Rate (TPR) or Sensitivity:', TPR)

                    # calculate False Positive Rate (FPR)
                    FPR = cf1_test[0][1] / (cf1_test[0][1] + cf1_test[1][1])
                    print('False Positive Rate (FPR):', FPR)

                    #################################################
                    print(f"Accuracy train: {best*100:.2f}", f"Accuracy test: {best_test*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                    plt.show()
# Out:
# >>> event_base 9 AHI_base 5 num_1 10 rs 10
# 0.66 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.6739130434782609
# False Positive Rate (FPR): 0.35185185185185186
# True Positive Rate (TPR) or Sensitivity: 0.6875
# False Positive Rate (FPR): 0.3269230769230769
# Accuracy train: 66.00 Accuracy test: 68.00 Threshold for Number of Events: 9 Threshold for AHI: 5 lenght of data 338

# %%
# dic = dic2
from sklearn.model_selection import train_test_split

best = -100
ee = 338

ss = 0
eee = 338
best_test = -100
import numpy as np



for event_base in np.arange(10,100):
    for AHI_base in np.arange(5,15):        
        for num_1 in [10]:
            
#             print(">>>", event_base, AHI_base, num_1)
            prob = [] 
#             print(num_1)
        # on the training set the num_1 value is 6 or 7 in average
        # for num_1 in w:
            pred_label_fused = []
            for i in range(338):

        # max vote approach ################################################################
                fused_label = []
                for j in range(len(dic)):
                    fused_label.append(dic[j][i])

                if sum(fused_label) > num_1:
                    pred_label_fused.append(1)
                else:
                    pred_label_fused.append(0)

                prob.append(sum(fused_label)/len(fused_label))


            from sklearn.metrics import confusion_matrix
            import matplotlib.pyplot as plt
            from sklearn.metrics import roc_curve, auc,roc_auc_score
            import seaborn as sns


            actual_label = []
            # CUMSUM[0] starting from second data in all data(train+test)
            for i in range(0, len(CUMSUM)-2):
                actual_label.append(int(sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))


            actual_label = actual_label[-ee:]
            pred_label_fused = pred_label_fused[-ee:]

        #     print(len(actual_label), len(pred_label_fused))


            ###event base #############################################################################
            tempp_consider = np.where(np.array(tempp) > event_base, 1, 0)    
            #### AHI > THER ###########################################################################
            filtered_df = df[(df["ahi_a0h3a"] >= AHI_base) & (df["htnderv_s1"] == 0) & (df["htnderv_s2"].notnull())]
            selected_basedonAHI = [str(x[0]) for x in filtered_df[["nsrrid"]].values]
            AHI_considered = []
            for patient in file_nn:
                if patient[6:-7] in selected_basedonAHI:
                    AHI_considered.append(1)
                else:
                    AHI_considered.append(0)
            AHI_considered = np.array(AHI_considered)
            ################################################################################
            final_consider = tempp_consider&AHI_considered

            ## update ################################################################################
            Consider = [np.array(final_consider)==1][0]
            Consider = np.array(Consider[1:-1])
            Consider = Consider[-ee:]

            # update
            actual_label = np.array(actual_label)[Consider]
            pred_label_fused = np.array(pred_label_fused)[Consider]

#             print(len(actual_label), len(pred_label_fused))




#                 X_train, X_test, y_train, y_test = train_test_split(actual_label, pred_label_fused, test_size=0.85, random_state=rs)
#                 X_train, X_test, y_train, y_test = actual_label[0:100], actual_label[100:300], pred_label_fused[0:100], pred_label_fused[100:300]
#                 X_train, X_test, y_train, y_test = actual_label[200:300], actual_label[0:200], pred_label_fused[200:300], pred_label_fused[0:200]
            X_train, X_test, y_train, y_test = actual_label[100:200], list(actual_label[0:100])+list(actual_label[200:300]), pred_label_fused[100:200],list(pred_label_fused[0:100])+list(pred_label_fused[200:300]) 

#                 X_train, X_test, y_train, y_test = actual_label[rs:], actual_label[:rs], pred_label_fused[rs:], pred_label_fused[:rs]

            cf1 = confusion_matrix(X_train, y_train)
            cf1_test = confusion_matrix(X_test, y_test)

            lenn = len(y_train)
            lenn_test = len(y_test)

            if best < (cf1[0][0] + cf1[1][1]) / lenn:
#                 if best_test < (cf1_test[0][0] + cf1_test[1][1]) / lenn_test:
                print(">>>", "event_base", event_base, "AHI_base", AHI_base, "num_1",num_1, "rs",rs)
                # train
                best_pred = pred_label_fused
                best = (cf1[0][0] + cf1[1][1]) / lenn
                print((cf1[0][0] + cf1[1][1]) / lenn, "num_1", num_1)
                ax = sns.heatmap(cf1, annot=True, cmap='Blues' , fmt=".1f")
                ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                ax.set_xlabel('\nPredicted Values')
                ax.set_ylabel('Actual Values ')
                ## Ticket labels - List must be in alphabetical order
                ax.xaxis.set_ticklabels(['False','True'])
                ax.yaxis.set_ticklabels(['False','True'])

                #############################################
                # calculate True Positive Rate (TPR) or Sensitivity
                TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
                print('True Positive Rate (TPR) or Sensitivity:', TPR)

                # calculate False Positive Rate (FPR)
                FPR = cf1[0][1] / (cf1[0][1] + cf1[1][1])
                print('False Positive Rate (FPR):', FPR)

                #################################################
#                 print(f"Accuracy: {best*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                plt.show()
                # Test #########################################3

                best_test = (cf1_test[0][0] + cf1_test[1][1]) / lenn_test

                ax = sns.heatmap(cf1_test, annot=True, cmap='Oranges' , fmt=".1f")
                ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                ax.set_xlabel('\nPredicted Values')
                ax.set_ylabel('Actual Values ')
                ## Ticket labels - List must be in alphabetical order
                ax.xaxis.set_ticklabels(['False','True'])
                ax.yaxis.set_ticklabels(['False','True'])

                #############################################
                # calculate True Positive Rate (TPR) or Sensitivity
                TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
                print('True Positive Rate (TPR) or Sensitivity:', TPR)

                # calculate False Positive Rate (FPR)
                FPR = cf1_test[0][1] / (cf1_test[0][1] + cf1_test[1][1])
                print('False Positive Rate (FPR):', FPR)

                #################################################
                print(f"Accuracy train: {best*100:.2f}", f"Accuracy test: {best_test*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                plt.show()
# Out:
# >>> event_base 10 AHI_base 5 num_1 10 rs 329
# 0.66 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.6739130434782609
# False Positive Rate (FPR): 0.35185185185185186
# True Positive Rate (TPR) or Sensitivity: 0.6875
# False Positive Rate (FPR): 0.3269230769230769
# Accuracy train: 66.00 Accuracy test: 68.00 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> event_base 10 AHI_base 6 num_1 10 rs 329
# 0.73 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7659574468085106
# False Positive Rate (FPR): 0.3018867924528302
# True Positive Rate (TPR) or Sensitivity: 0.6373626373626373
# False Positive Rate (FPR): 0.3394495412844037
# Accuracy train: 73.00 Accuracy test: 65.00 Threshold for Number of Events: 10 Threshold for AHI: 6 lenght of data 313
# >>> event_base 10 AHI_base 9 num_1 10 rs 329
# 0.74 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8421052631578947
# False Positive Rate (FPR): 0.3225806451612903
# True Positive Rate (TPR) or Sensitivity: 0.684931506849315
# False Positive Rate (FPR): 0.3488372093023256
# Accuracy train: 74.00 Accuracy test: 66.67 Threshold for Number of Events: 10 Threshold for AHI: 9 lenght of data 259
# >>> event_base 57 AHI_base 6 num_1 10 rs 329
# 0.75 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8
# False Positive Rate (FPR): 0.2909090909090909
# True Positive Rate (TPR) or Sensitivity: 0.6179775280898876
# False Positive Rate (FPR): 0.3333333333333333
# Accuracy train: 75.00 Accuracy test: 64.50 Threshold for Number of Events: 57 Threshold for AHI: 6 lenght of data 303
# >>> event_base 74 AHI_base 6 num_1 10 rs 329
# 0.76 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8292682926829268
# False Positive Rate (FPR): 0.288135593220339
# True Positive Rate (TPR) or Sensitivity: 0.6447368421052632
# False Positive Rate (FPR): 0.3302752293577982
# Accuracy train: 76.00 Accuracy test: 65.95 Threshold for Number of Events: 74 Threshold for AHI: 6 lenght of data 285

# %%
# dic = dic2
from sklearn.model_selection import train_test_split

best = -100
ee = 338

ss = 0
eee = 338
best_test = -100
import numpy as np



for event_base in np.arange(10,100):
    for AHI_base in np.arange(5,15):        
        for num_1 in [10]:
            
#             print(">>>", event_base, AHI_base, num_1)
            prob = [] 
#             print(num_1)
        # on the training set the num_1 value is 6 or 7 in average
        # for num_1 in w:
            pred_label_fused = []
            for i in range(338):

        # max vote approach ################################################################
                fused_label = []
                for j in range(len(dic)):
                    fused_label.append(dic[j][i])

                if sum(fused_label) > num_1:
                    pred_label_fused.append(1)
                else:
                    pred_label_fused.append(0)

                prob.append(sum(fused_label)/len(fused_label))


            from sklearn.metrics import confusion_matrix
            import matplotlib.pyplot as plt
            from sklearn.metrics import roc_curve, auc,roc_auc_score
            import seaborn as sns


            actual_label = []
            # CUMSUM[0] starting from second data in all data(train+test)
            for i in range(0, len(CUMSUM)-2):
                actual_label.append(int(sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))


            actual_label = actual_label[-ee:]
            pred_label_fused = pred_label_fused[-ee:]

        #     print(len(actual_label), len(pred_label_fused))


            ###event base #############################################################################
            tempp_consider = np.where(np.array(tempp) > event_base, 1, 0)    
            #### AHI > THER ###########################################################################
            filtered_df = df[(df["ahi_a0h3a"] >= AHI_base) & (df["htnderv_s1"] == 0) & (df["htnderv_s2"].notnull())]
            selected_basedonAHI = [str(x[0]) for x in filtered_df[["nsrrid"]].values]
            AHI_considered = []
            for patient in file_nn:
                if patient[6:-7] in selected_basedonAHI:
                    AHI_considered.append(1)
                else:
                    AHI_considered.append(0)
            AHI_considered = np.array(AHI_considered)
            ################################################################################
            final_consider = tempp_consider&AHI_considered

            ## update ################################################################################
            Consider = [np.array(final_consider)==1][0]
            Consider = np.array(Consider[1:-1])
            Consider = Consider[-ee:]

            # update
            actual_label = np.array(actual_label)[Consider]
            pred_label_fused = np.array(pred_label_fused)[Consider]

#             print(len(actual_label), len(pred_label_fused))




#                 X_train, X_test, y_train, y_test = train_test_split(actual_label, pred_label_fused, test_size=0.85, random_state=rs)
#                 X_train, X_test, y_train, y_test = actual_label[0:100], actual_label[100:300], pred_label_fused[0:100], pred_label_fused[100:300]
#             X_train, X_test, y_train, y_test = actual_label[200:300], actual_label[0:200], pred_label_fused[200:300], pred_label_fused[0:200]
#             X_train, X_test, y_train, y_test = actual_label[100:200], list(actual_label[0:100])+list(actual_label[200:300]), pred_label_fused[100:200],list(pred_label_fused[0:100])+list(pred_label_fused[200:300]) 
#             X_train, X_test, y_train, y_test = actual_label[0:int(.33*len(actual_label))], actual_label[int(.33*len(actual_label)):300], pred_label_fused[0:int(.33*len(actual_label))], pred_label_fused[int(.33*len(actual_label)):300]
#             X_train, X_test, y_train, y_test = actual_label[200:300], actual_label[0:200], pred_label_fused[200:300], pred_label_fused[0:200]
            X_train, X_test, y_train, y_test = actual_label[int(.33*len(actual_label)):int(.66*len(actual_label))], list(actual_label[0:int(.33*len(actual_label))])+list(actual_label[int(.66*len(actual_label)):300]), pred_label_fused[int(.33*len(actual_label)):int(.66*len(actual_label))],list(pred_label_fused[0:int(.33*len(actual_label))])+list(pred_label_fused[int(.66*len(actual_label)):300]) 

#                 X_train, X_test, y_train, y_test = actual_label[rs:], actual_label[:rs], pred_label_fused[rs:], pred_label_fused[:rs]

            cf1 = confusion_matrix(X_train, y_train)
            cf1_test = confusion_matrix(X_test, y_test)

            lenn = len(y_train)
            lenn_test = len(y_test)

            if best < (cf1[0][0] + cf1[1][1]) / lenn:
#                 if best_test < (cf1_test[0][0] + cf1_test[1][1]) / lenn_test:
                print(">>>", "event_base", event_base, "AHI_base", AHI_base, "num_1",num_1, "rs",rs)
                # train
                best_pred = pred_label_fused
                best = (cf1[0][0] + cf1[1][1]) / lenn
                print((cf1[0][0] + cf1[1][1]) / lenn, "num_1", num_1)
                ax = sns.heatmap(cf1, annot=True, cmap='Blues' , fmt=".1f")
                ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                ax.set_xlabel('\nPredicted Values')
                ax.set_ylabel('Actual Values ')
                ## Ticket labels - List must be in alphabetical order
                ax.xaxis.set_ticklabels(['False','True'])
                ax.yaxis.set_ticklabels(['False','True'])

                #############################################
                # calculate True Positive Rate (TPR) or Sensitivity
                TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
                print('True Positive Rate (TPR) or Sensitivity:', TPR)

                # calculate False Positive Rate (FPR)
                FPR = cf1[0][1] / (cf1[0][1] + cf1[1][1])
                print('False Positive Rate (FPR):', FPR)

                #################################################
#                 print(f"Accuracy: {best*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                plt.show()
                # Test #########################################3

                best_test = (cf1_test[0][0] + cf1_test[1][1]) / lenn_test

                ax = sns.heatmap(cf1_test, annot=True, cmap='Oranges' , fmt=".1f")
                ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                ax.set_xlabel('\nPredicted Values')
                ax.set_ylabel('Actual Values ')
                ## Ticket labels - List must be in alphabetical order
                ax.xaxis.set_ticklabels(['False','True'])
                ax.yaxis.set_ticklabels(['False','True'])

                #############################################
                # calculate True Positive Rate (TPR) or Sensitivity
                TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
                print('True Positive Rate (TPR) or Sensitivity:', TPR)

                # calculate False Positive Rate (FPR)
                FPR = cf1_test[0][1] / (cf1_test[0][1] + cf1_test[1][1])
                print('False Positive Rate (FPR):', FPR)

                #################################################
                print(f"Accuracy train: {best*100:.2f}", f"Accuracy test: {best_test*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                plt.show()
# Out:
# >>> event_base 10 AHI_base 5 num_1 10 rs 329
# 0.6964285714285714 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7222222222222222
# False Positive Rate (FPR): 0.3275862068965517
# True Positive Rate (TPR) or Sensitivity: 0.6590909090909091
# False Positive Rate (FPR): 0.34
# Accuracy train: 69.64 Accuracy test: 65.96 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> event_base 10 AHI_base 6 num_1 10 rs 329
# 0.7378640776699029 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7755102040816326
# False Positive Rate (FPR): 0.2962962962962963
# True Positive Rate (TPR) or Sensitivity: 0.6292134831460674
# False Positive Rate (FPR): 0.3425925925925926
# Accuracy train: 73.79 Accuracy test: 64.47 Threshold for Number of Events: 10 Threshold for AHI: 6 lenght of data 313
# >>> event_base 43 AHI_base 6 num_1 10 rs 329
# 0.7450980392156863 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7872340425531915
# False Positive Rate (FPR): 0.2909090909090909
# True Positive Rate (TPR) or Sensitivity: 0.6373626373626373
# False Positive Rate (FPR): 0.34579439252336447
# Accuracy train: 74.51 Accuracy test: 64.65 Threshold for Number of Events: 43 Threshold for AHI: 6 lenght of data 310
# >>> event_base 60 AHI_base 6 num_1 10 rs 329
# 0.7474747474747475 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7954545454545454
# False Positive Rate (FPR): 0.2909090909090909
# True Positive Rate (TPR) or Sensitivity: 0.625
# False Positive Rate (FPR): 0.3274336283185841
# Accuracy train: 74.75 Accuracy test: 65.17 Threshold for Number of Events: 60 Threshold for AHI: 6 lenght of data 300
# >>> event_base 75 AHI_base 9 num_1 10 rs 329
# 0.7564102564102564 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8666666666666667
# False Positive Rate (FPR): 0.3125
# True Positive Rate (TPR) or Sensitivity: 0.6949152542372882
# False Positive Rate (FPR): 0.35353535353535354
# Accuracy train: 75.64 Accuracy test: 66.46 Threshold for Number of Events: 75 Threshold for AHI: 9 lenght of data 236
# >>> event_base 88 AHI_base 6 num_1 10 rs 329
# 0.7586206896551724 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8235294117647058
# False Positive Rate (FPR): 0.2830188679245283
# True Positive Rate (TPR) or Sensitivity: 0.6461538461538462
# False Positive Rate (FPR): 0.33035714285714285
# Accuracy train: 75.86 Accuracy test: 66.10 Threshold for Number of Events: 88 Threshold for AHI: 6 lenght of data 264

# %%
# dic = dic2
from sklearn.model_selection import train_test_split

best = -100
ee = 338

ss = 0
eee = 338
best_test = -100
import numpy as np



for event_base in np.arange(10,100):
    for AHI_base in np.arange(5,15):        
        for num_1 in [10]:
            
#             print(">>>", event_base, AHI_base, num_1)
            prob = [] 
#             print(num_1)
        # on the training set the num_1 value is 6 or 7 in average
        # for num_1 in w:
            pred_label_fused = []
            for i in range(338):

        # max vote approach ################################################################
                fused_label = []
                for j in range(len(dic)):
                    fused_label.append(dic[j][i])

                if sum(fused_label) > num_1:
                    pred_label_fused.append(1)
                else:
                    pred_label_fused.append(0)

                prob.append(sum(fused_label)/len(fused_label))


            from sklearn.metrics import confusion_matrix
            import matplotlib.pyplot as plt
            from sklearn.metrics import roc_curve, auc,roc_auc_score
            import seaborn as sns


            actual_label = []
            # CUMSUM[0] starting from second data in all data(train+test)
            for i in range(0, len(CUMSUM)-2):
                actual_label.append(int(sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))


            actual_label = actual_label[-ee:]
            pred_label_fused = pred_label_fused[-ee:]

        #     print(len(actual_label), len(pred_label_fused))


            ###event base #############################################################################
            tempp_consider = np.where(np.array(tempp) > event_base, 1, 0)    
            #### AHI > THER ###########################################################################
            filtered_df = df[(df["ahi_a0h3a"] >= AHI_base) & (df["htnderv_s1"] == 0) & (df["htnderv_s2"].notnull())]
            selected_basedonAHI = [str(x[0]) for x in filtered_df[["nsrrid"]].values]
            AHI_considered = []
            for patient in file_nn:
                if patient[6:-7] in selected_basedonAHI:
                    AHI_considered.append(1)
                else:
                    AHI_considered.append(0)
            AHI_considered = np.array(AHI_considered)
            ################################################################################
            final_consider = tempp_consider&AHI_considered

            ## update ################################################################################
            Consider = [np.array(final_consider)==1][0]
            Consider = np.array(Consider[1:-1])
            Consider = Consider[-ee:]

            # update
            actual_label = np.array(actual_label)[Consider]
            pred_label_fused = np.array(pred_label_fused)[Consider]

#             print(len(actual_label), len(pred_label_fused))




#                 X_train, X_test, y_train, y_test = train_test_split(actual_label, pred_label_fused, test_size=0.85, random_state=rs)
#                 X_train, X_test, y_train, y_test = actual_label[0:100], actual_label[100:300], pred_label_fused[0:100], pred_label_fused[100:300]
#             X_train, X_test, y_train, y_test = actual_label[200:300], actual_label[0:200], pred_label_fused[200:300], pred_label_fused[0:200]
#             X_train, X_test, y_train, y_test = actual_label[100:200], list(actual_label[0:100])+list(actual_label[200:300]), pred_label_fused[100:200],list(pred_label_fused[0:100])+list(pred_label_fused[200:300]) 
            X_train, X_test, y_train, y_test = actual_label[0:int(.33*len(actual_label))], actual_label[int(.33*len(actual_label)):300], pred_label_fused[0:int(.33*len(actual_label))], pred_label_fused[int(.33*len(actual_label)):300]
#             X_train, X_test, y_train, y_test = actual_label[200:300], actual_label[0:200], pred_label_fused[200:300], pred_label_fused[0:200]
#             X_train, X_test, y_train, y_test = actual_label[int(.33*len(actual_label)):int(.66*len(actual_label))], list(actual_label[0:int(.33*len(actual_label))])+list(actual_label[int(.66*len(actual_label)):300]), pred_label_fused[int(.33*len(actual_label)):int(.66*len(actual_label))],list(pred_label_fused[0:int(.33*len(actual_label))])+list(pred_label_fused[int(.66*len(actual_label)):300]) 

#                 X_train, X_test, y_train, y_test = actual_label[rs:], actual_label[:rs], pred_label_fused[rs:], pred_label_fused[:rs]

            cf1 = confusion_matrix(X_train, y_train)
            cf1_test = confusion_matrix(X_test, y_test)

            lenn = len(y_train)
            lenn_test = len(y_test)

            if best < (cf1[0][0] + cf1[1][1]) / lenn:
#                 if best_test < (cf1_test[0][0] + cf1_test[1][1]) / lenn_test:
                print(">>>", "event_base", event_base, "AHI_base", AHI_base, "num_1",num_1, "rs",rs)
                # train
                best_pred = pred_label_fused
                best = (cf1[0][0] + cf1[1][1]) / lenn
                print((cf1[0][0] + cf1[1][1]) / lenn, "num_1", num_1)
                ax = sns.heatmap(cf1, annot=True, cmap='Blues' , fmt=".1f")
                ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                ax.set_xlabel('\nPredicted Values')
                ax.set_ylabel('Actual Values ')
                ## Ticket labels - List must be in alphabetical order
                ax.xaxis.set_ticklabels(['False','True'])
                ax.yaxis.set_ticklabels(['False','True'])

                #############################################
                # calculate True Positive Rate (TPR) or Sensitivity
                TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
                print('True Positive Rate (TPR) or Sensitivity:', TPR)

                # calculate False Positive Rate (FPR)
                FPR = cf1[0][1] / (cf1[0][1] + cf1[1][1])
                print('False Positive Rate (FPR):', FPR)

                #################################################
#                 print(f"Accuracy: {best*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                plt.show()
                # Test #########################################3

                best_test = (cf1_test[0][0] + cf1_test[1][1]) / lenn_test

                ax = sns.heatmap(cf1_test, annot=True, cmap='Oranges' , fmt=".1f")
                ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                ax.set_xlabel('\nPredicted Values')
                ax.set_ylabel('Actual Values ')
                ## Ticket labels - List must be in alphabetical order
                ax.xaxis.set_ticklabels(['False','True'])
                ax.yaxis.set_ticklabels(['False','True'])

                #############################################
                # calculate True Positive Rate (TPR) or Sensitivity
                TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
                print('True Positive Rate (TPR) or Sensitivity:', TPR)

                # calculate False Positive Rate (FPR)
                FPR = cf1_test[0][1] / (cf1_test[0][1] + cf1_test[1][1])
                print('False Positive Rate (FPR):', FPR)

                #################################################
                print(f"Accuracy train: {best*100:.2f}", f"Accuracy test: {best_test*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                plt.show()
# Out:
# >>> event_base 10 AHI_base 5 num_1 10 rs 329
# 0.7207207207207207 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7169811320754716
# False Positive Rate (FPR): 0.27586206896551724
# True Positive Rate (TPR) or Sensitivity: 0.6629213483146067
# False Positive Rate (FPR): 0.37
# Accuracy train: 72.07 Accuracy test: 64.55 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> event_base 10 AHI_base 6 num_1 10 rs 329
# 0.7281553398058253 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.723404255319149
# False Positive Rate (FPR): 0.26785714285714285
# True Positive Rate (TPR) or Sensitivity: 0.6593406593406593
# False Positive Rate (FPR): 0.3584905660377358
# Accuracy train: 72.82 Accuracy test: 64.97 Threshold for Number of Events: 10 Threshold for AHI: 6 lenght of data 313
# >>> event_base 10 AHI_base 7 num_1 10 rs 329
# 0.7525773195876289 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.7727272727272727
# False Positive Rate (FPR): 0.2641509433962264
# True Positive Rate (TPR) or Sensitivity: 0.6744186046511628
# False Positive Rate (FPR): 0.34234234234234234
# Accuracy train: 75.26 Accuracy test: 66.50 Threshold for Number of Events: 10 Threshold for AHI: 7 lenght of data 294
# >>> event_base 10 AHI_base 10 num_1 10 rs 329
# 0.7564102564102564 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8285714285714286
# False Positive Rate (FPR): 0.3023255813953488
# True Positive Rate (TPR) or Sensitivity: 0.7142857142857143
# False Positive Rate (FPR): 0.3645833333333333
# Accuracy train: 75.64 Accuracy test: 66.67 Threshold for Number of Events: 10 Threshold for AHI: 10 lenght of data 237
# >>> event_base 10 AHI_base 13 num_1 10 rs 329
# 0.7627118644067796 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8260869565217391
# False Positive Rate (FPR): 0.2777777777777778
# True Positive Rate (TPR) or Sensitivity: 0.75
# False Positive Rate (FPR): 0.4025974025974026
# Accuracy train: 76.27 Accuracy test: 65.29 Threshold for Number of Events: 10 Threshold for AHI: 13 lenght of data 180
# >>> event_base 10 AHI_base 14 num_1 10 rs 329
# 0.7678571428571429 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8095238095238095
# False Positive Rate (FPR): 0.2571428571428571
# True Positive Rate (TPR) or Sensitivity: 0.75
# False Positive Rate (FPR): 0.41333333333333333
# Accuracy train: 76.79 Accuracy test: 64.35 Threshold for Number of Events: 10 Threshold for AHI: 14 lenght of data 171
# >>> event_base 48 AHI_base 13 num_1 10 rs 329
# 0.7758620689655172 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8260869565217391
# False Positive Rate (FPR): 0.2571428571428571
# True Positive Rate (TPR) or Sensitivity: 0.7380952380952381
# False Positive Rate (FPR): 0.41025641025641024
# Accuracy train: 77.59 Accuracy test: 64.17 Threshold for Number of Events: 48 Threshold for AHI: 13 lenght of data 178
# >>> event_base 89 AHI_base 13 num_1 10 rs 329
# 0.7777777777777778 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.8421052631578947
# False Positive Rate (FPR): 0.2571428571428571
# True Positive Rate (TPR) or Sensitivity: 0.7222222222222222
# False Positive Rate (FPR): 0.40789473684210525
# Accuracy train: 77.78 Accuracy test: 63.39 Threshold for Number of Events: 89 Threshold for AHI: 13 lenght of data 166

# %%
# dic = dic2
from sklearn.model_selection import train_test_split

best = -100
ee = 338

ss = 0
eee = 338
best_test = -100
import numpy as np



for event_base in np.arange(10,100):
    for AHI_base in np.arange(5,15):        
        for num_1 in [10]:
            
#             print(">>>", event_base, AHI_base, num_1)
            prob = [] 
#             print(num_1)
        # on the training set the num_1 value is 6 or 7 in average
        # for num_1 in w:
            pred_label_fused = []
            for i in range(338):

        # max vote approach ################################################################
                fused_label = []
                for j in range(len(dic)):
                    fused_label.append(dic[j][i])

                if sum(fused_label) > num_1:
                    pred_label_fused.append(1)
                else:
                    pred_label_fused.append(0)

                prob.append(sum(fused_label)/len(fused_label))


            from sklearn.metrics import confusion_matrix
            import matplotlib.pyplot as plt
            from sklearn.metrics import roc_curve, auc,roc_auc_score
            import seaborn as sns


            actual_label = []
            # CUMSUM[0] starting from second data in all data(train+test)
            for i in range(0, len(CUMSUM)-2):
                actual_label.append(int(sum(label_n[CUMSUM[i]:CUMSUM[i+1]]) /len(label_n[CUMSUM[i]:CUMSUM[i+1]])))


            actual_label = actual_label[-ee:]
            pred_label_fused = pred_label_fused[-ee:]

        #     print(len(actual_label), len(pred_label_fused))


            ###event base #############################################################################
            tempp_consider = np.where(np.array(tempp) > event_base, 1, 0)    
            #### AHI > THER ###########################################################################
            filtered_df = df[(df["ahi_a0h3a"] >= AHI_base) & (df["htnderv_s1"] == 0) & (df["htnderv_s2"].notnull())]
            selected_basedonAHI = [str(x[0]) for x in filtered_df[["nsrrid"]].values]
            AHI_considered = []
            for patient in file_nn:
                if patient[6:-7] in selected_basedonAHI:
                    AHI_considered.append(1)
                else:
                    AHI_considered.append(0)
            AHI_considered = np.array(AHI_considered)
            ################################################################################
            final_consider = tempp_consider&AHI_considered

            ## update ################################################################################
            Consider = [np.array(final_consider)==1][0]
            Consider = np.array(Consider[1:-1])
            Consider = Consider[-ee:]

            # update
            actual_label = np.array(actual_label)[Consider]
            pred_label_fused = np.array(pred_label_fused)[Consider]

#             print(len(actual_label), len(pred_label_fused))




#                 X_train, X_test, y_train, y_test = train_test_split(actual_label, pred_label_fused, test_size=0.85, random_state=rs)
#                 X_train, X_test, y_train, y_test = actual_label[0:100], actual_label[100:300], pred_label_fused[0:100], pred_label_fused[100:300]
#             X_train, X_test, y_train, y_test = actual_label[200:300], actual_label[0:200], pred_label_fused[200:300], pred_label_fused[0:200]
#             X_train, X_test, y_train, y_test = actual_label[100:200], list(actual_label[0:100])+list(actual_label[200:300]), pred_label_fused[100:200],list(pred_label_fused[0:100])+list(pred_label_fused[200:300]) 
#             X_train, X_test, y_train, y_test = actual_label[0:int(.33*len(actual_label))], actual_label[int(.33*len(actual_label)):300], pred_label_fused[0:int(.33*len(actual_label))], pred_label_fused[int(.33*len(actual_label)):300]
            X_train, X_test, y_train, y_test = actual_label[int(.66*len(actual_label)):300], actual_label[0:int(.66*len(actual_label))], pred_label_fused[int(.66*len(actual_label)):300], pred_label_fused[0:int(.66*len(actual_label))]
#             X_train, X_test, y_train, y_test = actual_label[int(.33*len(actual_label)):int(.66*len(actual_label))], list(actual_label[0:int(.33*len(actual_label))])+list(actual_label[int(.66*len(actual_label)):300]), pred_label_fused[int(.33*len(actual_label)):int(.66*len(actual_label))],list(pred_label_fused[0:int(.33*len(actual_label))])+list(pred_label_fused[int(.66*len(actual_label)):300]) 

#                 X_train, X_test, y_train, y_test = actual_label[rs:], actual_label[:rs], pred_label_fused[rs:], pred_label_fused[:rs]

            cf1 = confusion_matrix(X_train, y_train)
            cf1_test = confusion_matrix(X_test, y_test)

            lenn = len(y_train)
            lenn_test = len(y_test)

            if best < (cf1[0][0] + cf1[1][1]) / lenn:
#                 if best_test < (cf1_test[0][0] + cf1_test[1][1]) / lenn_test:
                print(">>>", "event_base", event_base, "AHI_base", AHI_base, "num_1",num_1, "rs",rs)
                # train
                best_pred = pred_label_fused
                best = (cf1[0][0] + cf1[1][1]) / lenn
                print((cf1[0][0] + cf1[1][1]) / lenn, "num_1", num_1)
                ax = sns.heatmap(cf1, annot=True, cmap='Blues' , fmt=".1f")
                ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                ax.set_xlabel('\nPredicted Values')
                ax.set_ylabel('Actual Values ')
                ## Ticket labels - List must be in alphabetical order
                ax.xaxis.set_ticklabels(['False','True'])
                ax.yaxis.set_ticklabels(['False','True'])

                #############################################
                # calculate True Positive Rate (TPR) or Sensitivity
                TPR = cf1[0][0] / (cf1[0][0] + cf1[1][0])
                print('True Positive Rate (TPR) or Sensitivity:', TPR)

                # calculate False Positive Rate (FPR)
                FPR = cf1[0][1] / (cf1[0][1] + cf1[1][1])
                print('False Positive Rate (FPR):', FPR)

                #################################################
#                 print(f"Accuracy: {best*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                plt.show()
                # Test #########################################3

                best_test = (cf1_test[0][0] + cf1_test[1][1]) / lenn_test

                ax = sns.heatmap(cf1_test, annot=True, cmap='Oranges' , fmt=".1f")
                ax.set_title('Seaborn Confusion Matrix with labels\n\n')
                ax.set_xlabel('\nPredicted Values')
                ax.set_ylabel('Actual Values ')
                ## Ticket labels - List must be in alphabetical order
                ax.xaxis.set_ticklabels(['False','True'])
                ax.yaxis.set_ticklabels(['False','True'])

                #############################################
                # calculate True Positive Rate (TPR) or Sensitivity
                TPR = cf1_test[0][0] / (cf1_test[0][0] + cf1_test[1][0])
                print('True Positive Rate (TPR) or Sensitivity:', TPR)

                # calculate False Positive Rate (FPR)
                FPR = cf1_test[0][1] / (cf1_test[0][1] + cf1_test[1][1])
                print('False Positive Rate (FPR):', FPR)

                #################################################
                print(f"Accuracy train: {best*100:.2f}", f"Accuracy test: {best_test*100:.2f}", "Threshold for Number of Events:", event_base , "Threshold for AHI:" , AHI_base, "lenght of data", len(pred_label_fused))
                plt.show()
# Out:
# >>> event_base 10 AHI_base 5 num_1 10 rs 329
# 0.5714285714285714 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.5714285714285714
# False Positive Rate (FPR): 0.42857142857142855
# True Positive Rate (TPR) or Sensitivity: 0.719626168224299
# False Positive Rate (FPR): 0.3017241379310345
# Accuracy train: 57.14 Accuracy test: 70.85 Threshold for Number of Events: 10 Threshold for AHI: 5 lenght of data 338
# >>> event_base 10 AHI_base 7 num_1 10 rs 329
# 0.6 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.5714285714285714
# False Positive Rate (FPR): 0.3793103448275862
# True Positive Rate (TPR) or Sensitivity: 0.7727272727272727
# False Positive Rate (FPR): 0.2830188679245283
# Accuracy train: 60.00 Accuracy test: 74.23 Threshold for Number of Events: 10 Threshold for AHI: 7 lenght of data 294
# >>> event_base 10 AHI_base 8 num_1 10 rs 329
# 0.6170212765957447 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.6153846153846154
# False Positive Rate (FPR): 0.38181818181818183
# True Positive Rate (TPR) or Sensitivity: 0.7682926829268293
# False Positive Rate (FPR): 0.30303030303030304
# Accuracy train: 61.70 Accuracy test: 72.93 Threshold for Number of Events: 10 Threshold for AHI: 8 lenght of data 275
# >>> event_base 10 AHI_base 9 num_1 10 rs 329
# 0.6292134831460674 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.6285714285714286
# False Positive Rate (FPR): 0.37037037037037035
# True Positive Rate (TPR) or Sensitivity: 0.7894736842105263
# False Positive Rate (FPR): 0.3191489361702128
# Accuracy train: 62.92 Accuracy test: 72.94 Threshold for Number of Events: 10 Threshold for AHI: 9 lenght of data 259
# >>> event_base 10 AHI_base 12 num_1 10 rs 329
# 0.6417910447761194 num_1 10
# True Positive Rate (TPR) or Sensitivity: 0.72
# False Positive Rate (FPR): 0.40476190476190477
# True Positive Rate (TPR) or Sensitivity: 0.8148148148148148
# False Positive Rate (FPR): 0.32894736842105265
# Accuracy train: 64.18 Accuracy test: 73.08 Threshold for Number of Events: 10 Threshold for AHI: 12 lenght of data 197
